# %%
# !pip install hyperas
# !pip install hyperopt
# !pip install tfkerassurgeon
# !pip install kerassurgeon

# %%
import os
# import tensorflow as tf
# import pprint # for pretty printing our device stats
from google.colab import drive
drive.mount('/content/drive')

COMP_PATH = "/content/drive/My Drive/Colab Notebooks/NUS/CS5242 Neural Networks and Deep Learning/Project"
traindata_output_file = os.path.join(COMP_PATH, 'Tuning_fit_gen.cmd.txt')

if os.path.exists(traindata_output_file):
    os.remove(traindata_output_file)

os.chdir(COMP_PATH)
os.listdir()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['splits',
#  'groundTruth',
#  'airplane.png',
#  'segment.txt',
#  'main.py',
#  'data',
#  '__pycache__',
#  'Project CS5242 - Data Exploration.ipynb',
#  'model.png',
#  'model.json',
#  'model.h5',
#  'Load Model',
#  'All mains',
#  'All outputs',
#  'Copy of read_datasetBreakfast.py',
#  'read_datasetBreakfast.py',
#  'start_run.ipynb',
#  'Tuning.h5',
#  'LSTM Main.ipynb',
#  'Tuning_fit_gen.LSTM.cmd.py',
#  'loadfile_output.txt',
#  'Tuning_fit_gen.LSTM.cmd.txt',
#  'Tuning.LSTM.h5',
#  'tuning_LSTM.output.txt',
#  'Tuning_fit_gen.CNNLSTM.cmd.txt',
#  'start_run - 2.ipynb',
#  'Tuning_fit_gen.CNNLSTM.cmd.py',
#  'Tuning_fit_gen.main.ipynb']

# %%
# !python "Tuning_fit_gen.cmd.py" 2>&1 | tee Tuning_fit_gen.cmd.txt

# !python "Tuning_fit_gen.no_train.cmd.py" 2>&1 | tee Tuning_fit_gen.no_train.cmd.txt

# !python "Tuning_fit_gen.InceptionV3.cmd.py" 2>&1 | tee Tuning_fit_gen.InceptionV3.cmd.txt

# !python "Tuning_fit_gen.Inception.cmd.py" 2>&1 | tee Tuning_fit_gen.Inception.cmd.txt

# !python "Tuning_fit_gen.per_file.cmd.py" 2>&1 | tee Tuning_fit_gen.per_file.cmd.txt

# !python "Tuning_fit_gen.DNN.cmd.py" 2>&1 | tee Tuning_fit_gen.DNN.cmd.txt

# !python "Tuning_fit_gen.LSTM.cmd.py" 2>&1 | tee Tuning_fit_gen.LSTM.cmd.txt

# !python "Tuning_fit_gen.CNNLSTM.cmd.py" 2>&1 | tee Tuning_fit_gen.CNNLSTM.cmd.txt
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %%
a = []
while(1):
    a.append("1")
