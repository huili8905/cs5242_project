# %% [markdown]
# ## Video Action Classification

# %%
import os
import pickle

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_packed_sequence, pack_sequence
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device : {}".format(dev))
# Out:
# Using device : cuda:0

# %% [markdown]
# Load dataset

# %%
# pickle_filename = 'data.pickle'

# if os.path.isfile(pickle_filename):
#     with open(pickle_filename, 'rb') as file:
#         train_data_feat, train_data_labels, test_data_feat = pickle.load(file)
# else:
#     from read_datasetBreakfast import load_data, read_mapping_dict

#     COMP_PATH = ''

#     ''' 
#     training to load train set
#     test to load test set
#     '''
#     train_split =  os.path.join(COMP_PATH, 'splits/train.split1.bundle') #Train Split
#     test_split  =  os.path.join(COMP_PATH, 'splits/test.split1.bundle') #Test Split
#     GT_folder   =  os.path.join(COMP_PATH, 'groundTruth/') #Ground Truth Labels for each training video 
#     DATA_folder =  os.path.join(COMP_PATH, 'data/') #Frame I3D features for all videos
#     mapping_loc =  os.path.join(COMP_PATH, 'splits/mapping_bf.txt') 

#     actions_dict = read_mapping_dict(mapping_loc)
#     train_data_feat, train_data_labels = load_data( train_split, actions_dict, GT_folder, DATA_folder, datatype = "training") #Get features and labels
#     test_data_feat = load_data( test_split, actions_dict, GT_folder, DATA_folder, datatype = "test") #Get features only
    
#     with open(pickle_filename, 'wb') as file:
#         pickle.dump((train_data_feat, train_data_labels, test_data_feat), file)

# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))

# %% [markdown]
# ```python
# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))
# > 1460
# > 1460
# > 252
# ```

# %% [markdown]
# Flatten dataset

# %%
# with open("training_segment.txt", 'r') as file:
#     training_segment = [[int(a) for a in line.split()] for line in file]

# # tot_segment_len = 0
# # n_segment_len = 0
# # max_segment_len = 0
# # min_segment_len = float("inf")

# train_feat_flat = []
# train_labels_flat = []
# train_flat_idx = []
# for video_idx, video_segments in enumerate(tqdm(training_segment)):
#     for i in range(len(video_segments)-1):
#         segment_len = video_segments[i+1] - video_segments[i]
# #         tot_segment_len += segment_len
# #         n_segment_len += 1
# #         if segment_len > max_segment_len:
# #             max_segment_len = segment_len
# #         if segment_len < min_segment_len:
# #             min_segment_len = segment_len
#         train_flat_idx.append(len(train_feat_flat))
#         train_feat_flat.extend(train_data_feat[video_idx][video_segments[i]:video_segments[i+1]])
#         train_labels_flat.extend([(train_data_labels[video_idx][i])-1]*segment_len)
# train_flat_idx.append(len(train_feat_flat))

# # avg_segment_len = tot_segment_len / n_segment_len
# # print(avg_segment_len, max_segment_len, min_segment_len)

# %% [markdown]
# ```python
# print(avg_segment_len, max_segment_len, min_segment_len)
# > 404.3518021201413 5791 8
# ```

# %% [markdown]
# Pickle (or load) flatten dataset

# %%
num_split = 10
load_split = 10

files_exist = []
for i in range(num_split):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    files_exist.append(os.path.isfile(pickle_filename))

if not all(files_exist):
    max_len = len(train_feat_flat)
    split_len = max_len//num_split
    for i in tqdm(range(num_split)):
        pickle_filename = "flatten_data_{}.pickle".format(i)
        start_idx = split_len*i
        end_idx = split_len*(i+1) if i < num_split-1 else max_len
        print(i, start_idx, end_idx)
        with open(pickle_filename, 'wb') as file:
            train_feat_split_tensor = torch.stack(train_feat_flat[start_idx:end_idx]).to(dtype=torch.float32)
            train_labels_split_tensor = torch.LongTensor(train_labels_flat[start_idx:end_idx])
            pickle.dump((train_feat_split_tensor, train_labels_split_tensor), file)
    with open("flatten_data_idx.txt", 'w') as file:
        for i in train_flat_idx:
            file.write("{} ".format(i))

train_feat_split_list = []
train_labels_split_list = []
for i in tqdm(range(load_split)):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    with open(pickle_filename, 'rb') as file:
        train_feat_split, train_labels_split = pickle.load(file)
        train_feat_split_list.append(train_feat_split)
        train_labels_split_list.append(train_labels_split)
with open("flatten_data_idx.txt", 'r') as file:
    train_flat_idx = [int(a) for line in file for a in line.split()]

train_feat_tensor = torch.cat(train_feat_split_list, dim=0)
train_labels_tensor = torch.cat(train_labels_split_list, dim=0)
print(train_feat_tensor.shape)
print(train_labels_tensor.shape)
print(len(train_flat_idx))
print(train_flat_idx[:10])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# torch.Size([2860789, 400])
# torch.Size([2860789])
# 7076
# [0, 260, 465, 793, 1054, 1687, 5923, 7216, 7288, 7338]

# %% [markdown]
# Define model

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
#         self.dropout1 = nn.Dropout(p=0.2)
        self.lstm = nn.LSTM(400, 64, batch_first=True)
        self.linear = nn.Linear(64*3, 47)
#         self.linear = nn.Linear(64, 47)
        self.padding_value = 0
    def forward(self, x):
        h, (h_last, c) = self.lstm(x)
        h_pad, lengths = pad_packed_sequence(h, batch_first=True, padding_value=self.padding_value)
        non_padding_sum = torch.sum((h_pad != self.padding_value), 1)
        non_padding_sum[non_padding_sum == 0] = 1
        h_avg_pool = torch.sum(h_pad, 1) / non_padding_sum
        h_max_pool = torch.max(h_pad, 1)[0]
        x = torch.cat((h_pad[:,-1], h_avg_pool, h_max_pool), 1)
#         x = h_max_pool
        x = self.linear(x)
        return x

model = Model()
for param in model.parameters():
    print(type(param.data), param.size())
# Out:
# <class 'torch.Tensor'> torch.Size([256, 400])
# <class 'torch.Tensor'> torch.Size([256, 64])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([47, 192])
# <class 'torch.Tensor'> torch.Size([47])

# %% [markdown]
# Define training routine

# %%
import time
import copy

import copy
def train_val(num_epoch, dataloader_dict, model, loss, optimizer, print_epoch=True, device=None):
    val_acc_history = []
    val_loss_history = []
    train_acc_history = []
    train_loss_history = []
    best_acc = 0.0
    best_model_weights = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epoch):
        since = time.time()
        if print_epoch:
            print("Epoch {}/{}".format(epoch+1, num_epoch))
            print("-----------")
        
        for phase in ["train", "val"]:
            if phase == "train":
                model.train()
            else :
                model.eval()
            total_loss = 0.0
            total_correct = 0.0
            for X, y, batch_len in dataloader_dict[phase]:
                if device is not None:
                    X = X.to(device)
                    y = y.to(device)
                with torch.set_grad_enabled(phase == "train"):
                    y_tilde = model(X)
                    L = loss(y_tilde, y)
                    if phase == "train":
                        optimizer.zero_grad()
                        L.backward()
                        optimizer.step()
                y_tilde_label = torch.argmax(y_tilde, dim=1)
                num_correct = torch.sum((y_tilde_label == y))
                
                total_loss += L.item() * batch_len
                total_correct += num_correct.item()
            
            epoch_loss = total_loss / len(dataloader_dict[phase].dataset)
            epoch_acc = (total_correct / len(dataloader_dict[phase].dataset)) * 100
            
            if phase == "val":
                val_loss_history.append(epoch_loss)
                val_acc_history.append(epoch_acc)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_weights = copy.deepcopy(model.state_dict())
            if phase == "train":
                train_loss_history.append(epoch_loss)
                train_acc_history.append(epoch_acc)

            if print_epoch:
                print("{} | Loss : {:.4f}  Acc : {:.2f}%".format(phase.capitalize().ljust(5), epoch_loss, epoch_acc))
        
        print("Time elapsed : {:.2f} s".format(time.time() - since))
        print()
    
    model.load_state_dict(best_model_weights)
    return model, (train_acc_history, train_loss_history, val_acc_history, val_loss_history)

# %% [markdown]
# Create dataset

# %%
from torch.utils.data import Dataset, DataLoader, Subset
from torch._utils import _accumulate

class MyDataset(Dataset):
    
    def __init__(self, features, labels, indices):
        self.features = features
        self.labels = labels
        self.indices = indices
        self.len = len(self.indices) - 1

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        return (self.features[self.indices[idx]:self.indices[idx+1]], self.labels[self.indices[idx]])

my_dataset = MyDataset(train_feat_tensor, train_labels_tensor, train_flat_idx)

# %% [markdown]
# Split dataset

# %%
tot_len = len(my_dataset)
print("Number of training data: {}".format(tot_len))

train_split_size = 0.8
lengths = [int(tot_len*train_split_size), tot_len - int(tot_len*train_split_size)]

train_dataset, val_dataset = torch.utils.data.random_split(my_dataset, lengths)
# Out:
# Number of training data: 7075

# %% [markdown]
# Create DataLoader

# %%
def collate(batch_data):
    features = []
    labels = []
    for feature, label in batch_data:
        features.append(feature)
        labels.append(label)
    return (pack_sequence(features, enforce_sorted=False), torch.tensor(labels), len(batch_data))

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)

# %% [markdown]
# Start training

# %%
my_model = Model()
my_model.to(dev)
loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(my_model.parameters())

trained_model, acc = train_val(100, {"train": train_loader, "val": val_loader}, my_model, loss, optimizer, device=dev)
# Out:
# Epoch 1/100
# -----------
# Train | Loss : 3.2798  Acc : 17.90%
# Val   | Loss : 2.9245  Acc : 25.94%
# Time elapsed : 58.79 s
#
# Epoch 2/100
# -----------
# Train | Loss : 2.6778  Acc : 30.27%
# Val   | Loss : 2.5521  Acc : 32.93%
# Time elapsed : 55.08 s
#
# Epoch 3/100
# -----------
# Train | Loss : 2.3483  Acc : 36.33%
# Val   | Loss : 2.3099  Acc : 36.40%
# Time elapsed : 56.43 s
#
# Epoch 4/100
# -----------
# Train | Loss : 2.1272  Acc : 40.60%
# Val   | Loss : 2.1195  Acc : 43.46%
# Time elapsed : 54.53 s
#
# Epoch 5/100
# -----------
# Train | Loss : 1.9616  Acc : 45.46%
# Val   | Loss : 2.0457  Acc : 42.54%
# Time elapsed : 54.47 s
#
# Epoch 6/100
# -----------
# Train | Loss : 1.8324  Acc : 48.46%
# Val   | Loss : 1.8806  Acc : 47.42%
# Time elapsed : 54.33 s
#
# Epoch 7/100
# -----------
# Train | Loss : 1.7365  Acc : 50.95%
# Val   | Loss : 1.8694  Acc : 46.22%
# Time elapsed : 54.91 s
#
# Epoch 8/100
# -----------
# Train | Loss : 1.6449  Acc : 53.96%
# Val   | Loss : 1.7951  Acc : 50.74%
# Time elapsed : 54.41 s
#
# Epoch 9/100
# -----------
# Train | Loss : 1.5612  Acc : 55.49%
# Val   | Loss : 1.7681  Acc : 49.19%
# Time elapsed : 56.01 s
#
# Epoch 10/100
# -----------
# Train | Loss : 1.4998  Acc : 56.87%
# Val   | Loss : 1.7334  Acc : 50.46%
# Time elapsed : 56.82 s
#
# Epoch 11/100
# -----------
# Train | Loss : 1.4441  Acc : 58.75%
# Val   | Loss : 1.6501  Acc : 52.44%
# Time elapsed : 55.98 s
#
# Epoch 12/100
# -----------
# Train | Loss : 1.3999  Acc : 60.05%
# Val   | Loss : 1.6073  Acc : 53.29%
# Time elapsed : 56.05 s
#
# Epoch 13/100
# -----------
# Train | Loss : 1.3371  Acc : 61.73%
# Val   | Loss : 1.6137  Acc : 52.08%
# Time elapsed : 57.35 s
#
# Epoch 14/100
# -----------
# Train | Loss : 1.3054  Acc : 61.48%
# Val   | Loss : 1.5420  Acc : 54.63%
# Time elapsed : 58.07 s
#
# Epoch 15/100
# -----------
# Train | Loss : 1.2364  Acc : 64.73%
# Val   | Loss : 1.5220  Acc : 55.48%
# Time elapsed : 56.59 s
#
# Epoch 16/100
# -----------
# Train | Loss : 1.1825  Acc : 65.25%
# Val   | Loss : 1.5242  Acc : 55.27%
# Time elapsed : 57.68 s
#
# Epoch 17/100
# -----------
# Train | Loss : 1.1409  Acc : 66.31%
# Val   | Loss : 1.5272  Acc : 54.49%
# Time elapsed : 56.85 s
#
# Epoch 18/100
# -----------
# Train | Loss : 1.1080  Acc : 67.24%
# Val   | Loss : 1.4986  Acc : 54.06%
# Time elapsed : 60.42 s
#
# Epoch 19/100
# -----------
# Train | Loss : 1.0633  Acc : 68.76%
# Val   | Loss : 1.4551  Acc : 56.89%
# Time elapsed : 60.07 s
#
# Epoch 20/100
# -----------
# Train | Loss : 1.0303  Acc : 70.19%
# Val   | Loss : 1.4279  Acc : 56.54%
# Time elapsed : 60.60 s
#
# Epoch 21/100
# -----------
# Train | Loss : 1.0051  Acc : 71.13%
# Val   | Loss : 1.4025  Acc : 58.09%
# Time elapsed : 60.42 s
#
# Epoch 22/100
# -----------
# Train | Loss : 0.9712  Acc : 70.78%
# Val   | Loss : 1.4487  Acc : 56.47%
# Time elapsed : 59.40 s
#
# Epoch 23/100
# -----------
# Train | Loss : 0.9445  Acc : 72.83%
# Val   | Loss : 1.4290  Acc : 57.31%
# Time elapsed : 58.94 s
#
# Epoch 24/100
# -----------
# Train | Loss : 0.9237  Acc : 73.20%
# Val   | Loss : 1.4264  Acc : 55.48%
# Time elapsed : 59.51 s
#
# Epoch 25/100
# -----------
# Train | Loss : 0.8950  Acc : 74.06%
# Val   | Loss : 1.3969  Acc : 56.40%
# Time elapsed : 60.01 s
#
# Epoch 26/100
# -----------
# Train | Loss : 0.8733  Acc : 74.79%
# Val   | Loss : 1.3831  Acc : 58.73%
# Time elapsed : 61.00 s
#
# Epoch 27/100
# -----------
# Train | Loss : 0.8469  Acc : 75.97%
# Val   | Loss : 1.3835  Acc : 58.16%
# Time elapsed : 59.33 s
#
# Epoch 28/100
# -----------
# Train | Loss : 0.8004  Acc : 77.16%
# Val   | Loss : 1.3991  Acc : 56.47%
# Time elapsed : 60.33 s
#
# Epoch 29/100
# -----------
# Train | Loss : 0.7886  Acc : 77.69%
# Val   | Loss : 1.3419  Acc : 60.71%
# Time elapsed : 61.70 s
#
# Epoch 30/100
# -----------
# Train | Loss : 0.7615  Acc : 78.25%
# Val   | Loss : 1.3463  Acc : 58.45%
# Time elapsed : 61.00 s
#
# Epoch 31/100
# -----------
# Train | Loss : 0.7368  Acc : 79.52%
# Val   | Loss : 1.3750  Acc : 57.74%
# Time elapsed : 59.55 s
#
# Epoch 32/100
# -----------
# Train | Loss : 0.7050  Acc : 80.53%
# Val   | Loss : 1.3378  Acc : 59.58%
# Time elapsed : 59.20 s
#
# Epoch 33/100
# -----------
# Train | Loss : 0.6728  Acc : 81.48%
# Val   | Loss : 1.3423  Acc : 59.72%
# Time elapsed : 59.48 s
#
# Epoch 34/100
# -----------
# Train | Loss : 0.6781  Acc : 81.25%
# Val   | Loss : 1.3688  Acc : 59.22%
# Time elapsed : 59.71 s
#
# Epoch 35/100
# -----------
# Train | Loss : 0.6501  Acc : 81.52%
# Val   | Loss : 1.3077  Acc : 60.49%
# Time elapsed : 59.89 s
#
# Epoch 36/100
# -----------
# Train | Loss : 0.6277  Acc : 82.35%
# Val   | Loss : 1.3206  Acc : 60.14%
# Time elapsed : 59.43 s
#
# Epoch 37/100
# -----------
# Train | Loss : 0.6019  Acc : 84.12%
# Val   | Loss : 1.3340  Acc : 59.51%
# Time elapsed : 60.95 s
#
# Epoch 38/100
# -----------
# Train | Loss : 0.5992  Acc : 83.71%
# Val   | Loss : 1.3159  Acc : 60.28%
# Time elapsed : 60.18 s
#
# Epoch 39/100
# -----------
# Train | Loss : 0.5808  Acc : 84.35%
# Val   | Loss : 1.3212  Acc : 60.28%
# Time elapsed : 60.06 s
#
# Epoch 40/100
# -----------
# Train | Loss : 0.5548  Acc : 84.88%
# Val   | Loss : 1.3024  Acc : 60.14%
# Time elapsed : 59.83 s
#
# Epoch 41/100
# -----------
# Train | Loss : 0.5393  Acc : 85.37%
# Val   | Loss : 1.2990  Acc : 60.57%
# Time elapsed : 59.73 s
#
# Epoch 42/100
# -----------
# Train | Loss : 0.5332  Acc : 85.34%
# Val   | Loss : 1.3356  Acc : 59.58%
# Time elapsed : 59.43 s
#
# Epoch 43/100
# -----------
# Train | Loss : 0.5149  Acc : 86.40%
# Val   | Loss : 1.3299  Acc : 60.14%
# Time elapsed : 60.77 s
#
# Epoch 44/100
# -----------
# Train | Loss : 0.4933  Acc : 87.47%
# Val   | Loss : 1.3141  Acc : 61.63%
# Time elapsed : 59.13 s
#
# Epoch 45/100
# -----------
# Train | Loss : 0.4574  Acc : 88.73%
# Val   | Loss : 1.3109  Acc : 60.07%
# Time elapsed : 60.81 s
#
# Epoch 46/100
# -----------
# Train | Loss : 0.4510  Acc : 88.75%
# Val   | Loss : 1.2940  Acc : 61.20%
# Time elapsed : 59.13 s
#
# Epoch 47/100
# -----------
# Train | Loss : 0.4386  Acc : 89.36%
# Val   | Loss : 1.3053  Acc : 60.57%
# Time elapsed : 59.46 s
#
# Epoch 48/100
# -----------
# Train | Loss : 0.4309  Acc : 89.33%
# Val   | Loss : 1.3474  Acc : 60.64%
# Time elapsed : 59.05 s
#
# Epoch 49/100
# -----------
# Train | Loss : 0.4044  Acc : 90.19%
# Val   | Loss : 1.3148  Acc : 61.13%
# Time elapsed : 60.17 s
#
# Epoch 50/100
# -----------
# Train | Loss : 0.3942  Acc : 90.57%
# Val   | Loss : 1.3239  Acc : 60.57%
# Time elapsed : 60.64 s
#
# Epoch 51/100
# -----------
# Train | Loss : 0.3787  Acc : 91.01%
# Val   | Loss : 1.3100  Acc : 61.91%
# Time elapsed : 61.43 s
#
# Epoch 52/100
# -----------
# Train | Loss : 0.3713  Acc : 91.11%
# Val   | Loss : 1.3738  Acc : 60.71%
# Time elapsed : 59.58 s
#
# Epoch 53/100
# -----------
# Train | Loss : 0.3718  Acc : 90.81%
# Val   | Loss : 1.3191  Acc : 61.84%
# Time elapsed : 58.11 s
#
# Epoch 54/100
# -----------
# Train | Loss : 0.3550  Acc : 92.00%
# Val   | Loss : 1.3297  Acc : 60.71%
# Time elapsed : 59.27 s
#
# Epoch 55/100
# -----------
# Train | Loss : 0.3431  Acc : 91.89%
# Val   | Loss : 1.3586  Acc : 60.07%
# Time elapsed : 58.61 s
#
# Epoch 56/100
# -----------
# Train | Loss : 0.3340  Acc : 92.35%
# Val   | Loss : 1.3602  Acc : 61.41%
# Time elapsed : 59.09 s
#
# Epoch 57/100
# -----------
# Train | Loss : 0.3353  Acc : 92.65%
# Val   | Loss : 1.3382  Acc : 62.61%
# Time elapsed : 60.60 s
#
# Epoch 58/100
# -----------
# Train | Loss : 0.3296  Acc : 92.39%
# Val   | Loss : 1.3185  Acc : 62.05%
# Time elapsed : 59.70 s
#
# Epoch 59/100
# -----------
# Train | Loss : 0.3009  Acc : 94.06%
# Val   | Loss : 1.3697  Acc : 60.49%
# Time elapsed : 60.21 s
#
# Epoch 60/100
# -----------
# Train | Loss : 0.3078  Acc : 93.43%
# Val   | Loss : 1.3460  Acc : 61.20%
# Time elapsed : 58.42 s
#
# Epoch 61/100
# -----------
# Train | Loss : 0.2976  Acc : 93.67%
# Val   | Loss : 1.3581  Acc : 60.14%
# Time elapsed : 58.42 s
#
# Epoch 62/100
# -----------
# Train | Loss : 0.2636  Acc : 94.82%
# Val   | Loss : 1.3686  Acc : 61.41%
# Time elapsed : 60.08 s
#
# Epoch 63/100
# -----------
# Train | Loss : 0.2716  Acc : 94.51%
# Val   | Loss : 1.3489  Acc : 60.57%
# Time elapsed : 59.85 s
#
# Epoch 64/100
# -----------
# Train | Loss : 0.2577  Acc : 94.95%
# Val   | Loss : 1.3509  Acc : 62.12%
# Time elapsed : 59.21 s
#
# Epoch 65/100
# -----------
# Train | Loss : 0.2511  Acc : 95.62%
# Val   | Loss : 1.3313  Acc : 61.77%
# Time elapsed : 59.25 s
#
# Epoch 66/100
# -----------
# Train | Loss : 0.2376  Acc : 95.94%
# Val   | Loss : 1.3873  Acc : 61.34%
# Time elapsed : 58.49 s
#
# Epoch 67/100
# -----------
# Train | Loss : 0.2431  Acc : 95.35%
# Val   | Loss : 1.3839  Acc : 60.85%
# Time elapsed : 58.96 s
#
# Epoch 68/100
# -----------
# Train | Loss : 0.2368  Acc : 95.69%
# Val   | Loss : 1.3897  Acc : 61.27%
# Time elapsed : 60.22 s
#
# Epoch 69/100
# -----------
# Train | Loss : 0.2195  Acc : 96.20%
# Val   | Loss : 1.3616  Acc : 60.78%
# Time elapsed : 60.53 s
#
# Epoch 70/100
# -----------
# Train | Loss : 0.2228  Acc : 96.13%
# Val   | Loss : 1.3969  Acc : 60.92%
# Time elapsed : 60.58 s
#
# Epoch 71/100
# -----------
# Train | Loss : 0.2038  Acc : 96.63%
# Val   | Loss : 1.3959  Acc : 61.13%
# Time elapsed : 60.39 s
#
# Epoch 72/100
# -----------
# Train | Loss : 0.1936  Acc : 96.80%
# Val   | Loss : 1.4381  Acc : 60.35%
# Time elapsed : 59.08 s
#
# Epoch 73/100
# -----------
# Train | Loss : 0.1784  Acc : 97.46%
# Val   | Loss : 1.3994  Acc : 60.85%
# Time elapsed : 58.66 s
#
# Epoch 74/100
# -----------
# Train | Loss : 0.1719  Acc : 97.65%
# Val   | Loss : 1.3959  Acc : 62.12%
# Time elapsed : 60.00 s
#
# Epoch 75/100
# -----------
# Train | Loss : 0.1906  Acc : 96.48%
# Val   | Loss : 1.3947  Acc : 60.49%
# Time elapsed : 59.44 s
#
# Epoch 76/100
# -----------
# Train | Loss : 0.2061  Acc : 96.22%
# Val   | Loss : 1.4281  Acc : 60.00%
# Time elapsed : 59.99 s
#
# Epoch 77/100
# -----------
# Train | Loss : 0.1978  Acc : 96.31%
# Val   | Loss : 1.4508  Acc : 60.71%
# Time elapsed : 60.28 s
#
# Epoch 78/100
# -----------
# Train | Loss : 0.1705  Acc : 97.35%
# Val   | Loss : 1.4120  Acc : 59.29%
# Time elapsed : 58.53 s
#
# Epoch 79/100
# -----------
# Train | Loss : 0.1825  Acc : 96.78%
# Val   | Loss : 1.4156  Acc : 60.78%
# Time elapsed : 61.62 s
#
# Epoch 80/100
# -----------
# Train | Loss : 0.1728  Acc : 96.77%
# Val   | Loss : 1.5143  Acc : 60.78%
# Time elapsed : 60.83 s
#
# Epoch 81/100
# -----------
# Train | Loss : 0.1654  Acc : 97.28%
# Val   | Loss : 1.4588  Acc : 60.64%
# Time elapsed : 60.18 s
#
# Epoch 82/100
# -----------
# Train | Loss : 0.1589  Acc : 97.40%
# Val   | Loss : 1.4399  Acc : 62.12%
# Time elapsed : 60.04 s
#
# Epoch 83/100
# -----------
# Train | Loss : 0.1412  Acc : 97.79%
# Val   | Loss : 1.4547  Acc : 61.20%
# Time elapsed : 61.49 s
#
# Epoch 84/100
# -----------
# Train | Loss : 0.1331  Acc : 98.34%
# Val   | Loss : 1.4694  Acc : 61.06%
# Time elapsed : 60.90 s
#
# Epoch 85/100
# -----------
# Train | Loss : 0.1519  Acc : 97.61%
# Val   | Loss : 1.4943  Acc : 59.93%
# Time elapsed : 61.73 s
#
# Epoch 86/100
# -----------
# Train | Loss : 0.1599  Acc : 97.17%
# Val   | Loss : 1.4802  Acc : 60.78%
# Time elapsed : 60.46 s
#
# Epoch 87/100
# -----------
# Train | Loss : 0.1327  Acc : 98.34%
# Val   | Loss : 1.4968  Acc : 60.71%
# Time elapsed : 60.51 s
#
# Epoch 88/100
# -----------
# Train | Loss : 0.1139  Acc : 98.89%
# Val   | Loss : 1.4806  Acc : 60.71%
# Time elapsed : 61.05 s
#
# Epoch 89/100
# -----------
# Train | Loss : 0.1109  Acc : 98.94%
# Val   | Loss : 1.4867  Acc : 62.90%
# Time elapsed : 60.50 s
#
# Epoch 90/100
# -----------
# Train | Loss : 0.1065  Acc : 98.92%
# Val   | Loss : 1.4676  Acc : 61.41%
# Time elapsed : 59.49 s
#
# Epoch 91/100
# -----------
# Train | Loss : 0.1102  Acc : 98.85%
# Val   | Loss : 1.5364  Acc : 60.99%
# Time elapsed : 57.28 s
#
# Epoch 92/100
# -----------
# Train | Loss : 0.1598  Acc : 96.80%
# Val   | Loss : 1.5446  Acc : 61.06%
# Time elapsed : 58.43 s
#
# Epoch 93/100
# -----------
# Train | Loss : 0.1596  Acc : 96.98%
# Val   | Loss : 1.5137  Acc : 59.43%
# Time elapsed : 58.27 s
#
# Epoch 94/100
# -----------
# Train | Loss : 0.1319  Acc : 97.84%
# Val   | Loss : 1.4905  Acc : 62.47%
# Time elapsed : 56.94 s
#
# Epoch 95/100
# -----------
# Train | Loss : 0.0974  Acc : 99.06%
# Val   | Loss : 1.5021  Acc : 61.77%
# Time elapsed : 57.32 s
#
# Epoch 96/100
# -----------
# Train | Loss : 0.0839  Acc : 99.51%
# Val   | Loss : 1.5208  Acc : 61.06%
# Time elapsed : 56.64 s
#
# Epoch 97/100
# -----------
# Train | Loss : 0.0761  Acc : 99.59%
# Val   | Loss : 1.5613  Acc : 59.79%
# Time elapsed : 58.73 s
#
# Epoch 98/100
# -----------
# Train | Loss : 0.1357  Acc : 97.47%
# Val   | Loss : 1.6765  Acc : 58.80%
# Time elapsed : 58.26 s
#
# Epoch 99/100
# -----------
# Train | Loss : 0.2113  Acc : 94.82%
# Val   | Loss : 1.5720  Acc : 60.92%
# Time elapsed : 57.76 s
#
# Epoch 100/100
# -----------
# Train | Loss : 0.1714  Acc : 96.27%
# Val   | Loss : 1.5523  Acc : 60.85%
# Time elapsed : 58.61 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.figure(figsize=(18, 5))
epoch_num = range(1, 101)
plt.subplot(1, 2, 1)
plt.title('Accuracy')
plt.ylim(0, 110)
plt.grid(True)
plt.plot(epoch_num, acc[2], color="blue")
plt.plot(epoch_num, acc[0], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])
plt.subplot(1, 2, 2)
plt.title('Loss')
plt.ylim(0, 3)
plt.grid(True)
plt.plot(epoch_num, acc[3], color="blue")
plt.plot(epoch_num, acc[1], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])
