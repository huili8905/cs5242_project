# %% [markdown]
# ## Video Action Classification

# %%
# %cd /content/drive/My\ Drive/Project\ NNDL
import os
import pickle
import time
import copy

import numpy as np
# np.random.seed(5242)
numpy_seed = np.random.get_state()
import torch
# torch.manual_seed(5242)
torch_seed = torch.initial_seed()
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_packed_sequence, pack_sequence, pack_padded_sequence
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device : {}".format(dev))
# !nvidia-smi
# Out:
# /content/drive/My Drive/Project NNDL
# Using device : cuda:0
# Sun Apr  5 16:10:06 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    29W / 149W |     11MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Load dataset

# %%
# pickle_filename = 'data.pickle'

# if os.path.isfile(pickle_filename):
#     with open(pickle_filename, 'rb') as file:
#         train_data_feat, train_data_labels, test_data_feat = pickle.load(file)
# else:
#     from read_datasetBreakfast import load_data, read_mapping_dict

#     COMP_PATH = ''

#     ''' 
#     training to load train set
#     test to load test set
#     '''
#     train_split =  os.path.join(COMP_PATH, 'splits/train.split1.bundle') #Train Split
#     test_split  =  os.path.join(COMP_PATH, 'splits/test.split1.bundle') #Test Split
#     GT_folder   =  os.path.join(COMP_PATH, 'groundTruth/') #Ground Truth Labels for each training video 
#     DATA_folder =  os.path.join(COMP_PATH, 'data/') #Frame I3D features for all videos
#     mapping_loc =  os.path.join(COMP_PATH, 'splits/mapping_bf.txt') 

#     actions_dict = read_mapping_dict(mapping_loc)
#     train_data_feat, train_data_labels = load_data( train_split, actions_dict, GT_folder, DATA_folder, datatype = "training") #Get features and labels
#     test_data_feat = load_data( test_split, actions_dict, GT_folder, DATA_folder, datatype = "test") #Get features only
    
#     with open(pickle_filename, 'wb') as file:
#         pickle.dump((train_data_feat, train_data_labels, test_data_feat), file)

# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))

# %% [markdown]
# ```python
# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))
# > 1460
# > 1460
# > 252
# ```

# %% [markdown]
# Flatten dataset

# %%
# with open("training_segment.txt", 'r') as file:
#     training_segment = [[int(a) for a in line.split()] for line in file]

# # tot_segment_len = 0
# # n_segment_len = 0
# # max_segment_len = 0
# # min_segment_len = float("inf")

# train_feat_flat = []
# train_labels_flat = []
# train_flat_idx = []
# for video_idx, video_segments in enumerate(tqdm(training_segment)):
#     for i in range(len(video_segments)-1):
#         segment_len = video_segments[i+1] - video_segments[i]
# #         tot_segment_len += segment_len
# #         n_segment_len += 1
# #         if segment_len > max_segment_len:
# #             max_segment_len = segment_len
# #         if segment_len < min_segment_len:
# #             min_segment_len = segment_len
#         train_flat_idx.append(len(train_feat_flat))
#         train_feat_flat.extend(train_data_feat[video_idx][video_segments[i]:video_segments[i+1]])
#         train_labels_flat.extend([(train_data_labels[video_idx][i])-1]*segment_len)
# train_flat_idx.append(len(train_feat_flat))

# # avg_segment_len = tot_segment_len / n_segment_len
# # print(avg_segment_len, max_segment_len, min_segment_len)

# %% [markdown]
# ```python
# print(avg_segment_len, max_segment_len, min_segment_len)
# > 404.3518021201413 5791 8
# ```

# %% [markdown]
# Pickle (or load) flatten dataset

# %%
num_split = 10
load_split = 10

files_exist = []
for i in range(num_split):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    files_exist.append(os.path.isfile(pickle_filename))

if not all(files_exist):
    max_len = len(train_feat_flat)
    split_len = max_len//num_split
    for i in tqdm(range(num_split)):
        pickle_filename = "flatten_data_{}.pickle".format(i)
        start_idx = split_len*i
        end_idx = split_len*(i+1) if i < num_split-1 else max_len
        print(i, start_idx, end_idx)
        with open(pickle_filename, 'wb') as file:
            train_feat_split_tensor = torch.stack(train_feat_flat[start_idx:end_idx]).to(dtype=torch.float32)
            train_labels_split_tensor = torch.LongTensor(train_labels_flat[start_idx:end_idx])
            pickle.dump((train_feat_split_tensor, train_labels_split_tensor), file)
    with open("flatten_data_idx.txt", 'w') as file:
        for i in train_flat_idx:
            file.write("{} ".format(i))

train_feat_split_list = []
train_labels_split_list = []
for i in tqdm(range(load_split)):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    with open(pickle_filename, 'rb') as file:
        train_feat_split, train_labels_split = pickle.load(file)
        train_feat_split_list.append(train_feat_split)
        train_labels_split_list.append(train_labels_split)
with open("flatten_data_idx.txt", 'r') as file:
    train_flat_idx = [int(a) for line in file for a in line.split()]

train_feat_tensor = torch.cat(train_feat_split_list, dim=0)
train_labels_tensor = torch.cat(train_labels_split_list, dim=0)
print(train_feat_tensor.shape)
print(train_labels_tensor.shape)
print(len(train_flat_idx))
print(train_flat_idx[:10])
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# torch.Size([2860789, 400])
# torch.Size([2860789])
# 7076
# [0, 260, 465, 793, 1054, 1687, 5923, 7216, 7288, 7338]

# %% [markdown]
# Create Dataset

# %%
class VideoDataset(Dataset):
    
    def __init__(self, features, labels, training_segment_file):
        self.features = features
        self.labels = labels
        self.vid_indices = self._create_vid_indices(training_segment_file)
        self.len = len(self.vid_indices)

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        indices = self.vid_indices[idx]
        vid_features = [self.features[indices[seg_idx]:indices[seg_idx+1]] for seg_idx in range(len(indices)-1)]
        vid_labels = [self.labels[indices[seg_idx]] for seg_idx in range(len(indices)-1)]
        return (vid_features, vid_labels)
    
    def _create_vid_indices(self, training_segment_file):
        with open(training_segment_file, 'r') as file:
            training_segment = [[int(a) for a in line.split()] for line in file]
        vid_indices = []
        last_seg_idx = 0
        for vid in training_segment:
            vid_indices.append([seg-vid[0]+last_seg_idx for seg in vid])
            last_seg_idx = vid_indices[-1][-1]
        return vid_indices

# %%
class SegmentDataset(Dataset):
    
    def __init__(self, vid_dataset):
        self.vid_dataset = vid_dataset
        self.seg_to_vid, self.len = self._create_seg_to_vid_idx(self.vid_dataset)
    
    def _create_seg_to_vid_idx(self, vid_dataset):
        seg_to_vid = {}
        i = 0
        for vid_i, (_, labels) in enumerate(self.vid_dataset):
            for seg_i in range(len(labels)):
                seg_to_vid[i] = (vid_i, seg_i)
                i += 1
        return seg_to_vid, i

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        vid_i, seg_i = self.seg_to_vid[idx]
        return (self.vid_dataset[vid_i][0][seg_i], self.vid_dataset[vid_i][1][seg_i])

# %% [markdown]
# Split dataset

# %%
vid_dataset = VideoDataset(train_feat_tensor, train_labels_tensor, "training_segment.txt")

tot_len = len(vid_dataset)
print("Number of training video: {}".format(tot_len))

train_split_size = 0.85
lengths = [int(tot_len*train_split_size), tot_len - int(tot_len*train_split_size)]

vid_train_dataset, vid_val_dataset = torch.utils.data.random_split(vid_dataset, lengths)

seg_train_dataset = SegmentDataset(vid_train_dataset)
seg_val_dataset = SegmentDataset(vid_val_dataset)

print("Training data (video, segments): ({}, {})".format(len(vid_train_dataset), len(seg_train_dataset)))
print("Validation data (video, segments): ({}, {})".format(len(vid_val_dataset), len(seg_val_dataset)))
# Out:
# Number of training video: 1460
# Training data (video, segments): (1241, 6027)
# Validation data (video, segments): (219, 1048)

# %% [markdown]
# Define segment training routine

# %%
def seg_train_val(num_epoch, dataloader_dict, model, loss, optimizer, print_epoch=True, device=None):
    val_acc_history = []
    val_loss_history = []
    train_acc_history = []
    train_loss_history = []
    best_acc = 0.0
    best_model_weights = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epoch):
        since = time.time()
        if print_epoch:
            print("Epoch {}/{}".format(epoch+1, num_epoch))
            print("-----------")
        
        for phase in ["train", "val"]:
            if phase == "train":
                model.train()
            else :
                model.eval()
            total_loss = 0.0
            total_correct = 0.0
            for X, y, batch_len in dataloader_dict[phase]:
                if device is not None:
                    X = X.to(device)
                    y = y.to(device)
                with torch.set_grad_enabled(phase == "train"):
                    y_tilde = model(X)
                    L = loss(y_tilde, y)
                    if phase == "train":
                        optimizer.zero_grad()
                        L.backward()
                        optimizer.step()
                y_tilde_label = torch.argmax(y_tilde, dim=1)
                num_correct = torch.sum((y_tilde_label == y))
                
                total_loss += L.item() * batch_len
                total_correct += num_correct.item()
            
            epoch_loss = total_loss / len(dataloader_dict[phase].dataset)
            epoch_acc = (total_correct / len(dataloader_dict[phase].dataset)) * 100
            
            if phase == "val":
                val_loss_history.append(epoch_loss)
                val_acc_history.append(epoch_acc)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_weights = copy.deepcopy(model.state_dict())
            if phase == "train":
                train_loss_history.append(epoch_loss)
                train_acc_history.append(epoch_acc)

            if print_epoch:
                print("{} | Loss : {:.4f}  Acc : {:.2f}%".format(phase.capitalize().ljust(5), epoch_loss, epoch_acc))
        
        print("Time elapsed : {:.2f} s".format(time.time() - since))
        print()
    
    model.load_state_dict(best_model_weights)
    return model, (val_acc_history, val_loss_history, train_acc_history, train_loss_history)

# %% [markdown]
# Define segment model

# %%
class SegmentModel(nn.Module):
    def __init__(self):
        super(SegmentModel, self).__init__()
        self.dropout1 = nn.Dropout(p=0.2)
        self.num_layers = 2
        self.lstm = nn.LSTM(400, 512, batch_first=True, num_layers=self.num_layers, dropout=0.5)
        self.dropout2 = nn.Dropout(p=0.5)
        self.linear = nn.Linear(512*(2+self.num_layers), 47)
        self.padding_value = 0
    def forward(self, x):
        x_pad, lengths = pad_packed_sequence(x, batch_first=True, padding_value=self.padding_value)
        x_pad = self.dropout1(x_pad)
        x = pack_padded_sequence(x_pad, lengths, batch_first=True, enforce_sorted=False)
        
        h, (h_last, c) = self.lstm(x)
        
        h_pad, lengths = pad_packed_sequence(h, batch_first=True, padding_value=self.padding_value)
        h_avg_pool = torch.sum(h_pad, 1) / (torch.sum((h_pad != self.padding_value), 1) + 1e-5)
        h_max_pool = torch.max(h_pad, 1)[0]
        x = torch.cat((*(h_last.unbind()), h_avg_pool, h_max_pool), 1)
        
        x = self.dropout2(x)
        
        x = self.linear(x)
        return x

seg_model = SegmentModel()
for param in seg_model.parameters():
    print(param.size())
# Out:
# torch.Size([2048, 400])
# torch.Size([2048, 512])
# torch.Size([2048])
# torch.Size([2048])
# torch.Size([2048, 512])
# torch.Size([2048, 512])
# torch.Size([2048])
# torch.Size([2048])
# torch.Size([47, 2048])
# torch.Size([47])

# %% [markdown]
# Create segment DataLoader

# %%
def seg_collate(batch_data):
    features = []
    labels = []
    for feature, label in batch_data:
        features.append(feature)
        labels.append(label)
    return (pack_sequence(features, enforce_sorted=False), torch.tensor(labels), len(batch_data))

seg_train_loader = DataLoader(seg_train_dataset, batch_size=128, shuffle=True, pin_memory=True, collate_fn=seg_collate)
seg_val_loader = DataLoader(seg_val_dataset, batch_size=128, shuffle=True, pin_memory=True, collate_fn=seg_collate)

# %% [markdown]
# Start segment level training

# %%
seg_model = SegmentModel()
seg_model.to(dev)
seg_loss = nn.CrossEntropyLoss()
seg_optimizer = optim.Adam(seg_model.parameters())

seg_trained_model, seg_acc_loss = seg_train_val(100, {"train": seg_train_loader, "val": seg_val_loader}, seg_model, seg_loss, seg_optimizer, device=dev)
# Out:
# Epoch 1/100
# -----------
# Train | Loss : 3.0702  Acc : 19.11%
# Val   | Loss : 2.4339  Acc : 32.15%
# Time elapsed : 90.05 s
#
# Epoch 2/100
# -----------
# Train | Loss : 2.2363  Acc : 35.05%
# Val   | Loss : 2.0622  Acc : 39.61%
# Time elapsed : 87.74 s
#
# Epoch 3/100
# -----------
# Train | Loss : 1.8650  Acc : 43.42%
# Val   | Loss : 1.9035  Acc : 43.24%
# Time elapsed : 86.20 s
#
# Epoch 4/100
# -----------
# Train | Loss : 1.6465  Acc : 49.35%
# Val   | Loss : 1.7207  Acc : 47.72%
# Time elapsed : 90.10 s
#
# Epoch 5/100
# -----------
# Train | Loss : 1.4946  Acc : 53.38%
# Val   | Loss : 1.7275  Acc : 47.44%
# Time elapsed : 85.04 s
#
# Epoch 6/100
# -----------
# Train | Loss : 1.4070  Acc : 56.10%
# Val   | Loss : 1.4394  Acc : 54.99%
# Time elapsed : 87.82 s
#
# Epoch 7/100
# -----------
# Train | Loss : 1.2574  Acc : 59.63%
# Val   | Loss : 1.3911  Acc : 56.38%
# Time elapsed : 87.35 s
#
# Epoch 8/100
# -----------
# Train | Loss : 1.1303  Acc : 64.03%
# Val   | Loss : 1.4164  Acc : 56.29%
# Time elapsed : 85.27 s
#
# Epoch 9/100
# -----------
# Train | Loss : 1.0661  Acc : 64.95%
# Val   | Loss : 1.3126  Acc : 58.90%
# Time elapsed : 87.84 s
#
# Epoch 10/100
# -----------
# Train | Loss : 1.0030  Acc : 66.51%
# Val   | Loss : 1.2773  Acc : 58.90%
# Time elapsed : 85.87 s
#
# Epoch 11/100
# -----------
# Train | Loss : 0.9220  Acc : 69.43%
# Val   | Loss : 1.2255  Acc : 61.04%
# Time elapsed : 88.93 s
#
# Epoch 12/100
# -----------
# Train | Loss : 0.9138  Acc : 69.91%
# Val   | Loss : 1.2467  Acc : 61.04%
# Time elapsed : 87.05 s
#
# Epoch 13/100
# -----------
# Train | Loss : 0.8100  Acc : 73.63%
# Val   | Loss : 1.2347  Acc : 61.23%
# Time elapsed : 87.75 s
#
# Epoch 14/100
# -----------
# Train | Loss : 0.7886  Acc : 73.51%
# Val   | Loss : 1.2816  Acc : 61.14%
# Time elapsed : 87.47 s
#
# Epoch 15/100
# -----------
# Train | Loss : 0.7316  Acc : 75.44%
# Val   | Loss : 1.2030  Acc : 61.60%
# Time elapsed : 85.69 s
#
# Epoch 16/100
# -----------
# Train | Loss : 0.6837  Acc : 76.86%
# Val   | Loss : 1.1712  Acc : 62.63%
# Time elapsed : 87.65 s
#
# Epoch 17/100
# -----------
# Train | Loss : 0.6629  Acc : 77.96%
# Val   | Loss : 1.1889  Acc : 62.16%
# Time elapsed : 84.80 s
#
# Epoch 18/100
# -----------
# Train | Loss : 0.6396  Acc : 78.69%
# Val   | Loss : 1.2113  Acc : 63.65%
# Time elapsed : 85.36 s
#
# Epoch 19/100
# -----------
# Train | Loss : 0.5880  Acc : 80.32%
# Val   | Loss : 1.1921  Acc : 63.47%
# Time elapsed : 86.49 s
#
# Epoch 20/100
# -----------
# Train | Loss : 0.5967  Acc : 80.31%
# Val   | Loss : 1.1995  Acc : 63.37%
# Time elapsed : 85.15 s
#
# Epoch 21/100
# -----------
# Train | Loss : 0.5763  Acc : 80.72%
# Val   | Loss : 1.1563  Acc : 65.52%
# Time elapsed : 85.67 s
#
# Epoch 22/100
# -----------
# Train | Loss : 0.4917  Acc : 83.07%
# Val   | Loss : 1.1760  Acc : 64.59%
# Time elapsed : 87.56 s
#
# Epoch 23/100
# -----------
# Train | Loss : 0.5218  Acc : 82.06%
# Val   | Loss : 1.2794  Acc : 61.04%
# Time elapsed : 85.42 s
#
# Epoch 24/100
# -----------
# Train | Loss : 0.4787  Acc : 84.11%
# Val   | Loss : 1.1808  Acc : 63.47%
# Time elapsed : 88.49 s
#
# Epoch 25/100
# -----------
# Train | Loss : 0.3956  Acc : 86.79%
# Val   | Loss : 1.2255  Acc : 63.65%
# Time elapsed : 86.39 s
#
# Epoch 26/100
# -----------
# Train | Loss : 0.4145  Acc : 86.02%
# Val   | Loss : 1.2391  Acc : 64.12%
# Time elapsed : 87.20 s
#
# Epoch 27/100
# -----------
# Train | Loss : 0.4271  Acc : 85.19%
# Val   | Loss : 1.1475  Acc : 66.82%
# Time elapsed : 88.78 s
#
# Epoch 28/100
# -----------
# Train | Loss : 0.3955  Acc : 87.04%
# Val   | Loss : 1.2158  Acc : 63.84%
# Time elapsed : 85.29 s
#
# Epoch 29/100
# -----------
# Train | Loss : 0.3170  Acc : 89.57%
# Val   | Loss : 1.1644  Acc : 66.64%
# Time elapsed : 87.26 s
#
# Epoch 30/100
# -----------
# Train | Loss : 0.2866  Acc : 90.25%
# Val   | Loss : 1.1078  Acc : 69.52%
# Time elapsed : 87.02 s
#
# Epoch 31/100
# -----------
# Train | Loss : 0.3191  Acc : 89.09%
# Val   | Loss : 1.1583  Acc : 66.17%
# Time elapsed : 88.90 s
#
# Epoch 32/100
# -----------
# Train | Loss : 0.3066  Acc : 89.75%
# Val   | Loss : 1.2025  Acc : 65.52%
# Time elapsed : 86.86 s
#
# Epoch 33/100
# -----------
# Train | Loss : 0.3004  Acc : 89.95%
# Val   | Loss : 1.1234  Acc : 67.66%
# Time elapsed : 87.51 s
#
# Epoch 34/100
# -----------
# Train | Loss : 0.2991  Acc : 89.75%
# Val   | Loss : 1.1079  Acc : 68.69%
# Time elapsed : 87.88 s
#
# Epoch 35/100
# -----------
# Train | Loss : 0.2885  Acc : 90.05%
# Val   | Loss : 1.2721  Acc : 64.12%
# Time elapsed : 85.44 s
#
# Epoch 36/100
# -----------
# Train | Loss : 0.2305  Acc : 92.75%
# Val   | Loss : 1.1122  Acc : 67.85%
# Time elapsed : 87.11 s
#
# Epoch 37/100
# -----------
# Train | Loss : 0.1999  Acc : 93.34%
# Val   | Loss : 1.2680  Acc : 65.70%
# Time elapsed : 86.43 s
#
# Epoch 38/100
# -----------
# Train | Loss : 0.2741  Acc : 90.52%
# Val   | Loss : 1.2196  Acc : 64.40%
# Time elapsed : 87.76 s
#
# Epoch 39/100
# -----------
# Train | Loss : 0.2855  Acc : 90.49%
# Val   | Loss : 1.1960  Acc : 65.24%
# Time elapsed : 87.66 s
#
# Epoch 40/100
# -----------
# Train | Loss : 0.2117  Acc : 92.97%
# Val   | Loss : 1.1423  Acc : 69.15%
# Time elapsed : 85.87 s
#
# Epoch 41/100
# -----------
# Train | Loss : 0.1701  Acc : 94.25%
# Val   | Loss : 1.0460  Acc : 71.02%
# Time elapsed : 85.77 s
#
# Epoch 42/100
# -----------
# Train | Loss : 0.2187  Acc : 92.77%
# Val   | Loss : 1.1324  Acc : 67.85%
# Time elapsed : 85.04 s
#
# Epoch 43/100
# -----------
# Train | Loss : 0.2209  Acc : 92.59%
# Val   | Loss : 1.1994  Acc : 67.57%
# Time elapsed : 86.63 s
#
# Epoch 44/100
# -----------
# Train | Loss : 0.1785  Acc : 94.45%
# Val   | Loss : 1.2710  Acc : 65.89%
# Time elapsed : 86.38 s
#
# Epoch 45/100
# -----------
# Train | Loss : 0.1710  Acc : 94.44%
# Val   | Loss : 1.1577  Acc : 69.52%
# Time elapsed : 85.52 s
#
# Epoch 46/100
# -----------
# Train | Loss : 0.1375  Acc : 95.55%
# Val   | Loss : 1.1196  Acc : 69.52%
# Time elapsed : 85.91 s
#
# Epoch 47/100
# -----------
# Train | Loss : 0.1341  Acc : 95.98%
# Val   | Loss : 1.1470  Acc : 70.64%
# Time elapsed : 83.52 s
#
# Epoch 48/100
# -----------
# Train | Loss : 0.1106  Acc : 96.75%
# Val   | Loss : 1.1676  Acc : 68.59%
# Time elapsed : 87.96 s
#
# Epoch 49/100
# -----------
# Train | Loss : 0.1296  Acc : 95.88%
# Val   | Loss : 1.1911  Acc : 68.97%
# Time elapsed : 86.86 s
#
# Epoch 50/100
# -----------
# Train | Loss : 0.1402  Acc : 95.50%
# Val   | Loss : 1.2549  Acc : 67.47%
# Time elapsed : 88.58 s
#
# Epoch 51/100
# -----------
# Train | Loss : 0.2172  Acc : 92.77%
# Val   | Loss : 1.3482  Acc : 66.73%
# Time elapsed : 87.82 s
#
# Epoch 52/100
# -----------
# Train | Loss : 0.2411  Acc : 91.79%
# Val   | Loss : 1.1733  Acc : 67.66%
# Time elapsed : 84.79 s
#
# Epoch 53/100
# -----------
# Train | Loss : 0.1736  Acc : 94.27%
# Val   | Loss : 1.3001  Acc : 66.17%
# Time elapsed : 84.21 s
#
# Epoch 54/100
# -----------
# Train | Loss : 0.1877  Acc : 93.79%
# Val   | Loss : 1.2210  Acc : 68.87%
# Time elapsed : 84.80 s
#
# Epoch 55/100
# -----------
# Train | Loss : 0.1462  Acc : 95.32%
# Val   | Loss : 1.2299  Acc : 68.41%
# Time elapsed : 85.17 s
#
# Epoch 56/100
# -----------
# Train | Loss : 0.1663  Acc : 94.55%
# Val   | Loss : 1.1926  Acc : 69.90%
# Time elapsed : 85.36 s
#
# Epoch 57/100
# -----------
# Train | Loss : 0.1968  Acc : 93.50%
# Val   | Loss : 1.4331  Acc : 65.05%
# Time elapsed : 85.95 s
#
# Epoch 58/100
# -----------
# Train | Loss : 0.2359  Acc : 91.99%
# Val   | Loss : 1.1875  Acc : 69.99%
# Time elapsed : 85.50 s
#
# Epoch 59/100
# -----------
# Train | Loss : 0.1659  Acc : 94.54%
# Val   | Loss : 1.1565  Acc : 71.02%
# Time elapsed : 83.97 s
#
# Epoch 60/100
# -----------
# Train | Loss : 0.1302  Acc : 95.70%
# Val   | Loss : 1.1769  Acc : 69.80%
# Time elapsed : 88.67 s
#
# Epoch 61/100
# -----------
# Train | Loss : 0.1007  Acc : 96.92%
# Val   | Loss : 1.1381  Acc : 71.39%
# Time elapsed : 86.60 s
#
# Epoch 62/100
# -----------
# Train | Loss : 0.0971  Acc : 96.93%
# Val   | Loss : 1.1939  Acc : 70.36%
# Time elapsed : 87.25 s
#
# Epoch 63/100
# -----------
# Train | Loss : 0.1313  Acc : 95.80%
# Val   | Loss : 1.4616  Acc : 66.26%
# Time elapsed : 85.92 s
#
# Epoch 64/100
# -----------
# Train | Loss : 0.2164  Acc : 92.60%
# Val   | Loss : 1.3858  Acc : 65.05%
# Time elapsed : 86.52 s
#
# Epoch 65/100
# -----------
# Train | Loss : 0.2312  Acc : 92.29%
# Val   | Loss : 1.2260  Acc : 70.36%
# Time elapsed : 89.10 s
#
# Epoch 66/100
# -----------
# Train | Loss : 0.1723  Acc : 94.32%
# Val   | Loss : 1.3101  Acc : 68.31%
# Time elapsed : 87.04 s
#
# Epoch 67/100
# -----------
# Train | Loss : 0.1587  Acc : 94.50%
# Val   | Loss : 1.2089  Acc : 69.80%
# Time elapsed : 86.65 s
#
# Epoch 68/100
# -----------
# Train | Loss : 0.1443  Acc : 95.28%
# Val   | Loss : 1.3848  Acc : 67.19%
# Time elapsed : 87.72 s
#
# Epoch 69/100
# -----------
# Train | Loss : 0.1583  Acc : 95.12%
# Val   | Loss : 1.2061  Acc : 70.92%
# Time elapsed : 87.51 s
#
# Epoch 70/100
# -----------
# Train | Loss : 0.1252  Acc : 95.98%
# Val   | Loss : 1.2661  Acc : 68.78%
# Time elapsed : 85.70 s
#
# Epoch 71/100
# -----------
# Train | Loss : 0.1083  Acc : 96.77%
# Val   | Loss : 1.1461  Acc : 72.13%
# Time elapsed : 86.83 s
#
# Epoch 72/100
# -----------
# Train | Loss : 0.0768  Acc : 97.78%
# Val   | Loss : 1.1845  Acc : 71.20%
# Time elapsed : 86.20 s
#
# Epoch 73/100
# -----------
# Train | Loss : 0.0571  Acc : 98.42%
# Val   | Loss : 1.1980  Acc : 72.41%
# Time elapsed : 88.10 s
#
# Epoch 74/100
# -----------
# Train | Loss : 0.0584  Acc : 98.12%
# Val   | Loss : 1.3014  Acc : 69.71%
# Time elapsed : 87.18 s
#
# Epoch 75/100
# -----------
# Train | Loss : 0.0807  Acc : 97.47%
# Val   | Loss : 1.4889  Acc : 66.64%
# Time elapsed : 85.67 s
#
# Epoch 76/100
# -----------
# Train | Loss : 0.0998  Acc : 96.80%
# Val   | Loss : 1.2769  Acc : 69.52%
# Time elapsed : 84.45 s
#
# Epoch 77/100
# -----------
# Train | Loss : 0.0665  Acc : 97.97%
# Val   | Loss : 1.2090  Acc : 72.97%
# Time elapsed : 86.32 s
#
# Epoch 78/100
# -----------
# Train | Loss : 0.0607  Acc : 98.25%
# Val   | Loss : 1.2991  Acc : 71.76%
# Time elapsed : 87.42 s
#
# Epoch 79/100
# -----------
# Train | Loss : 0.0656  Acc : 97.95%
# Val   | Loss : 1.3132  Acc : 69.99%
# Time elapsed : 85.87 s
#
# Epoch 80/100
# -----------
# Train | Loss : 0.0570  Acc : 98.17%
# Val   | Loss : 1.2913  Acc : 71.20%
# Time elapsed : 88.37 s
#
# Epoch 81/100
# -----------
# Train | Loss : 0.0380  Acc : 99.02%
# Val   | Loss : 1.2448  Acc : 73.35%
# Time elapsed : 87.83 s
#
# Epoch 82/100
# -----------
# Train | Loss : 0.0385  Acc : 98.92%
# Val   | Loss : 1.3917  Acc : 70.92%
# Time elapsed : 84.84 s
#
# Epoch 83/100
# -----------
# Train | Loss : 0.0451  Acc : 98.85%
# Val   | Loss : 1.2390  Acc : 72.97%
# Time elapsed : 85.25 s
#
# Epoch 84/100
# -----------
# Train | Loss : 0.0390  Acc : 98.83%
# Val   | Loss : 1.3694  Acc : 71.02%
# Time elapsed : 87.22 s
#
# Epoch 85/100
# -----------
# Train | Loss : 0.0697  Acc : 97.80%
# Val   | Loss : 1.3674  Acc : 70.36%
# Time elapsed : 85.50 s
#
# Epoch 86/100
# -----------
# Train | Loss : 0.0892  Acc : 96.95%
# Val   | Loss : 1.4220  Acc : 68.22%
# Time elapsed : 87.96 s
#
# Epoch 87/100
# -----------
# Train | Loss : 0.1033  Acc : 96.70%
# Val   | Loss : 1.3741  Acc : 71.20%
# Time elapsed : 88.29 s
#
# Epoch 88/100
# -----------
# Train | Loss : 0.1147  Acc : 96.25%
# Val   | Loss : 1.6032  Acc : 64.68%
# Time elapsed : 87.35 s
#
# Epoch 89/100
# -----------
# Train | Loss : 0.1748  Acc : 94.49%
# Val   | Loss : 1.3650  Acc : 68.59%
# Time elapsed : 85.65 s
#
# Epoch 90/100
# -----------
# Train | Loss : 0.1923  Acc : 93.37%
# Val   | Loss : 1.5070  Acc : 65.80%
# Time elapsed : 85.54 s
#
# Epoch 91/100
# -----------
# Train | Loss : 0.1859  Acc : 93.90%
# Val   | Loss : 1.3842  Acc : 68.78%
# Time elapsed : 87.46 s
#
# Epoch 92/100
# -----------
# Train | Loss : 0.1326  Acc : 95.57%
# Val   | Loss : 1.2490  Acc : 70.46%
# Time elapsed : 89.19 s
#
# Epoch 93/100
# -----------
# Train | Loss : 0.1013  Acc : 96.65%
# Val   | Loss : 1.3628  Acc : 69.71%
# Time elapsed : 85.86 s
#
# Epoch 94/100
# -----------
# Train | Loss : 0.0750  Acc : 97.65%
# Val   | Loss : 1.3601  Acc : 70.08%
# Time elapsed : 85.08 s
#
# Epoch 95/100
# -----------
# Train | Loss : 0.0765  Acc : 97.47%
# Val   | Loss : 2.0478  Acc : 61.32%
# Time elapsed : 85.48 s
#
# Epoch 96/100
# -----------
# Train | Loss : 0.4889  Acc : 85.22%
# Val   | Loss : 1.4107  Acc : 66.36%
# Time elapsed : 87.12 s
#
# Epoch 97/100
# -----------
# Train | Loss : 0.2317  Acc : 92.19%
# Val   | Loss : 1.4690  Acc : 66.54%
# Time elapsed : 87.82 s
#
# Epoch 98/100
# -----------
# Train | Loss : 0.1938  Acc : 93.59%
# Val   | Loss : 1.4751  Acc : 65.61%
# Time elapsed : 85.55 s
#
# Epoch 99/100
# -----------
# Train | Loss : 0.1604  Acc : 94.94%
# Val   | Loss : 1.3109  Acc : 68.87%
# Time elapsed : 84.93 s
#
# Epoch 100/100
# -----------
# Train | Loss : 0.1071  Acc : 96.65%
# Val   | Loss : 1.2901  Acc : 70.55%
# Time elapsed : 87.56 s

# %%
def plot_train_val(acc_loss):
    plt.figure(figsize=(18, 5))
    epoch_num = range(1, len(acc_loss[0])+1)
    plt.subplot(1, 2, 1)
    plt.title('Accuracy')
    plt.ylim(0, 110)
    plt.grid(True)
    plt.plot(epoch_num, acc_loss[2], color="blue")
    plt.plot(epoch_num, acc_loss[0], color="red")
    blue_patch = mpatches.Patch(color='blue', label='Training')
    red_patch = mpatches.Patch(color='red', label='Validation')
    plt.legend(handles=[blue_patch, red_patch])
    plt.subplot(1, 2, 2)
    plt.title('Loss')
    plt.ylim(0, 3)
    plt.grid(True)
    plt.plot(epoch_num, acc_loss[3], color="blue")
    plt.plot(epoch_num, acc_loss[1], color="red")
    blue_patch = mpatches.Patch(color='blue', label='Training')
    red_patch = mpatches.Patch(color='red', label='Validation')
    plt.legend(handles=[blue_patch, red_patch])

# %%
plot_train_val(seg_acc_loss)

# %%
print(max(seg_acc_loss[0]))
# Out:
# 73.3457595526561

# %%
def set_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
set_lr(seg_optimizer, 0.0001)
seg_trained_model_tuning, seg_acc_loss_tuning = seg_train_val(50, {"train": seg_train_loader, "val": seg_val_loader}, seg_trained_model, seg_loss, seg_optimizer, device=dev)
# Out:
# Epoch 1/50
# -----------
# Train | Loss : 0.0264  Acc : 99.27%
# Val   | Loss : 1.2463  Acc : 73.35%
# Time elapsed : 88.17 s
#
# Epoch 2/50
# -----------
# Train | Loss : 0.0190  Acc : 99.65%
# Val   | Loss : 1.2550  Acc : 73.25%
# Time elapsed : 88.86 s
#
# Epoch 3/50
# -----------
# Train | Loss : 0.0207  Acc : 99.53%
# Val   | Loss : 1.2419  Acc : 73.90%
# Time elapsed : 86.96 s
#
# Epoch 4/50
# -----------
# Train | Loss : 0.0169  Acc : 99.67%
# Val   | Loss : 1.2564  Acc : 73.72%
# Time elapsed : 86.03 s
#
# Epoch 5/50
# -----------
# Train | Loss : 0.0151  Acc : 99.82%
# Val   | Loss : 1.2544  Acc : 73.90%
# Time elapsed : 87.01 s
#
# Epoch 6/50
# -----------
# Train | Loss : 0.0137  Acc : 99.85%
# Val   | Loss : 1.2547  Acc : 74.00%
# Time elapsed : 87.23 s
#
# Epoch 7/50
# -----------
# Train | Loss : 0.0147  Acc : 99.78%
# Val   | Loss : 1.2559  Acc : 74.37%
# Time elapsed : 86.66 s
#
# Epoch 8/50
# -----------
# Train | Loss : 0.0123  Acc : 99.85%
# Val   | Loss : 1.2502  Acc : 73.72%
# Time elapsed : 84.08 s
#
# Epoch 9/50
# -----------
# Train | Loss : 0.0130  Acc : 99.83%
# Val   | Loss : 1.2457  Acc : 73.81%
# Time elapsed : 88.56 s
#
# Epoch 10/50
# -----------
# Train | Loss : 0.0108  Acc : 99.85%
# Val   | Loss : 1.2500  Acc : 74.28%
# Time elapsed : 84.50 s
#
# Epoch 11/50
# -----------
# Train | Loss : 0.0118  Acc : 99.88%
# Val   | Loss : 1.2668  Acc : 73.72%
# Time elapsed : 86.48 s
#
# Epoch 12/50
# -----------
# Train | Loss : 0.0102  Acc : 99.90%
# Val   | Loss : 1.2640  Acc : 73.81%
# Time elapsed : 88.09 s
#
# Epoch 13/50
# -----------
# Train | Loss : 0.0108  Acc : 99.83%
# Val   | Loss : 1.2566  Acc : 74.09%
# Time elapsed : 88.03 s
#
# Epoch 14/50
# -----------
# Train | Loss : 0.0108  Acc : 99.83%
# Val   | Loss : 1.2777  Acc : 73.44%
# Time elapsed : 88.12 s
#
# Epoch 15/50
# -----------
# Train | Loss : 0.0112  Acc : 99.87%
# Val   | Loss : 1.2702  Acc : 74.46%
# Time elapsed : 86.05 s
#
# Epoch 16/50
# -----------
# Train | Loss : 0.0100  Acc : 99.87%
# Val   | Loss : 1.2635  Acc : 74.37%
# Time elapsed : 88.54 s
#
# Epoch 17/50
# -----------
# Train | Loss : 0.0093  Acc : 99.88%
# Val   | Loss : 1.2673  Acc : 74.18%
# Time elapsed : 85.37 s
#
# Epoch 18/50
# -----------
# Train | Loss : 0.0091  Acc : 99.90%
# Val   | Loss : 1.2866  Acc : 73.63%
# Time elapsed : 84.82 s
#
# Epoch 19/50
# -----------
# Train | Loss : 0.0098  Acc : 99.83%
# Val   | Loss : 1.2900  Acc : 73.53%
# Time elapsed : 86.56 s
#
# Epoch 20/50
# -----------
# Train | Loss : 0.0082  Acc : 99.95%
# Val   | Loss : 1.2987  Acc : 73.44%
# Time elapsed : 86.30 s
#
# Epoch 21/50
# -----------
# Train | Loss : 0.0086  Acc : 99.88%
# Val   | Loss : 1.2879  Acc : 73.81%
# Time elapsed : 86.77 s
#
# Epoch 22/50
# -----------
# Train | Loss : 0.0084  Acc : 99.88%
# Val   | Loss : 1.2881  Acc : 73.81%
# Time elapsed : 86.68 s
#
# Epoch 23/50
# -----------
# Train | Loss : 0.0088  Acc : 99.88%
# Val   | Loss : 1.2798  Acc : 73.63%
# Time elapsed : 84.67 s
#
# Epoch 24/50
# -----------
# Train | Loss : 0.0078  Acc : 99.98%
# Val   | Loss : 1.2774  Acc : 73.63%
# Time elapsed : 85.04 s
#
# Epoch 25/50
# -----------
# Train | Loss : 0.0079  Acc : 99.92%
# Val   | Loss : 1.2770  Acc : 73.90%
# Time elapsed : 85.00 s
#
# Epoch 26/50
# -----------
# Train | Loss : 0.0076  Acc : 99.92%
# Val   | Loss : 1.2852  Acc : 74.37%
# Time elapsed : 86.58 s
#
# Epoch 27/50
# -----------
# Train | Loss : 0.0065  Acc : 99.97%
# Val   | Loss : 1.2833  Acc : 74.37%
# Time elapsed : 84.87 s
#
# Epoch 28/50
# -----------
# Train | Loss : 0.0073  Acc : 99.85%
# Val   | Loss : 1.2762  Acc : 74.28%
# Time elapsed : 87.29 s
#
# Epoch 29/50
# -----------
# Train | Loss : 0.0076  Acc : 99.90%
# Val   | Loss : 1.2847  Acc : 74.37%
# Time elapsed : 83.97 s
#
# Epoch 30/50
# -----------
# Train | Loss : 0.0057  Acc : 99.97%
# Val   | Loss : 1.2888  Acc : 73.81%
# Time elapsed : 85.72 s
#
# Epoch 31/50
# -----------
# Train | Loss : 0.0057  Acc : 100.00%
# Val   | Loss : 1.2908  Acc : 74.28%
# Time elapsed : 84.35 s
#
# Epoch 32/50
# -----------
# Train | Loss : 0.0066  Acc : 99.93%
# Val   | Loss : 1.2837  Acc : 74.56%
# Time elapsed : 86.86 s
#
# Epoch 33/50
# -----------
# Train | Loss : 0.0055  Acc : 99.97%
# Val   | Loss : 1.2914  Acc : 74.18%
# Time elapsed : 88.30 s
#
# Epoch 34/50
# -----------
# Train | Loss : 0.0066  Acc : 99.90%
# Val   | Loss : 1.2926  Acc : 73.90%
# Time elapsed : 87.64 s
#
# Epoch 35/50
# -----------
# Train | Loss : 0.0056  Acc : 99.95%
# Val   | Loss : 1.2913  Acc : 74.18%
# Time elapsed : 88.80 s
#
# Epoch 36/50
# -----------
# Train | Loss : 0.0060  Acc : 99.90%
# Val   | Loss : 1.3070  Acc : 74.00%
# Time elapsed : 85.82 s
#
# Epoch 37/50
# -----------
# Train | Loss : 0.0059  Acc : 99.93%
# Val   | Loss : 1.3160  Acc : 74.00%
# Time elapsed : 86.35 s
#
# Epoch 38/50
# -----------
# Train | Loss : 0.0064  Acc : 99.95%
# Val   | Loss : 1.3347  Acc : 73.72%
# Time elapsed : 84.61 s
#
# Epoch 39/50
# -----------
# Train | Loss : 0.0050  Acc : 99.98%
# Val   | Loss : 1.3232  Acc : 74.18%
# Time elapsed : 85.03 s
#
# Epoch 40/50
# -----------
# Train | Loss : 0.0050  Acc : 99.93%
# Val   | Loss : 1.3281  Acc : 74.00%
# Time elapsed : 84.25 s
#
# Epoch 41/50
# -----------
# Train | Loss : 0.0051  Acc : 99.95%
# Val   | Loss : 1.3164  Acc : 74.18%
# Time elapsed : 86.83 s
#
# Epoch 42/50
# -----------
# Train | Loss : 0.0049  Acc : 99.98%
# Val   | Loss : 1.3226  Acc : 74.74%
# Time elapsed : 84.76 s
#
# Epoch 43/50
# -----------
# Train | Loss : 0.0043  Acc : 99.97%
# Val   | Loss : 1.3185  Acc : 74.46%
# Time elapsed : 86.15 s
#
# Epoch 44/50
# -----------
# Train | Loss : 0.0048  Acc : 99.98%
# Val   | Loss : 1.3362  Acc : 73.90%
# Time elapsed : 86.53 s
#
# Epoch 45/50
# -----------
# Train | Loss : 0.0048  Acc : 99.97%
# Val   | Loss : 1.3373  Acc : 74.28%
# Time elapsed : 86.03 s
#
# Epoch 46/50
# -----------
# Train | Loss : 0.0056  Acc : 99.90%
# Val   | Loss : 1.3483  Acc : 74.18%
# Time elapsed : 86.38 s
#
# Epoch 47/50
# -----------
# Train | Loss : 0.0057  Acc : 99.95%
# Val   | Loss : 1.3413  Acc : 73.90%
# Time elapsed : 85.52 s
#
# Epoch 48/50
# -----------
# Train | Loss : 0.0045  Acc : 99.98%
# Val   | Loss : 1.3505  Acc : 73.81%
# Time elapsed : 87.64 s
#
# Epoch 49/50
# -----------
# Train | Loss : 0.0054  Acc : 99.93%
# Val   | Loss : 1.3283  Acc : 74.00%
# Time elapsed : 85.20 s
#
# Epoch 50/50
# -----------
# Train | Loss : 0.0043  Acc : 99.97%
# Val   | Loss : 1.3416  Acc : 74.18%
# Time elapsed : 85.53 s

# %%
print(max(seg_acc_loss_tuning[0]))
# Out:
# 74.74370922646784

# %% [markdown]
# Save segment model

# %%
# model_filename = "lstm_val77_train99_2layers_512hidden.model"
timestamp = time.strftime("%y-%m-%d_%H:%M:%S", time.localtime())
segment_model_filename = timestamp + ".segment.model"
seeds_filename = timestamp + ".seeds"
with open(segment_model_filename, 'wb') as file:
    pickle.dump(seg_trained_model_tuning, file)
with open(seeds_filename, 'wb') as file:
    print("Torch seed: {}".format(torch_seed))
    pickle.dump((numpy_seed, torch_seed), file)
# with open(segment_model_filename, 'rb') as file:
#         seg_trained_model_tuning = pickle.load(file)
# Out:
# Torch seed: 4003546067702545403

# %% [markdown]
# Define video model

# %%
class VideoModel(nn.Module):
    def __init__(self, seg_model):
        super(VideoModel, self).__init__()
        
        self.seg_model = seg_model
        self.disable_parameters_grad(self.seg_model)
        
        self.num_layers = 2
        self.lstm = nn.LSTM(47, 512, batch_first=True, num_layers=self.num_layers, dropout=0.5)
        self.dropout = nn.Dropout(p=0.5)
        self.linear = nn.Linear(512, 47)
        self.padding_value = 0
        
    def forward(self, x, x_vid_len):
        y_flatten_seg = self.seg_model(x)
        
        y_seg = []
        last_i = 0
        for l in x_vid_len:
            y_seg.append(y_flatten_seg[last_i:last_i+l])
            last_i += l
        y_seg_seq = pack_sequence(y_seg, enforce_sorted=False)
        y_vid, _ = self.lstm(y_seg_seq)
        y_vid_pad, y_vid_lengths = pad_packed_sequence(y_vid, batch_first=True, padding_value=self.padding_value)
        y_vid_pad = self.dropout(y_vid_pad)
        y_vid_pad = self.linear(y_vid_pad)
        y_flatten_vid = torch.cat(tuple(vid[0:y_vid_lengths[i]] for i, vid in enumerate(y_vid_pad)))
        
        return y_flatten_vid
    
    def disable_parameters_grad(self, model):
        for param in model.parameters():
            param.requires_grad = False


vid_model = VideoModel(seg_trained_model_tuning)
for param in vid_model.parameters():
    print(param.size(), param.requires_grad)
# Out:
# torch.Size([2048, 400]) False
# torch.Size([2048, 512]) False
# torch.Size([2048]) False
# torch.Size([2048]) False
# torch.Size([2048, 512]) False
# torch.Size([2048, 512]) False
# torch.Size([2048]) False
# torch.Size([2048]) False
# torch.Size([47, 2048]) False
# torch.Size([47]) False
# torch.Size([2048, 47]) True
# torch.Size([2048, 512]) True
# torch.Size([2048]) True
# torch.Size([2048]) True
# torch.Size([2048, 512]) True
# torch.Size([2048, 512]) True
# torch.Size([2048]) True
# torch.Size([2048]) True
# torch.Size([47, 512]) True
# torch.Size([47]) True

# %% [markdown]
# Create video DataLoader

# %%
def vid_collate(batch_data):
    features = []
    labels = []
    vid_len = []
    for feature, label in batch_data:
        features.extend(feature)
        labels.extend(label)
        vid_len.append(len(feature))
    return (pack_sequence(features, enforce_sorted=False), torch.tensor(vid_len), torch.tensor(labels), len(batch_data))

vid_train_loader = DataLoader(vid_train_dataset, batch_size=4, shuffle=True, pin_memory=True, collate_fn=vid_collate)
vid_val_loader = DataLoader(vid_val_dataset, batch_size=4, shuffle=True, pin_memory=True, collate_fn=vid_collate)

# %% [markdown]
# Define video training routine

# %%
def vid_train_val(num_epoch, dataloader_dict, seg_count_dict, model, loss, optimizer, print_epoch=True, device=None):
    val_acc_history = []
    val_loss_history = []
    train_acc_history = []
    train_loss_history = []
    best_acc = 0.0
    best_model_weights = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epoch):
        since = time.time()
        if print_epoch:
            print("Epoch {}/{}".format(epoch+1, num_epoch))
            print("-----------")
        
        for phase in ["train", "val"]:
            if phase == "train":
                model.train()
            else :
                model.eval()
            total_loss = 0.0
            total_correct = 0.0
            for X, X_vid_len, y, _ in dataloader_dict[phase]:
                if device is not None:
                    X = X.to(device)
                    X_vid_len = X_vid_len.to(device)
                    y = y.to(device)
                with torch.set_grad_enabled(phase == "train"):
                    y_tilde = model(X, X_vid_len)
                    L = loss(y_tilde, y)
                    if phase == "train":
                        optimizer.zero_grad()
                        L.backward()
                        optimizer.step()
                y_tilde_label = torch.argmax(y_tilde, dim=1)
                num_correct = torch.sum((y_tilde_label == y))
                
                total_loss += L.item() * torch.sum(X_vid_len)
                total_correct += num_correct.item()
                
            epoch_loss = total_loss / seg_count_dict[phase]
            epoch_acc = (total_correct / seg_count_dict[phase]) * 100
            
            if phase == "val":
                val_loss_history.append(epoch_loss)
                val_acc_history.append(epoch_acc)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_weights = copy.deepcopy(model.state_dict())
            if phase == "train":
                train_loss_history.append(epoch_loss)
                train_acc_history.append(epoch_acc)

            if print_epoch:
                print("{} | Loss : {:.4f}  Acc : {:.2f}%".format(phase.capitalize().ljust(5), epoch_loss, epoch_acc))
        
        print("Time elapsed : {:.2f} s".format(time.time() - since))
        print()
    
    model.load_state_dict(best_model_weights)
    return model, (val_acc_history, val_loss_history, train_acc_history, train_loss_history)

# %% [markdown]
# Start video level training

# %%
vid_model = VideoModel(seg_trained_model_tuning)
vid_model.to(dev)
vid_loss = nn.CrossEntropyLoss()
vid_optimizer = optim.Adam(vid_model.parameters())

vid_trained_model, vid_acc_loss = vid_train_val(25, {"train": vid_train_loader, "val": vid_val_loader}, {"train": len(seg_train_dataset), "val": len(seg_val_dataset)}, vid_model, vid_loss, vid_optimizer, device=dev)
# Out:
# Epoch 1/25
# -----------
# Train | Loss : 1.0601  Acc : 72.33%
# Val   | Loss : 0.6905  Acc : 79.50%
# Time elapsed : 68.38 s
#
# Epoch 2/25
# -----------
# Train | Loss : 0.1656  Acc : 95.68%
# Val   | Loss : 0.7088  Acc : 80.52%
# Time elapsed : 69.38 s
#
# Epoch 3/25
# -----------
# Train | Loss : 0.0989  Acc : 97.30%
# Val   | Loss : 0.6696  Acc : 82.76%
# Time elapsed : 69.55 s
#
# Epoch 4/25
# -----------
# Train | Loss : 0.0834  Acc : 97.63%
# Val   | Loss : 0.6308  Acc : 82.85%
# Time elapsed : 68.39 s
#
# Epoch 5/25
# -----------
# Train | Loss : 0.0615  Acc : 98.25%
# Val   | Loss : 0.6281  Acc : 85.18%
# Time elapsed : 68.17 s
#
# Epoch 6/25
# -----------
# Train | Loss : 0.0507  Acc : 98.50%
# Val   | Loss : 0.6835  Acc : 83.50%
# Time elapsed : 68.54 s
#
# Epoch 7/25
# -----------
# Train | Loss : 0.0481  Acc : 98.53%
# Val   | Loss : 0.7378  Acc : 82.76%
# Time elapsed : 68.92 s
#
# Epoch 8/25
# -----------
# Train | Loss : 0.0519  Acc : 98.32%
# Val   | Loss : 0.6804  Acc : 85.09%
# Time elapsed : 68.54 s
#
# Epoch 9/25
# -----------
# Train | Loss : 0.0489  Acc : 98.63%
# Val   | Loss : 0.6882  Acc : 84.44%
# Time elapsed : 69.30 s
#
# Epoch 10/25
# -----------
# Train | Loss : 0.0469  Acc : 98.50%
# Val   | Loss : 0.6796  Acc : 84.44%
# Time elapsed : 68.91 s
#
# Epoch 11/25
# -----------
# Train | Loss : 0.0404  Acc : 98.90%
# Val   | Loss : 0.7273  Acc : 84.44%
# Time elapsed : 69.71 s
#
# Epoch 12/25
# -----------
# Train | Loss : 0.0438  Acc : 98.62%
# Val   | Loss : 0.7289  Acc : 85.18%
# Time elapsed : 69.01 s
#
# Epoch 13/25
# -----------
# Train | Loss : 0.0404  Acc : 98.67%
# Val   | Loss : 0.7017  Acc : 85.46%
# Time elapsed : 67.61 s
#
# Epoch 14/25
# -----------
# Train | Loss : 0.0556  Acc : 98.23%
# Val   | Loss : 0.7676  Acc : 84.25%
# Time elapsed : 68.84 s
#
# Epoch 15/25
# -----------
# Train | Loss : 0.0581  Acc : 98.37%
# Val   | Loss : 0.6872  Acc : 85.27%
# Time elapsed : 69.31 s
#
# Epoch 16/25
# -----------
# Train | Loss : 0.0323  Acc : 98.95%
# Val   | Loss : 0.7421  Acc : 84.81%
# Time elapsed : 67.93 s
#
# Epoch 17/25
# -----------
# Train | Loss : 0.0287  Acc : 99.05%
# Val   | Loss : 0.7603  Acc : 84.34%
# Time elapsed : 68.47 s
#
# Epoch 18/25
# -----------
# Train | Loss : 0.0411  Acc : 98.75%
# Val   | Loss : 0.7309  Acc : 85.55%
# Time elapsed : 68.80 s
#
# Epoch 19/25
# -----------
# Train | Loss : 0.0317  Acc : 98.85%
# Val   | Loss : 0.8487  Acc : 82.95%
# Time elapsed : 69.07 s
#
# Epoch 20/25
# -----------
# Train | Loss : 0.0457  Acc : 98.48%
# Val   | Loss : 0.7761  Acc : 85.00%
# Time elapsed : 68.25 s
#
# Epoch 21/25
# -----------
# Train | Loss : 0.0364  Acc : 98.82%
# Val   | Loss : 0.8176  Acc : 85.18%
# Time elapsed : 68.42 s
#
# Epoch 22/25
# -----------
# Train | Loss : 0.0362  Acc : 98.98%
# Val   | Loss : 0.7732  Acc : 85.37%
# Time elapsed : 68.06 s
#
# Epoch 23/25
# -----------
# Train | Loss : 0.0298  Acc : 99.10%
# Val   | Loss : 0.7604  Acc : 85.93%
# Time elapsed : 67.72 s
#
# Epoch 24/25
# -----------
# Train | Loss : 0.0224  Acc : 99.28%
# Val   | Loss : 0.8030  Acc : 85.09%
# Time elapsed : 67.82 s
#
# Epoch 25/25
# -----------
# Train | Loss : 0.0308  Acc : 99.05%
# Val   | Loss : 0.7512  Acc : 86.58%
# Time elapsed : 66.75 s

# %%
plot_train_val(vid_acc_loss)

# %%
print(max(vid_acc_loss[0]))
# Out:
# 86.57968313140726

# %%
set_lr(vid_optimizer, 0.0001)
vid_trained_model_tuning, vid_acc_loss_tuning = vid_train_val(10, {"train": vid_train_loader, "val": vid_val_loader}, {"train": len(seg_train_dataset), "val": len(seg_val_dataset)}, vid_trained_model, vid_loss, vid_optimizer, device=dev)
# Out:
# Epoch 1/10
# -----------
# Train | Loss : 0.0209  Acc : 99.33%
# Val   | Loss : 0.7467  Acc : 87.05%
# Time elapsed : 69.13 s
#
# Epoch 2/10
# -----------
# Train | Loss : 0.0175  Acc : 99.45%
# Val   | Loss : 0.7495  Acc : 86.58%
# Time elapsed : 68.81 s
#
# Epoch 3/10
# -----------
# Train | Loss : 0.0131  Acc : 99.63%
# Val   | Loss : 0.7540  Acc : 86.77%
# Time elapsed : 68.38 s
#
# Epoch 4/10
# -----------
# Train | Loss : 0.0156  Acc : 99.57%
# Val   | Loss : 0.7569  Acc : 86.77%
# Time elapsed : 68.64 s
#
# Epoch 5/10
# -----------
# Train | Loss : 0.0132  Acc : 99.52%
# Val   | Loss : 0.7614  Acc : 86.67%
# Time elapsed : 69.76 s
#
# Epoch 6/10
# -----------
# Train | Loss : 0.0110  Acc : 99.60%
# Val   | Loss : 0.7661  Acc : 86.67%
# Time elapsed : 68.21 s
#
# Epoch 7/10
# -----------
# Train | Loss : 0.0092  Acc : 99.68%
# Val   | Loss : 0.7720  Acc : 86.77%
# Time elapsed : 68.34 s
#
# Epoch 8/10
# -----------
# Train | Loss : 0.0085  Acc : 99.68%
# Val   | Loss : 0.7843  Acc : 87.14%
# Time elapsed : 68.16 s
#
# Epoch 9/10
# -----------
# Train | Loss : 0.0105  Acc : 99.67%
# Val   | Loss : 0.7843  Acc : 86.49%
# Time elapsed : 69.10 s
#
# Epoch 10/10
# -----------
# Train | Loss : 0.0080  Acc : 99.73%
# Val   | Loss : 0.7918  Acc : 86.58%
# Time elapsed : 67.66 s

# %%
print(max(vid_acc_loss_tuning[0]))
# Out:
# 87.13886300093196

# %%
set_lr(vid_optimizer, 0.00001)
vid_trained_model_tuning1, vid_acc_loss_tuning1 = vid_train_val(10, {"train": vid_train_loader, "val": vid_val_loader}, {"train": len(seg_train_dataset), "val": len(seg_val_dataset)}, vid_trained_model_tuning, vid_loss, vid_optimizer, device=dev)
# Out:
# Epoch 1/10
# -----------
# Train | Loss : 0.0080  Acc : 99.77%
# Val   | Loss : 0.7841  Acc : 87.14%
# Time elapsed : 68.26 s
#
# Epoch 2/10
# -----------
# Train | Loss : 0.0130  Acc : 99.55%
# Val   | Loss : 0.7850  Acc : 87.14%
# Time elapsed : 69.66 s
#
# Epoch 3/10
# -----------
# Train | Loss : 0.0072  Acc : 99.82%
# Val   | Loss : 0.7844  Acc : 87.23%
# Time elapsed : 69.39 s
#
# Epoch 4/10
# -----------
# Train | Loss : 0.0114  Acc : 99.62%
# Val   | Loss : 0.7846  Acc : 87.05%
# Time elapsed : 69.02 s
#
# Epoch 5/10
# -----------
# Train | Loss : 0.0069  Acc : 99.83%
# Val   | Loss : 0.7851  Acc : 86.95%
# Time elapsed : 68.53 s
#
# Epoch 6/10
# -----------
# Train | Loss : 0.0079  Acc : 99.77%
# Val   | Loss : 0.7860  Acc : 86.86%
# Time elapsed : 68.90 s
#
# Epoch 7/10
# -----------
# Train | Loss : 0.0096  Acc : 99.68%
# Val   | Loss : 0.7876  Acc : 86.86%
# Time elapsed : 68.62 s
#
# Epoch 8/10
# -----------
# Train | Loss : 0.0071  Acc : 99.75%
# Val   | Loss : 0.7877  Acc : 86.95%
# Time elapsed : 68.33 s
#
# Epoch 9/10
# -----------
# Train | Loss : 0.0073  Acc : 99.75%
# Val   | Loss : 0.7872  Acc : 86.86%
# Time elapsed : 69.91 s
#
# Epoch 10/10
# -----------
# Train | Loss : 0.0055  Acc : 99.88%
# Val   | Loss : 0.7865  Acc : 86.95%
# Time elapsed : 68.60 s

# %%
print(max(vid_acc_loss_tuning1[0]))
# Out:
# 87.23205964585274
