# %% [markdown]
# ## Video Action Classification

# %%
import os
import pickle

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_packed_sequence, pack_sequence, pack_padded_sequence
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device : {}".format(dev))
# Out:
# Using device : cuda:0

# %% [markdown]
# Load dataset

# %%
# pickle_filename = 'data.pickle'

# if os.path.isfile(pickle_filename):
#     with open(pickle_filename, 'rb') as file:
#         train_data_feat, train_data_labels, test_data_feat = pickle.load(file)
# else:
#     from read_datasetBreakfast import load_data, read_mapping_dict

#     COMP_PATH = ''

#     ''' 
#     training to load train set
#     test to load test set
#     '''
#     train_split =  os.path.join(COMP_PATH, 'splits/train.split1.bundle') #Train Split
#     test_split  =  os.path.join(COMP_PATH, 'splits/test.split1.bundle') #Test Split
#     GT_folder   =  os.path.join(COMP_PATH, 'groundTruth/') #Ground Truth Labels for each training video 
#     DATA_folder =  os.path.join(COMP_PATH, 'data/') #Frame I3D features for all videos
#     mapping_loc =  os.path.join(COMP_PATH, 'splits/mapping_bf.txt') 

#     actions_dict = read_mapping_dict(mapping_loc)
#     train_data_feat, train_data_labels = load_data( train_split, actions_dict, GT_folder, DATA_folder, datatype = "training") #Get features and labels
#     test_data_feat = load_data( test_split, actions_dict, GT_folder, DATA_folder, datatype = "test") #Get features only
    
#     with open(pickle_filename, 'wb') as file:
#         pickle.dump((train_data_feat, train_data_labels, test_data_feat), file)

# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))

# %% [markdown]
# ```python
# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))
# > 1460
# > 1460
# > 252
# ```

# %% [markdown]
# Flatten dataset

# %%
# with open("training_segment.txt", 'r') as file:
#     training_segment = [[int(a) for a in line.split()] for line in file]

# # tot_segment_len = 0
# # n_segment_len = 0
# # max_segment_len = 0
# # min_segment_len = float("inf")

# train_feat_flat = []
# train_labels_flat = []
# train_flat_idx = []
# for video_idx, video_segments in enumerate(tqdm(training_segment)):
#     for i in range(len(video_segments)-1):
#         segment_len = video_segments[i+1] - video_segments[i]
# #         tot_segment_len += segment_len
# #         n_segment_len += 1
# #         if segment_len > max_segment_len:
# #             max_segment_len = segment_len
# #         if segment_len < min_segment_len:
# #             min_segment_len = segment_len
#         train_flat_idx.append(len(train_feat_flat))
#         train_feat_flat.extend(train_data_feat[video_idx][video_segments[i]:video_segments[i+1]])
#         train_labels_flat.extend([(train_data_labels[video_idx][i])-1]*segment_len)
# train_flat_idx.append(len(train_feat_flat))

# # avg_segment_len = tot_segment_len / n_segment_len
# # print(avg_segment_len, max_segment_len, min_segment_len)

# %% [markdown]
# ```python
# print(avg_segment_len, max_segment_len, min_segment_len)
# > 404.3518021201413 5791 8
# ```

# %% [markdown]
# Pickle (or load) flatten dataset

# %%
num_split = 10
load_split = 10

files_exist = []
for i in range(num_split):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    files_exist.append(os.path.isfile(pickle_filename))

if not all(files_exist):
    max_len = len(train_feat_flat)
    split_len = max_len//num_split
    for i in tqdm(range(num_split)):
        pickle_filename = "flatten_data_{}.pickle".format(i)
        start_idx = split_len*i
        end_idx = split_len*(i+1) if i < num_split-1 else max_len
        print(i, start_idx, end_idx)
        with open(pickle_filename, 'wb') as file:
            train_feat_split_tensor = torch.stack(train_feat_flat[start_idx:end_idx]).to(dtype=torch.float32)
            train_labels_split_tensor = torch.LongTensor(train_labels_flat[start_idx:end_idx])
            pickle.dump((train_feat_split_tensor, train_labels_split_tensor), file)
    with open("flatten_data_idx.txt", 'w') as file:
        for i in train_flat_idx:
            file.write("{} ".format(i))

train_feat_split_list = []
train_labels_split_list = []
for i in tqdm(range(load_split)):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    with open(pickle_filename, 'rb') as file:
        train_feat_split, train_labels_split = pickle.load(file)
        train_feat_split_list.append(train_feat_split)
        train_labels_split_list.append(train_labels_split)
with open("flatten_data_idx.txt", 'r') as file:
    train_flat_idx = [int(a) for line in file for a in line.split()]

train_feat_tensor = torch.cat(train_feat_split_list, dim=0)
train_labels_tensor = torch.cat(train_labels_split_list, dim=0)
print(train_feat_tensor.shape)
print(train_labels_tensor.shape)
print(len(train_flat_idx))
print(train_flat_idx[:10])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# torch.Size([2860789, 400])
# torch.Size([2860789])
# 7076
# [0, 260, 465, 793, 1054, 1687, 5923, 7216, 7288, 7338]

# %% [markdown]
# Create dataset

# %%
from torch.utils.data import Dataset, DataLoader, Subset
from torch._utils import _accumulate

class MyDataset(Dataset):
    
    def __init__(self, features, labels, indices):
        self.features = features
        self.labels = labels
        self.indices = indices
        self.len = len(self.indices) - 1

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        return (self.features[self.indices[idx]:self.indices[idx+1]], self.labels[self.indices[idx]])

my_dataset = MyDataset(train_feat_tensor, train_labels_tensor, train_flat_idx)

# %% [markdown]
# Split dataset

# %%
tot_len = len(my_dataset)
print("Number of training data: {}".format(tot_len))

train_split_size = 0.85
lengths = [int(tot_len*train_split_size), tot_len - int(tot_len*train_split_size)]

train_dataset, val_dataset = torch.utils.data.random_split(my_dataset, lengths)
# Out:
# Number of training data: 7075

# %% [markdown]
# Define training routine

# %%
import time
import copy

import copy
def train_val(num_epoch, dataloader_dict, model, loss, optimizer, print_epoch=True, device=None):
    val_acc_history = []
    val_loss_history = []
    train_acc_history = []
    train_loss_history = []
    best_acc = 0.0
    best_model_weights = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epoch):
        since = time.time()
        if print_epoch:
            print("Epoch {}/{}".format(epoch+1, num_epoch))
            print("-----------")
        
        for phase in ["train", "val"]:
            if phase == "train":
                model.train()
            else :
                model.eval()
            total_loss = 0.0
            total_correct = 0.0
            for X, y, batch_len in dataloader_dict[phase]:
                if device is not None:
                    X = X.to(device)
                    y = y.to(device)
                with torch.set_grad_enabled(phase == "train"):
                    y_tilde = model(X)
                    L = loss(y_tilde, y)
                    if phase == "train":
                        optimizer.zero_grad()
                        L.backward()
                        optimizer.step()
                y_tilde_label = torch.argmax(y_tilde, dim=1)
                num_correct = torch.sum((y_tilde_label == y))
                
                total_loss += L.item() * batch_len
                total_correct += num_correct.item()
            
            epoch_loss = total_loss / len(dataloader_dict[phase].dataset)
            epoch_acc = (total_correct / len(dataloader_dict[phase].dataset)) * 100
            
            if phase == "val":
                val_loss_history.append(epoch_loss)
                val_acc_history.append(epoch_acc)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_weights = copy.deepcopy(model.state_dict())
            if phase == "train":
                train_loss_history.append(epoch_loss)
                train_acc_history.append(epoch_acc)

            if print_epoch:
                print("{} | Loss : {:.4f}  Acc : {:.2f}%".format(phase.capitalize().ljust(5), epoch_loss, epoch_acc))
        
        print("Time elapsed : {:.2f} s".format(time.time() - since))
        print()
    
    model.load_state_dict(best_model_weights)
    return model, (val_acc_history, val_loss_history, train_acc_history, train_loss_history)

# %% [markdown]
# Define model

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.dropout1 = nn.Dropout(p=0.2)
        self.num_layers = 2
        self.lstm = nn.LSTM(400, 256, batch_first=True, num_layers=self.num_layers, dropout=0.5)
        self.dropout2 = nn.Dropout(p=0.5)
        self.linear = nn.Linear(256*(2+self.num_layers), 47)
        self.padding_value = 0
    def forward(self, x):
        x_pad, lengths = pad_packed_sequence(x, batch_first=True, padding_value=self.padding_value)
        x_pad = self.dropout1(x_pad)
        x = pack_padded_sequence(x_pad, lengths, batch_first=True, enforce_sorted=False)
        
        h, (h_last, c) = self.lstm(x)
        
        h_pad, lengths = pad_packed_sequence(h, batch_first=True, padding_value=self.padding_value)
        h_avg_pool = torch.sum(h_pad, 1) / (torch.sum((h_pad != self.padding_value), 1) + 1e-5)
        h_max_pool = torch.max(h_pad, 1)[0]
        x = torch.cat((*(h_last.unbind()), h_avg_pool, h_max_pool), 1)
        
        x = self.dropout2(x)
        
        x = self.linear(x)
        return x

model = Model()
for param in model.parameters():
    print(type(param.data), param.size())
# Out:
# <class 'torch.Tensor'> torch.Size([1024, 400])
# <class 'torch.Tensor'> torch.Size([1024, 256])
# <class 'torch.Tensor'> torch.Size([1024])
# <class 'torch.Tensor'> torch.Size([1024])
# <class 'torch.Tensor'> torch.Size([1024, 256])
# <class 'torch.Tensor'> torch.Size([1024, 256])
# <class 'torch.Tensor'> torch.Size([1024])
# <class 'torch.Tensor'> torch.Size([1024])
# <class 'torch.Tensor'> torch.Size([47, 1024])
# <class 'torch.Tensor'> torch.Size([47])

# %% [markdown]
# Create DataLoader

# %%
def collate(batch_data):
    features = []
    labels = []
    for feature, label in batch_data:
        features.append(feature)
        labels.append(label)
    return (pack_sequence(features, enforce_sorted=False), torch.tensor(labels), len(batch_data))

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)

# %% [markdown]
# Start training

# %%
my_model = Model()
my_model.to(dev)
loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(my_model.parameters())

trained_model, acc = train_val(100, {"train": train_loader, "val": val_loader}, my_model, loss, optimizer, device=dev)
# Out:
# Epoch 1/100
# -----------
# Train | Loss : 3.0533  Acc : 18.63%
# Val   | Loss : 2.7450  Acc : 23.73%
# Time elapsed : 136.11 s
#
# Epoch 2/100
# -----------
# Train | Loss : 2.4009  Acc : 31.12%
# Val   | Loss : 2.1815  Acc : 38.04%
# Time elapsed : 133.66 s
#
# Epoch 3/100
# -----------
# Train | Loss : 2.0389  Acc : 38.83%
# Val   | Loss : 2.0178  Acc : 40.02%
# Time elapsed : 130.74 s
#
# Epoch 4/100
# -----------
# Train | Loss : 1.7994  Acc : 44.87%
# Val   | Loss : 1.7656  Acc : 46.42%
# Time elapsed : 133.12 s
#
# Epoch 5/100
# -----------
# Train | Loss : 1.6417  Acc : 49.04%
# Val   | Loss : 1.7043  Acc : 47.65%
# Time elapsed : 136.03 s
#
# Epoch 6/100
# -----------
# Train | Loss : 1.5161  Acc : 52.64%
# Val   | Loss : 1.6973  Acc : 48.40%
# Time elapsed : 131.57 s
#
# Epoch 7/100
# -----------
# Train | Loss : 1.5023  Acc : 53.68%
# Val   | Loss : 1.5966  Acc : 51.32%
# Time elapsed : 131.12 s
#
# Epoch 8/100
# -----------
# Train | Loss : 1.4695  Acc : 54.78%
# Val   | Loss : 1.4388  Acc : 57.16%
# Time elapsed : 131.94 s
#
# Epoch 9/100
# -----------
# Train | Loss : 1.3082  Acc : 58.67%
# Val   | Loss : 1.4205  Acc : 56.87%
# Time elapsed : 131.53 s
#
# Epoch 10/100
# -----------
# Train | Loss : 1.2471  Acc : 60.17%
# Val   | Loss : 1.4427  Acc : 56.69%
# Time elapsed : 141.97 s
#
# Epoch 11/100
# -----------
# Train | Loss : 1.1769  Acc : 62.38%
# Val   | Loss : 1.3472  Acc : 57.16%
# Time elapsed : 139.22 s
#
# Epoch 12/100
# -----------
# Train | Loss : 1.1628  Acc : 62.96%
# Val   | Loss : 1.3736  Acc : 58.10%
# Time elapsed : 136.98 s
#
# Epoch 13/100
# -----------
# Train | Loss : 1.0886  Acc : 64.84%
# Val   | Loss : 1.2905  Acc : 61.21%
# Time elapsed : 132.47 s
#
# Epoch 14/100
# -----------
# Train | Loss : 1.0173  Acc : 66.79%
# Val   | Loss : 1.2355  Acc : 60.17%
# Time elapsed : 134.29 s
#
# Epoch 15/100
# -----------
# Train | Loss : 0.9809  Acc : 67.82%
# Val   | Loss : 1.2509  Acc : 62.52%
# Time elapsed : 142.40 s
#
# Epoch 16/100
# -----------
# Train | Loss : 0.9425  Acc : 68.40%
# Val   | Loss : 1.2583  Acc : 60.73%
# Time elapsed : 139.61 s
#
# Epoch 17/100
# -----------
# Train | Loss : 0.8807  Acc : 70.86%
# Val   | Loss : 1.2930  Acc : 62.15%
# Time elapsed : 135.88 s
#
# Epoch 18/100
# -----------
# Train | Loss : 0.9520  Acc : 69.07%
# Val   | Loss : 1.2951  Acc : 59.60%
# Time elapsed : 144.56 s
#
# Epoch 19/100
# -----------
# Train | Loss : 0.9357  Acc : 68.57%
# Val   | Loss : 1.2512  Acc : 61.58%
# Time elapsed : 141.28 s
#
# Epoch 20/100
# -----------
# Train | Loss : 0.8265  Acc : 72.11%
# Val   | Loss : 1.2143  Acc : 62.71%
# Time elapsed : 142.07 s
#
# Epoch 21/100
# -----------
# Train | Loss : 0.7870  Acc : 73.36%
# Val   | Loss : 1.1587  Acc : 64.03%
# Time elapsed : 140.37 s
#
# Epoch 22/100
# -----------
# Train | Loss : 0.7252  Acc : 75.20%
# Val   | Loss : 1.1192  Acc : 64.12%
# Time elapsed : 140.12 s
#
# Epoch 23/100
# -----------
# Train | Loss : 0.7137  Acc : 76.09%
# Val   | Loss : 1.1590  Acc : 64.31%
# Time elapsed : 139.42 s
#
# Epoch 24/100
# -----------
# Train | Loss : 0.6896  Acc : 76.67%
# Val   | Loss : 1.1510  Acc : 64.50%
# Time elapsed : 144.30 s
#
# Epoch 25/100
# -----------
# Train | Loss : 0.6654  Acc : 77.28%
# Val   | Loss : 1.1401  Acc : 64.22%
# Time elapsed : 140.27 s
#
# Epoch 26/100
# -----------
# Train | Loss : 0.6675  Acc : 77.17%
# Val   | Loss : 1.2575  Acc : 63.84%
# Time elapsed : 144.93 s
#
# Epoch 27/100
# -----------
# Train | Loss : 0.6173  Acc : 79.43%
# Val   | Loss : 1.2830  Acc : 61.77%
# Time elapsed : 147.18 s
#
# Epoch 28/100
# -----------
# Train | Loss : 0.6021  Acc : 79.13%
# Val   | Loss : 1.1868  Acc : 65.16%
# Time elapsed : 138.76 s
#
# Epoch 29/100
# -----------
# Train | Loss : 0.5343  Acc : 81.22%
# Val   | Loss : 1.2389  Acc : 64.97%
# Time elapsed : 140.90 s
#
# Epoch 30/100
# -----------
# Train | Loss : 0.5823  Acc : 80.09%
# Val   | Loss : 1.1743  Acc : 64.69%
# Time elapsed : 135.90 s
#
# Epoch 31/100
# -----------
# Train | Loss : 0.4953  Acc : 83.12%
# Val   | Loss : 1.1455  Acc : 65.44%
# Time elapsed : 140.38 s
#
# Epoch 32/100
# -----------
# Train | Loss : 0.4992  Acc : 82.60%
# Val   | Loss : 1.1856  Acc : 66.85%
# Time elapsed : 134.07 s
#
# Epoch 33/100
# -----------
# Train | Loss : 0.5508  Acc : 81.22%
# Val   | Loss : 1.2738  Acc : 63.28%
# Time elapsed : 133.39 s
#
# Epoch 34/100
# -----------
# Train | Loss : 0.5062  Acc : 82.49%
# Val   | Loss : 1.1128  Acc : 68.55%
# Time elapsed : 141.45 s
#
# Epoch 35/100
# -----------
# Train | Loss : 0.4567  Acc : 84.42%
# Val   | Loss : 1.1796  Acc : 66.76%
# Time elapsed : 148.28 s
#
# Epoch 36/100
# -----------
# Train | Loss : 0.4934  Acc : 83.45%
# Val   | Loss : 1.2012  Acc : 66.57%
# Time elapsed : 141.39 s
#
# Epoch 37/100
# -----------
# Train | Loss : 0.4828  Acc : 83.30%
# Val   | Loss : 1.2091  Acc : 65.91%
# Time elapsed : 149.86 s
#
# Epoch 38/100
# -----------
# Train | Loss : 0.4001  Acc : 86.48%
# Val   | Loss : 1.1416  Acc : 66.76%
# Time elapsed : 153.42 s
#
# Epoch 39/100
# -----------
# Train | Loss : 0.4475  Acc : 84.87%
# Val   | Loss : 1.2071  Acc : 66.48%
# Time elapsed : 154.62 s
#
# Epoch 40/100
# -----------
# Train | Loss : 0.3815  Acc : 86.93%
# Val   | Loss : 1.2440  Acc : 65.82%
# Time elapsed : 150.94 s
#
# Epoch 41/100
# -----------
# Train | Loss : 0.4062  Acc : 85.65%
# Val   | Loss : 1.1813  Acc : 66.29%
# Time elapsed : 151.32 s
#
# Epoch 42/100
# -----------
# Train | Loss : 0.4201  Acc : 85.53%
# Val   | Loss : 1.2220  Acc : 66.38%
# Time elapsed : 154.52 s
#
# Epoch 43/100
# -----------
# Train | Loss : 0.4248  Acc : 86.00%
# Val   | Loss : 1.2845  Acc : 64.60%
# Time elapsed : 155.16 s
#
# Epoch 44/100
# -----------
# Train | Loss : 0.4536  Acc : 84.22%
# Val   | Loss : 1.2229  Acc : 65.82%
# Time elapsed : 151.67 s
#
# Epoch 45/100
# -----------
# Train | Loss : 0.3776  Acc : 87.26%
# Val   | Loss : 1.2115  Acc : 67.04%
# Time elapsed : 149.01 s
#
# Epoch 46/100
# -----------
# Train | Loss : 0.3745  Acc : 86.50%
# Val   | Loss : 1.2954  Acc : 65.54%
# Time elapsed : 151.96 s
#
# Epoch 47/100
# -----------
# Train | Loss : 0.3667  Acc : 87.13%
# Val   | Loss : 1.2753  Acc : 65.35%
# Time elapsed : 152.77 s
#
# Epoch 48/100
# -----------
# Train | Loss : 0.3873  Acc : 86.88%
# Val   | Loss : 1.1887  Acc : 67.98%
# Time elapsed : 149.04 s
#
# Epoch 49/100
# -----------
# Train | Loss : 0.3373  Acc : 88.08%
# Val   | Loss : 1.2484  Acc : 66.76%
# Time elapsed : 152.52 s
#
# Epoch 50/100
# -----------
# Train | Loss : 0.3527  Acc : 88.13%
# Val   | Loss : 1.3035  Acc : 66.95%
# Time elapsed : 150.52 s
#
# Epoch 51/100
# -----------
# Train | Loss : 0.3220  Acc : 89.14%
# Val   | Loss : 1.1522  Acc : 68.64%
# Time elapsed : 151.95 s
#
# Epoch 52/100
# -----------
# Train | Loss : 0.2957  Acc : 89.49%
# Val   | Loss : 1.2271  Acc : 66.38%
# Time elapsed : 150.00 s
#
# Epoch 53/100
# -----------
# Train | Loss : 0.3147  Acc : 89.16%
# Val   | Loss : 1.1890  Acc : 69.40%
# Time elapsed : 151.63 s
#
# Epoch 54/100
# -----------
# Train | Loss : 0.3448  Acc : 88.24%
# Val   | Loss : 1.2560  Acc : 66.85%
# Time elapsed : 152.46 s
#
# Epoch 55/100
# -----------
# Train | Loss : 0.3134  Acc : 88.96%
# Val   | Loss : 1.1896  Acc : 68.64%
# Time elapsed : 150.47 s
#
# Epoch 56/100
# -----------
# Train | Loss : 0.3190  Acc : 89.54%
# Val   | Loss : 1.2473  Acc : 67.80%
# Time elapsed : 149.47 s
#
# Epoch 57/100
# -----------
# Train | Loss : 0.2977  Acc : 89.36%
# Val   | Loss : 1.2197  Acc : 67.89%
# Time elapsed : 153.08 s
#
# Epoch 58/100
# -----------
# Train | Loss : 0.2686  Acc : 90.87%
# Val   | Loss : 1.2616  Acc : 67.23%
# Time elapsed : 158.32 s
#
# Epoch 59/100
# -----------
# Train | Loss : 0.2462  Acc : 91.30%
# Val   | Loss : 1.2063  Acc : 69.30%
# Time elapsed : 161.96 s
#
# Epoch 60/100
# -----------
# Train | Loss : 0.2323  Acc : 91.77%
# Val   | Loss : 1.2680  Acc : 69.30%
# Time elapsed : 160.73 s
#
# Epoch 61/100
# -----------
# Train | Loss : 0.2363  Acc : 91.73%
# Val   | Loss : 1.2752  Acc : 69.49%
# Time elapsed : 155.41 s
#
# Epoch 62/100
# -----------
# Train | Loss : 0.2877  Acc : 90.00%
# Val   | Loss : 1.2974  Acc : 69.21%
# Time elapsed : 150.40 s
#
# Epoch 63/100
# -----------
# Train | Loss : 0.2850  Acc : 90.02%
# Val   | Loss : 1.3282  Acc : 65.63%
# Time elapsed : 140.96 s
#
# Epoch 64/100
# -----------
# Train | Loss : 0.2127  Acc : 92.85%
# Val   | Loss : 1.3627  Acc : 68.36%
# Time elapsed : 137.90 s
#
# Epoch 65/100
# -----------
# Train | Loss : 0.2231  Acc : 92.45%
# Val   | Loss : 1.3082  Acc : 67.98%
# Time elapsed : 139.17 s
#
# Epoch 66/100
# -----------
# Train | Loss : 0.1943  Acc : 93.51%
# Val   | Loss : 1.3335  Acc : 69.77%
# Time elapsed : 134.74 s
#
# Epoch 67/100
# -----------
# Train | Loss : 0.2810  Acc : 90.45%
# Val   | Loss : 1.2893  Acc : 67.80%
# Time elapsed : 144.90 s
#
# Epoch 68/100
# -----------
# Train | Loss : 0.2356  Acc : 92.17%
# Val   | Loss : 1.3571  Acc : 68.93%
# Time elapsed : 154.59 s
#
# Epoch 69/100
# -----------
# Train | Loss : 0.1966  Acc : 93.55%
# Val   | Loss : 1.4283  Acc : 66.48%
# Time elapsed : 157.03 s
#
# Epoch 70/100
# -----------
# Train | Loss : 0.2580  Acc : 91.50%
# Val   | Loss : 1.4675  Acc : 64.60%
# Time elapsed : 151.97 s
#
# Epoch 71/100
# -----------
# Train | Loss : 0.2264  Acc : 92.10%
# Val   | Loss : 1.2632  Acc : 69.11%
# Time elapsed : 138.57 s
#
# Epoch 72/100
# -----------
# Train | Loss : 0.2358  Acc : 91.78%
# Val   | Loss : 1.2903  Acc : 69.40%
# Time elapsed : 134.84 s
#
# Epoch 73/100
# -----------
# Train | Loss : 0.2331  Acc : 92.05%
# Val   | Loss : 1.4344  Acc : 66.29%
# Time elapsed : 134.07 s
#
# Epoch 74/100
# -----------
# Train | Loss : 0.1670  Acc : 94.38%
# Val   | Loss : 1.3692  Acc : 66.48%
# Time elapsed : 133.67 s
#
# Epoch 75/100
# -----------
# Train | Loss : 0.1980  Acc : 92.98%
# Val   | Loss : 1.3349  Acc : 68.83%
# Time elapsed : 132.22 s
#
# Epoch 76/100
# -----------
# Train | Loss : 0.1786  Acc : 93.75%
# Val   | Loss : 1.4177  Acc : 68.36%
# Time elapsed : 135.27 s
#
# Epoch 77/100
# -----------
# Train | Loss : 0.3317  Acc : 88.92%
# Val   | Loss : 1.4108  Acc : 67.80%
# Time elapsed : 131.04 s
#
# Epoch 78/100
# -----------
# Train | Loss : 0.2234  Acc : 92.18%
# Val   | Loss : 1.3472  Acc : 69.59%
# Time elapsed : 135.56 s
#
# Epoch 79/100
# -----------
# Train | Loss : 0.2079  Acc : 92.72%
# Val   | Loss : 1.3181  Acc : 68.55%
# Time elapsed : 139.24 s
#
# Epoch 80/100
# -----------
# Train | Loss : 0.1884  Acc : 93.48%
# Val   | Loss : 1.3052  Acc : 68.46%
# Time elapsed : 133.06 s
#
# Epoch 81/100
# -----------
# Train | Loss : 0.1784  Acc : 93.88%
# Val   | Loss : 1.4704  Acc : 67.61%
# Time elapsed : 147.52 s
#
# Epoch 82/100
# -----------
# Train | Loss : 0.1867  Acc : 93.76%
# Val   | Loss : 1.4125  Acc : 69.59%
# Time elapsed : 143.43 s
#
# Epoch 83/100
# -----------
# Train | Loss : 0.1882  Acc : 93.88%
# Val   | Loss : 1.4067  Acc : 67.89%
# Time elapsed : 138.47 s
#
# Epoch 84/100
# -----------
# Train | Loss : 0.1368  Acc : 95.24%
# Val   | Loss : 1.3814  Acc : 70.24%
# Time elapsed : 136.26 s
#
# Epoch 85/100
# -----------
# Train | Loss : 0.1585  Acc : 94.25%
# Val   | Loss : 1.5089  Acc : 65.91%
# Time elapsed : 137.53 s
#
# Epoch 86/100
# -----------
# Train | Loss : 0.1446  Acc : 95.29%
# Val   | Loss : 1.3171  Acc : 70.90%
# Time elapsed : 131.86 s
#
# Epoch 87/100
# -----------
# Train | Loss : 0.1464  Acc : 95.14%
# Val   | Loss : 1.3515  Acc : 69.59%
# Time elapsed : 135.29 s
#
# Epoch 88/100
# -----------
# Train | Loss : 0.1309  Acc : 95.39%
# Val   | Loss : 1.5214  Acc : 67.04%
# Time elapsed : 139.53 s
#
# Epoch 89/100
# -----------
# Train | Loss : 0.1427  Acc : 95.38%
# Val   | Loss : 1.4940  Acc : 67.23%
# Time elapsed : 137.18 s
#
# Epoch 90/100
# -----------
# Train | Loss : 0.1602  Acc : 94.73%
# Val   | Loss : 1.4764  Acc : 67.61%
# Time elapsed : 141.18 s
#
# Epoch 91/100
# -----------
# Train | Loss : 0.1645  Acc : 94.38%
# Val   | Loss : 1.3762  Acc : 67.89%
# Time elapsed : 141.76 s
#
# Epoch 92/100
# -----------
# Train | Loss : 0.1636  Acc : 94.40%
# Val   | Loss : 1.4859  Acc : 66.29%
# Time elapsed : 144.10 s
#
# Epoch 93/100
# -----------
# Train | Loss : 0.1571  Acc : 94.64%
# Val   | Loss : 1.5564  Acc : 66.85%
# Time elapsed : 136.82 s
#
# Epoch 94/100
# -----------
# Train | Loss : 0.1895  Acc : 94.05%
# Val   | Loss : 1.4026  Acc : 70.62%
# Time elapsed : 141.04 s
#
# Epoch 95/100
# -----------
# Train | Loss : 0.1831  Acc : 94.01%
# Val   | Loss : 1.5016  Acc : 67.89%
# Time elapsed : 127.31 s
#
# Epoch 96/100
# -----------
# Train | Loss : 0.1519  Acc : 94.74%
# Val   | Loss : 1.3099  Acc : 72.03%
# Time elapsed : 136.02 s
#
# Epoch 97/100
# -----------
# Train | Loss : 0.1911  Acc : 93.66%
# Val   | Loss : 1.5269  Acc : 65.82%
# Time elapsed : 139.64 s
#
# Epoch 98/100
# -----------
# Train | Loss : 0.2626  Acc : 91.57%
# Val   | Loss : 1.3630  Acc : 69.77%
# Time elapsed : 135.15 s
#
# Epoch 99/100
# -----------
# Train | Loss : 0.1432  Acc : 95.03%
# Val   | Loss : 1.4357  Acc : 69.77%
# Time elapsed : 135.68 s
#
# Epoch 100/100
# -----------
# Train | Loss : 0.1521  Acc : 95.03%
# Val   | Loss : 1.4959  Acc : 67.04%
# Time elapsed : 140.94 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.figure(figsize=(18, 5))
epoch_num = range(1, 101)
plt.subplot(1, 2, 1)
plt.title('Accuracy')
plt.ylim(0, 110)
plt.grid(True)
plt.plot(epoch_num, acc[2], color="blue")
plt.plot(epoch_num, acc[0], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])
plt.subplot(1, 2, 2)
plt.title('Loss')
plt.ylim(0, 3)
plt.grid(True)
plt.plot(epoch_num, acc[3], color="blue")
plt.plot(epoch_num, acc[1], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])

# %%
print(max(acc[0]))
# Out:
# 72.03389830508475

# %%
def set_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
set_lr(optimizer, 0.0001)
trained_model_tuning, acc_tuning = train_val(50, {"train": train_loader, "val": val_loader}, trained_model, loss, optimizer, device=dev)
# Out:
# Epoch 1/50
# -----------
# Train | Loss : 0.0925  Acc : 96.94%
# Val   | Loss : 1.3195  Acc : 71.47%
# Time elapsed : 133.94 s
#
# Epoch 2/50
# -----------
# Train | Loss : 0.0775  Acc : 97.41%
# Val   | Loss : 1.3305  Acc : 71.28%
# Time elapsed : 126.42 s
#
# Epoch 3/50
# -----------
# Train | Loss : 0.0651  Acc : 97.64%
# Val   | Loss : 1.3354  Acc : 72.22%
# Time elapsed : 131.16 s
#
# Epoch 4/50
# -----------
# Train | Loss : 0.0570  Acc : 98.17%
# Val   | Loss : 1.3456  Acc : 72.13%
# Time elapsed : 126.14 s
#
# Epoch 5/50
# -----------
# Train | Loss : 0.0523  Acc : 98.39%
# Val   | Loss : 1.3220  Acc : 72.41%
# Time elapsed : 128.06 s
#
# Epoch 6/50
# -----------
# Train | Loss : 0.0490  Acc : 98.59%
# Val   | Loss : 1.3316  Acc : 72.50%
# Time elapsed : 131.60 s
#
# Epoch 7/50
# -----------
# Train | Loss : 0.0430  Acc : 98.79%
# Val   | Loss : 1.3378  Acc : 72.03%
# Time elapsed : 126.78 s
#
# Epoch 8/50
# -----------
# Train | Loss : 0.0385  Acc : 99.05%
# Val   | Loss : 1.3606  Acc : 71.47%
# Time elapsed : 131.16 s
#
# Epoch 9/50
# -----------
# Train | Loss : 0.0394  Acc : 99.07%
# Val   | Loss : 1.3869  Acc : 71.85%
# Time elapsed : 129.02 s
#
# Epoch 10/50
# -----------
# Train | Loss : 0.0354  Acc : 99.17%
# Val   | Loss : 1.3909  Acc : 72.03%
# Time elapsed : 128.08 s
#
# Epoch 11/50
# -----------
# Train | Loss : 0.0368  Acc : 98.95%
# Val   | Loss : 1.3647  Acc : 72.22%
# Time elapsed : 132.10 s
#
# Epoch 12/50
# -----------
# Train | Loss : 0.0344  Acc : 99.09%
# Val   | Loss : 1.3664  Acc : 72.32%
# Time elapsed : 129.65 s
#
# Epoch 13/50
# -----------
# Train | Loss : 0.0382  Acc : 99.02%
# Val   | Loss : 1.3811  Acc : 72.88%
# Time elapsed : 132.11 s
#
# Epoch 14/50
# -----------
# Train | Loss : 0.0328  Acc : 99.09%
# Val   | Loss : 1.3869  Acc : 72.22%
# Time elapsed : 129.96 s
#
# Epoch 15/50
# -----------
# Train | Loss : 0.0315  Acc : 99.15%
# Val   | Loss : 1.3917  Acc : 72.32%
# Time elapsed : 132.99 s
#
# Epoch 16/50
# -----------
# Train | Loss : 0.0322  Acc : 99.04%
# Val   | Loss : 1.3796  Acc : 72.13%
# Time elapsed : 130.41 s
#
# Epoch 17/50
# -----------
# Train | Loss : 0.0295  Acc : 99.25%
# Val   | Loss : 1.3709  Acc : 72.60%
# Time elapsed : 129.12 s
#
# Epoch 18/50
# -----------
# Train | Loss : 0.0266  Acc : 99.28%
# Val   | Loss : 1.3782  Acc : 73.26%
# Time elapsed : 132.00 s
#
# Epoch 19/50
# -----------
# Train | Loss : 0.0301  Acc : 99.25%
# Val   | Loss : 1.3665  Acc : 72.98%
# Time elapsed : 137.74 s
#
# Epoch 20/50
# -----------
# Train | Loss : 0.0273  Acc : 99.25%
# Val   | Loss : 1.3976  Acc : 72.32%
# Time elapsed : 128.07 s
#
# Epoch 21/50
# -----------
# Train | Loss : 0.0270  Acc : 99.27%
# Val   | Loss : 1.4120  Acc : 72.79%
# Time elapsed : 130.28 s
#
# Epoch 22/50
# -----------
# Train | Loss : 0.0250  Acc : 99.28%
# Val   | Loss : 1.4402  Acc : 71.94%
# Time elapsed : 133.20 s
#
# Epoch 23/50
# -----------
# Train | Loss : 0.0218  Acc : 99.45%
# Val   | Loss : 1.4238  Acc : 72.41%
# Time elapsed : 128.40 s
#
# Epoch 24/50
# -----------
# Train | Loss : 0.0241  Acc : 99.42%
# Val   | Loss : 1.4268  Acc : 71.47%
# Time elapsed : 129.56 s
#
# Epoch 25/50
# -----------
# Train | Loss : 0.0249  Acc : 99.43%
# Val   | Loss : 1.4132  Acc : 72.32%
# Time elapsed : 128.44 s
#
# Epoch 26/50
# -----------
# Train | Loss : 0.0195  Acc : 99.53%
# Val   | Loss : 1.4034  Acc : 72.13%
# Time elapsed : 133.21 s
#
# Epoch 27/50
# -----------
# Train | Loss : 0.0192  Acc : 99.50%
# Val   | Loss : 1.4365  Acc : 72.50%
# Time elapsed : 129.98 s
#
# Epoch 28/50
# -----------
# Train | Loss : 0.0204  Acc : 99.53%
# Val   | Loss : 1.4278  Acc : 72.03%
# Time elapsed : 128.33 s
#
# Epoch 29/50
# -----------
# Train | Loss : 0.0189  Acc : 99.60%
# Val   | Loss : 1.4257  Acc : 72.50%
# Time elapsed : 133.37 s
#
# Epoch 30/50
# -----------
# Train | Loss : 0.0178  Acc : 99.57%
# Val   | Loss : 1.4168  Acc : 73.63%
# Time elapsed : 132.42 s
#
# Epoch 31/50
# -----------
# Train | Loss : 0.0182  Acc : 99.67%
# Val   | Loss : 1.4934  Acc : 72.32%
# Time elapsed : 128.43 s
#
# Epoch 32/50
# -----------
# Train | Loss : 0.0204  Acc : 99.47%
# Val   | Loss : 1.4727  Acc : 71.37%
# Time elapsed : 134.84 s
#
# Epoch 33/50
# -----------
# Train | Loss : 0.0174  Acc : 99.62%
# Val   | Loss : 1.4761  Acc : 72.32%
# Time elapsed : 133.95 s
#
# Epoch 34/50
# -----------
# Train | Loss : 0.0159  Acc : 99.63%
# Val   | Loss : 1.4686  Acc : 72.13%
# Time elapsed : 132.05 s
#
# Epoch 35/50
# -----------
# Train | Loss : 0.0162  Acc : 99.63%
# Val   | Loss : 1.4683  Acc : 72.79%
# Time elapsed : 134.44 s
#
# Epoch 36/50
# -----------
# Train | Loss : 0.0162  Acc : 99.53%
# Val   | Loss : 1.4627  Acc : 71.66%
# Time elapsed : 130.84 s
#
# Epoch 37/50
# -----------
# Train | Loss : 0.0207  Acc : 99.43%
# Val   | Loss : 1.5556  Acc : 70.15%
# Time elapsed : 133.40 s
#
# Epoch 38/50
# -----------
# Train | Loss : 0.0142  Acc : 99.58%
# Val   | Loss : 1.5364  Acc : 70.53%
# Time elapsed : 128.92 s
#
# Epoch 39/50
# -----------
# Train | Loss : 0.0142  Acc : 99.68%
# Val   | Loss : 1.5029  Acc : 71.56%
# Time elapsed : 130.48 s
#
# Epoch 40/50
# -----------
# Train | Loss : 0.0163  Acc : 99.63%
# Val   | Loss : 1.5284  Acc : 71.28%
# Time elapsed : 130.30 s
#
# Epoch 41/50
# -----------
# Train | Loss : 0.0159  Acc : 99.63%
# Val   | Loss : 1.5450  Acc : 71.56%
# Time elapsed : 130.31 s
#
# Epoch 42/50
# -----------
# Train | Loss : 0.0154  Acc : 99.65%
# Val   | Loss : 1.5252  Acc : 71.37%
# Time elapsed : 131.28 s
#
# Epoch 43/50
# -----------
# Train | Loss : 0.0174  Acc : 99.47%
# Val   | Loss : 1.5757  Acc : 71.47%
# Time elapsed : 127.77 s
#
# Epoch 44/50
# -----------
# Train | Loss : 0.0152  Acc : 99.67%
# Val   | Loss : 1.5625  Acc : 71.47%
# Time elapsed : 130.64 s
#
# Epoch 45/50
# -----------
# Train | Loss : 0.0138  Acc : 99.72%
# Val   | Loss : 1.5507  Acc : 71.66%
# Time elapsed : 130.22 s
#
# Epoch 46/50
# -----------
# Train | Loss : 0.0157  Acc : 99.57%
# Val   | Loss : 1.5574  Acc : 71.37%
# Time elapsed : 130.20 s
#
# Epoch 47/50
# -----------
# Train | Loss : 0.0144  Acc : 99.65%
# Val   | Loss : 1.5594  Acc : 71.94%
# Time elapsed : 128.67 s
#
# Epoch 48/50
# -----------
# Train | Loss : 0.0141  Acc : 99.62%
# Val   | Loss : 1.5821  Acc : 70.81%
# Time elapsed : 131.21 s
#
# Epoch 49/50
# -----------
# Train | Loss : 0.0141  Acc : 99.67%
# Val   | Loss : 1.5694  Acc : 71.28%
# Time elapsed : 129.14 s
#
# Epoch 50/50
# -----------
# Train | Loss : 0.0133  Acc : 99.62%
# Val   | Loss : 1.5704  Acc : 71.28%
# Time elapsed : 130.26 s

# %%
print(max(acc_tuning[0]))
# Out:
# 73.6346516007533
