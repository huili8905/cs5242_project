# %% [markdown]
# ## Video Action Classification

# %%
import os
import pickle

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_packed_sequence, pack_sequence, pack_padded_sequence
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device : {}".format(dev))
# Out:
# Using device : cuda:0

# %% [markdown]
# Load dataset

# %%
# pickle_filename = 'data.pickle'

# if os.path.isfile(pickle_filename):
#     with open(pickle_filename, 'rb') as file:
#         train_data_feat, train_data_labels, test_data_feat = pickle.load(file)
# else:
#     from read_datasetBreakfast import load_data, read_mapping_dict

#     COMP_PATH = ''

#     ''' 
#     training to load train set
#     test to load test set
#     '''
#     train_split =  os.path.join(COMP_PATH, 'splits/train.split1.bundle') #Train Split
#     test_split  =  os.path.join(COMP_PATH, 'splits/test.split1.bundle') #Test Split
#     GT_folder   =  os.path.join(COMP_PATH, 'groundTruth/') #Ground Truth Labels for each training video 
#     DATA_folder =  os.path.join(COMP_PATH, 'data/') #Frame I3D features for all videos
#     mapping_loc =  os.path.join(COMP_PATH, 'splits/mapping_bf.txt') 

#     actions_dict = read_mapping_dict(mapping_loc)
#     train_data_feat, train_data_labels = load_data( train_split, actions_dict, GT_folder, DATA_folder, datatype = "training") #Get features and labels
#     test_data_feat = load_data( test_split, actions_dict, GT_folder, DATA_folder, datatype = "test") #Get features only
    
#     with open(pickle_filename, 'wb') as file:
#         pickle.dump((train_data_feat, train_data_labels, test_data_feat), file)

# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))

# %% [markdown]
# ```python
# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))
# > 1460
# > 1460
# > 252
# ```

# %% [markdown]
# Flatten dataset

# %%
# with open("training_segment.txt", 'r') as file:
#     training_segment = [[int(a) for a in line.split()] for line in file]

# # tot_segment_len = 0
# # n_segment_len = 0
# # max_segment_len = 0
# # min_segment_len = float("inf")

# train_feat_flat = []
# train_labels_flat = []
# train_flat_idx = []
# for video_idx, video_segments in enumerate(tqdm(training_segment)):
#     for i in range(len(video_segments)-1):
#         segment_len = video_segments[i+1] - video_segments[i]
# #         tot_segment_len += segment_len
# #         n_segment_len += 1
# #         if segment_len > max_segment_len:
# #             max_segment_len = segment_len
# #         if segment_len < min_segment_len:
# #             min_segment_len = segment_len
#         train_flat_idx.append(len(train_feat_flat))
#         train_feat_flat.extend(train_data_feat[video_idx][video_segments[i]:video_segments[i+1]])
#         train_labels_flat.extend([(train_data_labels[video_idx][i])-1]*segment_len)
# train_flat_idx.append(len(train_feat_flat))

# # avg_segment_len = tot_segment_len / n_segment_len
# # print(avg_segment_len, max_segment_len, min_segment_len)

# %% [markdown]
# ```python
# print(avg_segment_len, max_segment_len, min_segment_len)
# > 404.3518021201413 5791 8
# ```

# %% [markdown]
# Pickle (or load) flatten dataset

# %%
num_split = 10
load_split = 10

files_exist = []
for i in range(num_split):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    files_exist.append(os.path.isfile(pickle_filename))

if not all(files_exist):
    max_len = len(train_feat_flat)
    split_len = max_len//num_split
    for i in tqdm(range(num_split)):
        pickle_filename = "flatten_data_{}.pickle".format(i)
        start_idx = split_len*i
        end_idx = split_len*(i+1) if i < num_split-1 else max_len
        print(i, start_idx, end_idx)
        with open(pickle_filename, 'wb') as file:
            train_feat_split_tensor = torch.stack(train_feat_flat[start_idx:end_idx]).to(dtype=torch.float32)
            train_labels_split_tensor = torch.LongTensor(train_labels_flat[start_idx:end_idx])
            pickle.dump((train_feat_split_tensor, train_labels_split_tensor), file)
    with open("flatten_data_idx.txt", 'w') as file:
        for i in train_flat_idx:
            file.write("{} ".format(i))

train_feat_split_list = []
train_labels_split_list = []
for i in tqdm(range(load_split)):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    with open(pickle_filename, 'rb') as file:
        train_feat_split, train_labels_split = pickle.load(file)
        train_feat_split_list.append(train_feat_split)
        train_labels_split_list.append(train_labels_split)
with open("flatten_data_idx.txt", 'r') as file:
    train_flat_idx = [int(a) for line in file for a in line.split()]

train_feat_tensor = torch.cat(train_feat_split_list, dim=0)
train_labels_tensor = torch.cat(train_labels_split_list, dim=0)
print(train_feat_tensor.shape)
print(train_labels_tensor.shape)
print(len(train_flat_idx))
print(train_flat_idx[:10])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# torch.Size([2860789, 400])
# torch.Size([2860789])
# 7076
# [0, 260, 465, 793, 1054, 1687, 5923, 7216, 7288, 7338]

# %% [markdown]
# Create dataset

# %%
from torch.utils.data import Dataset, DataLoader, Subset
from torch._utils import _accumulate

class MyDataset(Dataset):
    
    def __init__(self, features, labels, indices):
        self.features = features
        self.labels = labels
        self.indices = indices
        self.len = len(self.indices) - 1

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        return (self.features[self.indices[idx]:self.indices[idx+1]], self.labels[self.indices[idx]])

my_dataset = MyDataset(train_feat_tensor, train_labels_tensor, train_flat_idx)

# %% [markdown]
# Split dataset

# %%
tot_len = len(my_dataset)
print("Number of training data: {}".format(tot_len))

train_split_size = 0.85
lengths = [int(tot_len*train_split_size), tot_len - int(tot_len*train_split_size)]

train_dataset, val_dataset = torch.utils.data.random_split(my_dataset, lengths)
# Out:
# Number of training data: 7075

# %% [markdown]
# Define training routine

# %%
import time
import copy

import copy
def train_val(num_epoch, dataloader_dict, model, loss, optimizer, print_epoch=True, device=None):
    val_acc_history = []
    val_loss_history = []
    train_acc_history = []
    train_loss_history = []
    best_acc = 0.0
    best_model_weights = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epoch):
        since = time.time()
        if print_epoch:
            print("Epoch {}/{}".format(epoch+1, num_epoch))
            print("-----------")
        
        for phase in ["train", "val"]:
            if phase == "train":
                model.train()
            else :
                model.eval()
            total_loss = 0.0
            total_correct = 0.0
            for X, y, batch_len in dataloader_dict[phase]:
                if device is not None:
                    X = X.to(device)
                    y = y.to(device)
                with torch.set_grad_enabled(phase == "train"):
                    y_tilde = model(X)
                    L = loss(y_tilde, y)
                    if phase == "train":
                        optimizer.zero_grad()
                        L.backward()
                        optimizer.step()
                y_tilde_label = torch.argmax(y_tilde, dim=1)
                num_correct = torch.sum((y_tilde_label == y))
                
                total_loss += L.item() * batch_len
                total_correct += num_correct.item()
            
            epoch_loss = total_loss / len(dataloader_dict[phase].dataset)
            epoch_acc = (total_correct / len(dataloader_dict[phase].dataset)) * 100
            
            if phase == "val":
                val_loss_history.append(epoch_loss)
                val_acc_history.append(epoch_acc)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_weights = copy.deepcopy(model.state_dict())
            if phase == "train":
                train_loss_history.append(epoch_loss)
                train_acc_history.append(epoch_acc)

            if print_epoch:
                print("{} | Loss : {:.4f}  Acc : {:.2f}%".format(phase.capitalize().ljust(5), epoch_loss, epoch_acc))
        
        print("Time elapsed : {:.2f} s".format(time.time() - since))
        print()
    
    model.load_state_dict(best_model_weights)
    return model, (val_acc_history, val_loss_history, train_acc_history, train_loss_history)

# %% [markdown]
# Define model

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.dropout1 = nn.Dropout(p=0.2)
        self.num_layers = 2
        self.lstm = nn.LSTM(400, 512, batch_first=True, num_layers=self.num_layers, dropout=0.5)
        self.dropout2 = nn.Dropout(p=0.5)
        self.linear = nn.Linear(512*(2+self.num_layers), 47)
        self.padding_value = 0
    def forward(self, x):
        x_pad, lengths = pad_packed_sequence(x, batch_first=True, padding_value=self.padding_value)
        x_pad = self.dropout1(x_pad)
        x = pack_padded_sequence(x_pad, lengths, batch_first=True, enforce_sorted=False)
        
        h, (h_last, c) = self.lstm(x)
        
        h_pad, lengths = pad_packed_sequence(h, batch_first=True, padding_value=self.padding_value)
        h_avg_pool = torch.sum(h_pad, 1) / (torch.sum((h_pad != self.padding_value), 1) + 1e-5)
        h_max_pool = torch.max(h_pad, 1)[0]
        x = torch.cat((*(h_last.unbind()), h_avg_pool, h_max_pool), 1)
        
        x = self.dropout2(x)
        
        x = self.linear(x)
        return x

model = Model()
for param in model.parameters():
    print(type(param.data), param.size())
# Out:
# <class 'torch.Tensor'> torch.Size([2048, 400])
# <class 'torch.Tensor'> torch.Size([2048, 512])
# <class 'torch.Tensor'> torch.Size([2048])
# <class 'torch.Tensor'> torch.Size([2048])
# <class 'torch.Tensor'> torch.Size([2048, 512])
# <class 'torch.Tensor'> torch.Size([2048, 512])
# <class 'torch.Tensor'> torch.Size([2048])
# <class 'torch.Tensor'> torch.Size([2048])
# <class 'torch.Tensor'> torch.Size([47, 2048])
# <class 'torch.Tensor'> torch.Size([47])

# %% [markdown]
# Create DataLoader

# %%
def collate(batch_data):
    features = []
    labels = []
    for feature, label in batch_data:
        features.append(feature)
        labels.append(label)
    return (pack_sequence(features, enforce_sorted=False), torch.tensor(labels), len(batch_data))

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)

# %% [markdown]
# Start training

# %%
my_model = Model()
my_model.to(dev)
loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(my_model.parameters())

trained_model, acc = train_val(100, {"train": train_loader, "val": val_loader}, my_model, loss, optimizer, device=dev)
# Out:
# Epoch 1/100
# -----------
# Train | Loss : 2.9653  Acc : 20.79%
# Val   | Loss : 2.4714  Acc : 30.32%
# Time elapsed : 277.20 s
#
# Epoch 2/100
# -----------
# Train | Loss : 2.2590  Acc : 34.41%
# Val   | Loss : 2.0251  Acc : 36.25%
# Time elapsed : 287.81 s
#
# Epoch 3/100
# -----------
# Train | Loss : 1.9332  Acc : 42.24%
# Val   | Loss : 1.8100  Acc : 43.69%
# Time elapsed : 304.04 s
#
# Epoch 4/100
# -----------
# Train | Loss : 1.7126  Acc : 47.16%
# Val   | Loss : 1.7671  Acc : 46.61%
# Time elapsed : 308.10 s
#
# Epoch 5/100
# -----------
# Train | Loss : 1.5678  Acc : 51.67%
# Val   | Loss : 1.6696  Acc : 48.49%
# Time elapsed : 300.66 s
#
# Epoch 6/100
# -----------
# Train | Loss : 1.4635  Acc : 53.50%
# Val   | Loss : 1.5734  Acc : 49.25%
# Time elapsed : 303.09 s
#
# Epoch 7/100
# -----------
# Train | Loss : 1.3616  Acc : 56.71%
# Val   | Loss : 1.3363  Acc : 57.34%
# Time elapsed : 289.03 s
#
# Epoch 8/100
# -----------
# Train | Loss : 1.2673  Acc : 58.92%
# Val   | Loss : 1.3758  Acc : 56.50%
# Time elapsed : 295.39 s
#
# Epoch 9/100
# -----------
# Train | Loss : 1.1929  Acc : 62.61%
# Val   | Loss : 1.3774  Acc : 56.40%
# Time elapsed : 292.02 s
#
# Epoch 10/100
# -----------
# Train | Loss : 1.1429  Acc : 62.95%
# Val   | Loss : 1.3342  Acc : 55.65%
# Time elapsed : 290.70 s
#
# Epoch 11/100
# -----------
# Train | Loss : 1.0750  Acc : 65.19%
# Val   | Loss : 1.2167  Acc : 61.68%
# Time elapsed : 280.44 s
#
# Epoch 12/100
# -----------
# Train | Loss : 1.0122  Acc : 67.24%
# Val   | Loss : 1.1389  Acc : 62.43%
# Time elapsed : 281.79 s
#
# Epoch 13/100
# -----------
# Train | Loss : 0.9120  Acc : 69.18%
# Val   | Loss : 1.1536  Acc : 62.34%
# Time elapsed : 302.31 s
#
# Epoch 14/100
# -----------
# Train | Loss : 0.8895  Acc : 70.51%
# Val   | Loss : 1.1045  Acc : 64.69%
# Time elapsed : 303.31 s
#
# Epoch 15/100
# -----------
# Train | Loss : 0.8506  Acc : 71.46%
# Val   | Loss : 1.1120  Acc : 63.75%
# Time elapsed : 285.25 s
#
# Epoch 16/100
# -----------
# Train | Loss : 0.7713  Acc : 74.04%
# Val   | Loss : 1.0443  Acc : 65.35%
# Time elapsed : 281.99 s
#
# Epoch 17/100
# -----------
# Train | Loss : 0.7479  Acc : 74.22%
# Val   | Loss : 1.0760  Acc : 64.22%
# Time elapsed : 292.48 s
#
# Epoch 18/100
# -----------
# Train | Loss : 0.6802  Acc : 76.97%
# Val   | Loss : 1.0426  Acc : 65.73%
# Time elapsed : 290.64 s
#
# Epoch 19/100
# -----------
# Train | Loss : 0.6720  Acc : 77.10%
# Val   | Loss : 1.1078  Acc : 66.57%
# Time elapsed : 282.49 s
#
# Epoch 20/100
# -----------
# Train | Loss : 0.6742  Acc : 77.13%
# Val   | Loss : 1.0538  Acc : 67.51%
# Time elapsed : 285.59 s
#
# Epoch 21/100
# -----------
# Train | Loss : 0.6287  Acc : 78.41%
# Val   | Loss : 1.1389  Acc : 65.54%
# Time elapsed : 279.59 s
#
# Epoch 22/100
# -----------
# Train | Loss : 0.5992  Acc : 79.56%
# Val   | Loss : 1.0858  Acc : 65.35%
# Time elapsed : 282.54 s
#
# Epoch 23/100
# -----------
# Train | Loss : 0.4922  Acc : 83.10%
# Val   | Loss : 1.0466  Acc : 68.17%
# Time elapsed : 281.67 s
#
# Epoch 24/100
# -----------
# Train | Loss : 0.4725  Acc : 83.74%
# Val   | Loss : 1.0513  Acc : 68.36%
# Time elapsed : 285.17 s
#
# Epoch 25/100
# -----------
# Train | Loss : 0.4593  Acc : 84.22%
# Val   | Loss : 1.0086  Acc : 69.11%
# Time elapsed : 282.20 s
#
# Epoch 26/100
# -----------
# Train | Loss : 0.4359  Acc : 85.25%
# Val   | Loss : 1.0513  Acc : 68.17%
# Time elapsed : 284.54 s
#
# Epoch 27/100
# -----------
# Train | Loss : 0.4354  Acc : 84.97%
# Val   | Loss : 1.1000  Acc : 69.68%
# Time elapsed : 289.47 s
#
# Epoch 28/100
# -----------
# Train | Loss : 0.4313  Acc : 84.55%
# Val   | Loss : 1.1549  Acc : 65.63%
# Time elapsed : 289.12 s
#
# Epoch 29/100
# -----------
# Train | Loss : 0.4479  Acc : 84.40%
# Val   | Loss : 1.0173  Acc : 70.15%
# Time elapsed : 286.80 s
#
# Epoch 30/100
# -----------
# Train | Loss : 0.4140  Acc : 85.88%
# Val   | Loss : 1.0549  Acc : 69.96%
# Time elapsed : 276.57 s
#
# Epoch 31/100
# -----------
# Train | Loss : 0.3233  Acc : 88.86%
# Val   | Loss : 1.0672  Acc : 67.70%
# Time elapsed : 286.07 s
#
# Epoch 32/100
# -----------
# Train | Loss : 0.3666  Acc : 87.19%
# Val   | Loss : 1.0586  Acc : 69.96%
# Time elapsed : 291.03 s
#
# Epoch 33/100
# -----------
# Train | Loss : 0.3491  Acc : 87.66%
# Val   | Loss : 1.1136  Acc : 68.27%
# Time elapsed : 284.62 s
#
# Epoch 34/100
# -----------
# Train | Loss : 0.3306  Acc : 89.04%
# Val   | Loss : 1.0599  Acc : 69.40%
# Time elapsed : 285.73 s
#
# Epoch 35/100
# -----------
# Train | Loss : 0.3041  Acc : 89.69%
# Val   | Loss : 1.1566  Acc : 67.61%
# Time elapsed : 285.90 s
#
# Epoch 36/100
# -----------
# Train | Loss : 0.2812  Acc : 90.00%
# Val   | Loss : 1.1634  Acc : 67.51%
# Time elapsed : 280.40 s
#
# Epoch 37/100
# -----------
# Train | Loss : 0.3055  Acc : 89.06%
# Val   | Loss : 1.1326  Acc : 69.40%
# Time elapsed : 275.66 s
#
# Epoch 38/100
# -----------
# Train | Loss : 0.3043  Acc : 89.76%
# Val   | Loss : 1.1878  Acc : 67.33%
# Time elapsed : 274.85 s
#
# Epoch 39/100
# -----------
# Train | Loss : 0.2867  Acc : 89.91%
# Val   | Loss : 1.1168  Acc : 68.93%
# Time elapsed : 280.45 s
#
# Epoch 40/100
# -----------
# Train | Loss : 0.2363  Acc : 91.37%
# Val   | Loss : 1.2986  Acc : 67.04%
# Time elapsed : 281.61 s
#
# Epoch 41/100
# -----------
# Train | Loss : 0.3444  Acc : 88.34%
# Val   | Loss : 1.0987  Acc : 68.83%
# Time elapsed : 283.45 s
#
# Epoch 42/100
# -----------
# Train | Loss : 0.3145  Acc : 88.64%
# Val   | Loss : 1.1886  Acc : 68.74%
# Time elapsed : 288.01 s
#
# Epoch 43/100
# -----------
# Train | Loss : 0.2956  Acc : 89.62%
# Val   | Loss : 1.0998  Acc : 70.81%
# Time elapsed : 286.84 s
#
# Epoch 44/100
# -----------
# Train | Loss : 0.2736  Acc : 90.64%
# Val   | Loss : 1.0572  Acc : 72.22%
# Time elapsed : 282.95 s
#
# Epoch 45/100
# -----------
# Train | Loss : 0.2253  Acc : 92.02%
# Val   | Loss : 1.1624  Acc : 70.34%
# Time elapsed : 281.84 s
#
# Epoch 46/100
# -----------
# Train | Loss : 0.2319  Acc : 92.00%
# Val   | Loss : 1.1678  Acc : 69.59%
# Time elapsed : 281.44 s
#
# Epoch 47/100
# -----------
# Train | Loss : 0.2156  Acc : 92.85%
# Val   | Loss : 1.1384  Acc : 69.40%
# Time elapsed : 286.32 s
#
# Epoch 48/100
# -----------
# Train | Loss : 0.2296  Acc : 92.17%
# Val   | Loss : 1.1273  Acc : 70.90%
# Time elapsed : 286.65 s
#
# Epoch 49/100
# -----------
# Train | Loss : 0.2085  Acc : 92.83%
# Val   | Loss : 1.1796  Acc : 69.02%
# Time elapsed : 287.08 s
#
# Epoch 50/100
# -----------
# Train | Loss : 0.2462  Acc : 91.42%
# Val   | Loss : 1.1334  Acc : 71.00%
# Time elapsed : 289.79 s
#
# Epoch 51/100
# -----------
# Train | Loss : 0.1836  Acc : 93.86%
# Val   | Loss : 1.1420  Acc : 71.37%
# Time elapsed : 284.56 s
#
# Epoch 52/100
# -----------
# Train | Loss : 0.1779  Acc : 93.91%
# Val   | Loss : 1.1111  Acc : 72.79%
# Time elapsed : 284.40 s
#
# Epoch 53/100
# -----------
# Train | Loss : 0.1553  Acc : 94.68%
# Val   | Loss : 1.1498  Acc : 71.75%
# Time elapsed : 283.88 s
#
# Epoch 54/100
# -----------
# Train | Loss : 0.2007  Acc : 93.11%
# Val   | Loss : 1.1732  Acc : 71.00%
# Time elapsed : 280.78 s
#
# Epoch 55/100
# -----------
# Train | Loss : 0.1793  Acc : 94.05%
# Val   | Loss : 1.2145  Acc : 72.50%
# Time elapsed : 290.00 s
#
# Epoch 56/100
# -----------
# Train | Loss : 0.2017  Acc : 93.10%
# Val   | Loss : 1.1041  Acc : 71.94%
# Time elapsed : 279.37 s
#
# Epoch 57/100
# -----------
# Train | Loss : 0.2003  Acc : 93.28%
# Val   | Loss : 1.1774  Acc : 71.28%
# Time elapsed : 296.28 s
#
# Epoch 58/100
# -----------
# Train | Loss : 0.2024  Acc : 92.68%
# Val   | Loss : 1.1412  Acc : 71.19%
# Time elapsed : 286.44 s
#
# Epoch 59/100
# -----------
# Train | Loss : 0.1907  Acc : 93.63%
# Val   | Loss : 1.1355  Acc : 70.81%
# Time elapsed : 285.20 s
#
# Epoch 60/100
# -----------
# Train | Loss : 0.1512  Acc : 94.73%
# Val   | Loss : 1.2350  Acc : 70.15%
# Time elapsed : 287.60 s
#
# Epoch 61/100
# -----------
# Train | Loss : 0.1551  Acc : 94.93%
# Val   | Loss : 1.2259  Acc : 68.27%
# Time elapsed : 288.72 s
#
# Epoch 62/100
# -----------
# Train | Loss : 0.1602  Acc : 94.20%
# Val   | Loss : 1.2628  Acc : 71.85%
# Time elapsed : 284.63 s
#
# Epoch 63/100
# -----------
# Train | Loss : 0.1903  Acc : 93.71%
# Val   | Loss : 1.2004  Acc : 71.56%
# Time elapsed : 278.82 s
#
# Epoch 64/100
# -----------
# Train | Loss : 0.1786  Acc : 93.95%
# Val   | Loss : 1.2486  Acc : 70.72%
# Time elapsed : 280.06 s
#
# Epoch 65/100
# -----------
# Train | Loss : 0.1951  Acc : 93.30%
# Val   | Loss : 1.2076  Acc : 71.09%
# Time elapsed : 284.59 s
#
# Epoch 66/100
# -----------
# Train | Loss : 0.1788  Acc : 93.88%
# Val   | Loss : 1.2332  Acc : 71.00%
# Time elapsed : 277.48 s
#
# Epoch 67/100
# -----------
# Train | Loss : 0.1648  Acc : 94.50%
# Val   | Loss : 1.2507  Acc : 70.06%
# Time elapsed : 280.63 s
#
# Epoch 68/100
# -----------
# Train | Loss : 0.1646  Acc : 94.40%
# Val   | Loss : 1.2704  Acc : 70.43%
# Time elapsed : 273.95 s
#
# Epoch 69/100
# -----------
# Train | Loss : 0.1714  Acc : 94.15%
# Val   | Loss : 1.2616  Acc : 70.15%
# Time elapsed : 280.64 s
#
# Epoch 70/100
# -----------
# Train | Loss : 0.1400  Acc : 95.38%
# Val   | Loss : 1.1750  Acc : 71.85%
# Time elapsed : 279.51 s
#
# Epoch 71/100
# -----------
# Train | Loss : 0.1349  Acc : 95.19%
# Val   | Loss : 1.2001  Acc : 72.13%
# Time elapsed : 276.04 s
#
# Epoch 72/100
# -----------
# Train | Loss : 0.1484  Acc : 95.14%
# Val   | Loss : 1.2968  Acc : 70.62%
# Time elapsed : 276.53 s
#
# Epoch 73/100
# -----------
# Train | Loss : 0.1915  Acc : 93.70%
# Val   | Loss : 1.2475  Acc : 71.94%
# Time elapsed : 279.41 s
#
# Epoch 74/100
# -----------
# Train | Loss : 0.2031  Acc : 93.36%
# Val   | Loss : 1.2647  Acc : 70.53%
# Time elapsed : 281.80 s
#
# Epoch 75/100
# -----------
# Train | Loss : 0.1717  Acc : 94.23%
# Val   | Loss : 1.1947  Acc : 72.79%
# Time elapsed : 277.56 s
#
# Epoch 76/100
# -----------
# Train | Loss : 0.1309  Acc : 95.49%
# Val   | Loss : 1.1771  Acc : 71.94%
# Time elapsed : 279.05 s
#
# Epoch 77/100
# -----------
# Train | Loss : 0.1114  Acc : 96.11%
# Val   | Loss : 1.2005  Acc : 73.54%
# Time elapsed : 277.65 s
#
# Epoch 78/100
# -----------
# Train | Loss : 0.0927  Acc : 96.87%
# Val   | Loss : 1.1658  Acc : 74.29%
# Time elapsed : 277.17 s
#
# Epoch 79/100
# -----------
# Train | Loss : 0.1029  Acc : 96.67%
# Val   | Loss : 1.2240  Acc : 72.13%
# Time elapsed : 275.73 s
#
# Epoch 80/100
# -----------
# Train | Loss : 0.1342  Acc : 95.34%
# Val   | Loss : 1.2506  Acc : 72.32%
# Time elapsed : 275.95 s
#
# Epoch 81/100
# -----------
# Train | Loss : 0.1286  Acc : 95.68%
# Val   | Loss : 1.3625  Acc : 71.19%
# Time elapsed : 272.86 s
#
# Epoch 82/100
# -----------
# Train | Loss : 0.1079  Acc : 96.46%
# Val   | Loss : 1.3821  Acc : 71.56%
# Time elapsed : 272.18 s
#
# Epoch 83/100
# -----------
# Train | Loss : 0.1953  Acc : 93.61%
# Val   | Loss : 1.3229  Acc : 70.24%
# Time elapsed : 273.25 s
#
# Epoch 84/100
# -----------
# Train | Loss : 0.1441  Acc : 94.99%
# Val   | Loss : 1.2941  Acc : 70.81%
# Time elapsed : 270.10 s
#
# Epoch 85/100
# -----------
# Train | Loss : 0.1882  Acc : 93.55%
# Val   | Loss : 1.3790  Acc : 69.21%
# Time elapsed : 273.76 s
#
# Epoch 86/100
# -----------
# Train | Loss : 0.1750  Acc : 94.00%
# Val   | Loss : 1.2904  Acc : 70.72%
# Time elapsed : 270.72 s
#
# Epoch 87/100
# -----------
# Train | Loss : 0.1157  Acc : 96.24%
# Val   | Loss : 1.2701  Acc : 71.85%
# Time elapsed : 276.10 s
#
# Epoch 88/100
# -----------
# Train | Loss : 0.1433  Acc : 95.53%
# Val   | Loss : 1.3035  Acc : 71.19%
# Time elapsed : 273.07 s
#
# Epoch 89/100
# -----------
# Train | Loss : 0.1720  Acc : 94.18%
# Val   | Loss : 1.2991  Acc : 71.94%
# Time elapsed : 274.11 s
#
# Epoch 90/100
# -----------
# Train | Loss : 0.1265  Acc : 95.83%
# Val   | Loss : 1.2095  Acc : 72.60%
# Time elapsed : 275.22 s
#
# Epoch 91/100
# -----------
# Train | Loss : 0.1122  Acc : 96.06%
# Val   | Loss : 1.2138  Acc : 72.03%
# Time elapsed : 269.92 s
#
# Epoch 92/100
# -----------
# Train | Loss : 0.1129  Acc : 96.17%
# Val   | Loss : 1.2406  Acc : 71.94%
# Time elapsed : 268.37 s
#
# Epoch 93/100
# -----------
# Train | Loss : 0.1376  Acc : 95.83%
# Val   | Loss : 1.5568  Acc : 66.10%
# Time elapsed : 273.66 s
#
# Epoch 94/100
# -----------
# Train | Loss : 0.1516  Acc : 94.96%
# Val   | Loss : 1.3344  Acc : 71.56%
# Time elapsed : 273.78 s
#
# Epoch 95/100
# -----------
# Train | Loss : 0.2679  Acc : 91.70%
# Val   | Loss : 1.3809  Acc : 68.64%
# Time elapsed : 269.92 s
#
# Epoch 96/100
# -----------
# Train | Loss : 0.2296  Acc : 92.33%
# Val   | Loss : 1.3166  Acc : 71.56%
# Time elapsed : 274.17 s
#
# Epoch 97/100
# -----------
# Train | Loss : 0.2606  Acc : 92.30%
# Val   | Loss : 1.5139  Acc : 67.04%
# Time elapsed : 274.98 s
#
# Epoch 98/100
# -----------
# Train | Loss : 0.3008  Acc : 90.92%
# Val   | Loss : 1.4104  Acc : 69.30%
# Time elapsed : 275.20 s
#
# Epoch 99/100
# -----------
# Train | Loss : 0.1782  Acc : 93.80%
# Val   | Loss : 1.2758  Acc : 71.47%
# Time elapsed : 271.88 s
#
# Epoch 100/100
# -----------
# Train | Loss : 0.1662  Acc : 94.35%
# Val   | Loss : 1.3800  Acc : 71.09%
# Time elapsed : 272.53 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.figure(figsize=(18, 5))
epoch_num = range(1, 101)
plt.subplot(1, 2, 1)
plt.title('Accuracy')
plt.ylim(0, 110)
plt.grid(True)
plt.plot(epoch_num, acc[2], color="blue")
plt.plot(epoch_num, acc[0], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])
plt.subplot(1, 2, 2)
plt.title('Loss')
plt.ylim(0, 3)
plt.grid(True)
plt.plot(epoch_num, acc[3], color="blue")
plt.plot(epoch_num, acc[1], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])

# %%
print(max(acc[0]))
# Out:
# 74.29378531073446

# %%
def set_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
set_lr(optimizer, 0.0001)
trained_model_tuning, acc_tuning = train_val(50, {"train": train_loader, "val": val_loader}, trained_model, loss, optimizer, device=dev)
# Out:
# Epoch 1/50
# -----------
# Train | Loss : 0.0556  Acc : 98.19%
# Val   | Loss : 1.0776  Acc : 75.61%
# Time elapsed : 274.76 s
#
# Epoch 2/50
# -----------
# Train | Loss : 0.0410  Acc : 98.90%
# Val   | Loss : 1.0775  Acc : 75.80%
# Time elapsed : 275.13 s
#
# Epoch 3/50
# -----------
# Train | Loss : 0.0388  Acc : 98.80%
# Val   | Loss : 1.0564  Acc : 76.18%
# Time elapsed : 267.98 s
#
# Epoch 4/50
# -----------
# Train | Loss : 0.0275  Acc : 99.19%
# Val   | Loss : 1.0513  Acc : 76.18%
# Time elapsed : 271.43 s
#
# Epoch 5/50
# -----------
# Train | Loss : 0.0287  Acc : 99.22%
# Val   | Loss : 1.0500  Acc : 76.37%
# Time elapsed : 273.84 s
#
# Epoch 6/50
# -----------
# Train | Loss : 0.0304  Acc : 99.15%
# Val   | Loss : 1.0439  Acc : 75.89%
# Time elapsed : 271.52 s
#
# Epoch 7/50
# -----------
# Train | Loss : 0.0280  Acc : 99.19%
# Val   | Loss : 1.0655  Acc : 76.08%
# Time elapsed : 267.88 s
#
# Epoch 8/50
# -----------
# Train | Loss : 0.0237  Acc : 99.37%
# Val   | Loss : 1.0854  Acc : 76.37%
# Time elapsed : 275.81 s
#
# Epoch 9/50
# -----------
# Train | Loss : 0.0220  Acc : 99.37%
# Val   | Loss : 1.0775  Acc : 75.89%
# Time elapsed : 272.74 s
#
# Epoch 10/50
# -----------
# Train | Loss : 0.0212  Acc : 99.48%
# Val   | Loss : 1.0774  Acc : 76.08%
# Time elapsed : 274.71 s
#
# Epoch 11/50
# -----------
# Train | Loss : 0.0185  Acc : 99.58%
# Val   | Loss : 1.0792  Acc : 75.24%
# Time elapsed : 268.92 s
#
# Epoch 12/50
# -----------
# Train | Loss : 0.0176  Acc : 99.55%
# Val   | Loss : 1.1060  Acc : 75.71%
# Time elapsed : 273.03 s
#
# Epoch 13/50
# -----------
# Train | Loss : 0.0196  Acc : 99.40%
# Val   | Loss : 1.0765  Acc : 76.55%
# Time elapsed : 273.22 s
#
# Epoch 14/50
# -----------
# Train | Loss : 0.0154  Acc : 99.67%
# Val   | Loss : 1.0846  Acc : 76.84%
# Time elapsed : 272.49 s
#
# Epoch 15/50
# -----------
# Train | Loss : 0.0176  Acc : 99.43%
# Val   | Loss : 1.0782  Acc : 76.46%
# Time elapsed : 270.76 s
#
# Epoch 16/50
# -----------
# Train | Loss : 0.0210  Acc : 99.43%
# Val   | Loss : 1.0967  Acc : 76.18%
# Time elapsed : 270.47 s
#
# Epoch 17/50
# -----------
# Train | Loss : 0.0171  Acc : 99.52%
# Val   | Loss : 1.0881  Acc : 77.21%
# Time elapsed : 267.11 s
#
# Epoch 18/50
# -----------
# Train | Loss : 0.0132  Acc : 99.72%
# Val   | Loss : 1.0906  Acc : 75.89%
# Time elapsed : 273.65 s
#
# Epoch 19/50
# -----------
# Train | Loss : 0.0157  Acc : 99.60%
# Val   | Loss : 1.0992  Acc : 75.80%
# Time elapsed : 274.57 s
#
# Epoch 20/50
# -----------
# Train | Loss : 0.0155  Acc : 99.55%
# Val   | Loss : 1.0818  Acc : 76.27%
# Time elapsed : 272.30 s
#
# Epoch 21/50
# -----------
# Train | Loss : 0.0125  Acc : 99.72%
# Val   | Loss : 1.0767  Acc : 76.84%
# Time elapsed : 274.54 s
#
# Epoch 22/50
# -----------
# Train | Loss : 0.0135  Acc : 99.60%
# Val   | Loss : 1.1020  Acc : 76.93%
# Time elapsed : 274.51 s
#
# Epoch 23/50
# -----------
# Train | Loss : 0.0121  Acc : 99.80%
# Val   | Loss : 1.1088  Acc : 77.12%
# Time elapsed : 270.31 s
#
# Epoch 24/50
# -----------
# Train | Loss : 0.0117  Acc : 99.75%
# Val   | Loss : 1.1001  Acc : 76.46%
# Time elapsed : 272.75 s
#
# Epoch 25/50
# -----------
# Train | Loss : 0.0117  Acc : 99.73%
# Val   | Loss : 1.1154  Acc : 77.02%
# Time elapsed : 270.37 s
#
# Epoch 26/50
# -----------
# Train | Loss : 0.0101  Acc : 99.82%
# Val   | Loss : 1.1534  Acc : 76.65%
# Time elapsed : 275.15 s
#
# Epoch 27/50
# -----------
# Train | Loss : 0.0128  Acc : 99.60%
# Val   | Loss : 1.1282  Acc : 76.08%
# Time elapsed : 270.60 s
#
# Epoch 28/50
# -----------
# Train | Loss : 0.0086  Acc : 99.82%
# Val   | Loss : 1.1240  Acc : 76.18%
# Time elapsed : 271.25 s
#
# Epoch 29/50
# -----------
# Train | Loss : 0.0086  Acc : 99.83%
# Val   | Loss : 1.1248  Acc : 76.18%
# Time elapsed : 275.41 s
#
# Epoch 30/50
# -----------
# Train | Loss : 0.0094  Acc : 99.75%
# Val   | Loss : 1.1168  Acc : 76.65%
# Time elapsed : 269.17 s
#
# Epoch 31/50
# -----------
# Train | Loss : 0.0082  Acc : 99.82%
# Val   | Loss : 1.1430  Acc : 76.37%
# Time elapsed : 269.93 s
#
# Epoch 32/50
# -----------
# Train | Loss : 0.0100  Acc : 99.78%
# Val   | Loss : 1.1674  Acc : 75.89%
# Time elapsed : 274.77 s
#
# Epoch 33/50
# -----------
# Train | Loss : 0.0093  Acc : 99.77%
# Val   | Loss : 1.1619  Acc : 75.61%
# Time elapsed : 278.32 s
#
# Epoch 34/50
# -----------
# Train | Loss : 0.0092  Acc : 99.78%
# Val   | Loss : 1.1412  Acc : 76.18%
# Time elapsed : 274.63 s
#
# Epoch 35/50
# -----------
# Train | Loss : 0.0091  Acc : 99.80%
# Val   | Loss : 1.2254  Acc : 76.08%
# Time elapsed : 272.40 s
#
# Epoch 36/50
# -----------
# Train | Loss : 0.0081  Acc : 99.78%
# Val   | Loss : 1.1752  Acc : 76.65%
# Time elapsed : 271.52 s
#
# Epoch 37/50
# -----------
# Train | Loss : 0.0087  Acc : 99.78%
# Val   | Loss : 1.1676  Acc : 76.55%
# Time elapsed : 267.87 s
#
# Epoch 38/50
# -----------
# Train | Loss : 0.0084  Acc : 99.85%
# Val   | Loss : 1.1583  Acc : 76.74%
# Time elapsed : 273.58 s
#
# Epoch 39/50
# -----------
# Train | Loss : 0.0067  Acc : 99.87%
# Val   | Loss : 1.1957  Acc : 76.46%
# Time elapsed : 273.00 s
#
# Epoch 40/50
# -----------
# Train | Loss : 0.0079  Acc : 99.78%
# Val   | Loss : 1.1791  Acc : 75.52%
# Time elapsed : 271.44 s
#
# Epoch 41/50
# -----------
# Train | Loss : 0.0074  Acc : 99.82%
# Val   | Loss : 1.1744  Acc : 76.74%
# Time elapsed : 271.09 s
#
# Epoch 42/50
# -----------
# Train | Loss : 0.0070  Acc : 99.82%
# Val   | Loss : 1.1825  Acc : 76.84%
# Time elapsed : 274.32 s
#
# Epoch 43/50
# -----------
# Train | Loss : 0.0098  Acc : 99.80%
# Val   | Loss : 1.2094  Acc : 75.71%
# Time elapsed : 269.20 s
#
# Epoch 44/50
# -----------
# Train | Loss : 0.0062  Acc : 99.87%
# Val   | Loss : 1.1913  Acc : 75.99%
# Time elapsed : 274.49 s
#
# Epoch 45/50
# -----------
# Train | Loss : 0.0089  Acc : 99.75%
# Val   | Loss : 1.2359  Acc : 75.80%
# Time elapsed : 270.20 s
#
# Epoch 46/50
# -----------
# Train | Loss : 0.0078  Acc : 99.88%
# Val   | Loss : 1.1999  Acc : 75.42%
# Time elapsed : 268.16 s
#
# Epoch 47/50
# -----------
# Train | Loss : 0.0092  Acc : 99.77%
# Val   | Loss : 1.2157  Acc : 75.80%
# Time elapsed : 270.69 s
#
# Epoch 48/50
# -----------
# Train | Loss : 0.0075  Acc : 99.83%
# Val   | Loss : 1.2178  Acc : 76.18%
# Time elapsed : 273.55 s
#
# Epoch 49/50
# -----------
# Train | Loss : 0.0070  Acc : 99.82%
# Val   | Loss : 1.2113  Acc : 76.93%
# Time elapsed : 272.97 s
#
# Epoch 50/50
# -----------
# Train | Loss : 0.0067  Acc : 99.83%
# Val   | Loss : 1.1930  Acc : 76.18%
# Time elapsed : 275.38 s

# %%
print(max(acc_tuning[0]))
# Out:
# 77.21280602636534

# %%
set_lr(optimizer, 0.00001)
trained_model_tuning1, acc_tuning1 = train_val(50, {"train": train_loader, "val": val_loader}, trained_model_tuning, loss, optimizer, device=dev)
# Out:
# Epoch 1/50
# -----------
# Train | Loss : 0.0140  Acc : 99.73%
# Val   | Loss : 1.0901  Acc : 77.12%
# Time elapsed : 263.61 s
#
# Epoch 2/50
# -----------
# Train | Loss : 0.0150  Acc : 99.62%
# Val   | Loss : 1.0975  Acc : 77.31%
# Time elapsed : 276.32 s
#
# Epoch 3/50
# -----------
# Train | Loss : 0.0156  Acc : 99.67%
# Val   | Loss : 1.1023  Acc : 77.21%
# Time elapsed : 272.07 s
#
# Epoch 4/50
# -----------
# Train | Loss : 0.0154  Acc : 99.75%
# Val   | Loss : 1.1021  Acc : 76.93%
# Time elapsed : 271.93 s
#
# Epoch 5/50
# -----------
# Train | Loss : 0.0167  Acc : 99.55%
# Val   | Loss : 1.0991  Acc : 76.74%
# Time elapsed : 271.07 s
#
# Epoch 6/50
# -----------
# Train | Loss : 0.0106  Acc : 99.82%
# Val   | Loss : 1.0963  Acc : 76.65%
# Time elapsed : 272.51 s
#
# Epoch 7/50
# -----------
# Train | Loss : 0.0130  Acc : 99.72%
# Val   | Loss : 1.0921  Acc : 76.65%
# Time elapsed : 273.35 s
#
# Epoch 8/50
# -----------
# Train | Loss : 0.0129  Acc : 99.77%
# Val   | Loss : 1.0934  Acc : 76.74%
# Time elapsed : 272.37 s
#
# Epoch 9/50
# -----------
# Train | Loss : 0.0119  Acc : 99.75%
# Val   | Loss : 1.0981  Acc : 76.65%
# Time elapsed : 270.86 s
#
# Epoch 10/50
# -----------
# Train | Loss : 0.0141  Acc : 99.63%
# Val   | Loss : 1.0999  Acc : 76.65%
# Time elapsed : 274.97 s
#
# Epoch 11/50
# -----------
# Train | Loss : 0.0129  Acc : 99.68%
# Val   | Loss : 1.0974  Acc : 76.93%
# Time elapsed : 273.92 s
#
# Epoch 12/50
# -----------
# Train | Loss : 0.0109  Acc : 99.77%
# Val   | Loss : 1.0958  Acc : 76.37%
# Time elapsed : 268.02 s
#
# Epoch 13/50
# -----------
# Train | Loss : 0.0134  Acc : 99.62%
# Val   | Loss : 1.0915  Acc : 76.93%
# Time elapsed : 275.71 s
#
# Epoch 14/50
# -----------
# Train | Loss : 0.0137  Acc : 99.67%
# Val   | Loss : 1.0936  Acc : 76.65%
# Time elapsed : 270.34 s
#
# Epoch 15/50
# -----------
# Train | Loss : 0.0107  Acc : 99.78%
# Val   | Loss : 1.0968  Acc : 76.18%
# Time elapsed : 274.52 s
#
# Epoch 16/50
# -----------
# Train | Loss : 0.0123  Acc : 99.68%
# Val   | Loss : 1.0990  Acc : 76.18%
# Time elapsed : 278.77 s
#
# Epoch 17/50
# -----------
# Train | Loss : 0.0116  Acc : 99.75%
# Val   | Loss : 1.1001  Acc : 76.74%
# Time elapsed : 273.03 s
#
# Epoch 18/50
# -----------
# Train | Loss : 0.0109  Acc : 99.77%
# Val   | Loss : 1.0999  Acc : 76.74%
# Time elapsed : 275.00 s
#
# Epoch 19/50
# -----------
# Train | Loss : 0.0098  Acc : 99.87%
# Val   | Loss : 1.1019  Acc : 76.46%
# Time elapsed : 276.51 s
#
# Epoch 20/50
# -----------
# Train | Loss : 0.0132  Acc : 99.63%
# Val   | Loss : 1.0966  Acc : 76.27%
# Time elapsed : 275.72 s
#
# Epoch 21/50
# -----------
# Train | Loss : 0.0118  Acc : 99.78%
# Val   | Loss : 1.0941  Acc : 76.65%
# Time elapsed : 265.89 s
#
# Epoch 22/50
# -----------
# Train | Loss : 0.0134  Acc : 99.68%
# Val   | Loss : 1.0917  Acc : 76.65%
# Time elapsed : 273.49 s
#
# Epoch 23/50
# -----------
# Train | Loss : 0.0131  Acc : 99.73%
# Val   | Loss : 1.0936  Acc : 76.65%
# Time elapsed : 271.57 s
#
# Epoch 24/50
# -----------
# Train | Loss : 0.0106  Acc : 99.83%
# Val   | Loss : 1.0909  Acc : 76.84%
# Time elapsed : 273.98 s
#
# Epoch 25/50
# -----------
# Train | Loss : 0.0112  Acc : 99.75%
# Val   | Loss : 1.0919  Acc : 76.84%
# Time elapsed : 273.07 s
#
# Epoch 26/50
# -----------
# Train | Loss : 0.0114  Acc : 99.75%
# Val   | Loss : 1.0919  Acc : 76.84%
# Time elapsed : 277.70 s
#
# Epoch 27/50
# -----------
# Train | Loss : 0.0124  Acc : 99.73%
# Val   | Loss : 1.0946  Acc : 76.93%
# Time elapsed : 276.20 s
#
# Epoch 28/50
# -----------
# Train | Loss : 0.0110  Acc : 99.75%
# Val   | Loss : 1.0966  Acc : 76.46%
# Time elapsed : 272.74 s
#
# Epoch 29/50
# -----------
# Train | Loss : 0.0117  Acc : 99.68%
# Val   | Loss : 1.0947  Acc : 76.74%
# Time elapsed : 274.26 s
#
# Epoch 30/50
# -----------
# Train | Loss : 0.0117  Acc : 99.73%
# Val   | Loss : 1.0942  Acc : 76.74%
# Time elapsed : 268.28 s
#
# Epoch 31/50
# -----------
# Train | Loss : 0.0102  Acc : 99.75%
# Val   | Loss : 1.0949  Acc : 77.21%
# Time elapsed : 273.67 s
#
# Epoch 32/50
# -----------
# Train | Loss : 0.0099  Acc : 99.78%
# Val   | Loss : 1.0979  Acc : 77.12%
# Time elapsed : 272.61 s
#
# Epoch 33/50
# -----------
# Train | Loss : 0.0086  Acc : 99.82%
# Val   | Loss : 1.0941  Acc : 76.74%
# Time elapsed : 272.95 s
#
# Epoch 34/50
# -----------
# Train | Loss : 0.0121  Acc : 99.72%
# Val   | Loss : 1.0938  Acc : 76.74%
# Time elapsed : 276.24 s
#
# Epoch 35/50
# -----------
# Train | Loss : 0.0118  Acc : 99.73%
# Val   | Loss : 1.0935  Acc : 77.21%
# Time elapsed : 267.46 s
#
# Epoch 36/50
# -----------
# Train | Loss : 0.0104  Acc : 99.77%
# Val   | Loss : 1.0906  Acc : 77.21%
# Time elapsed : 263.65 s
#
# Epoch 37/50
# -----------
# Train | Loss : 0.0091  Acc : 99.82%
# Val   | Loss : 1.0933  Acc : 77.31%
# Time elapsed : 273.70 s
#
# Epoch 38/50
# -----------
# Train | Loss : 0.0091  Acc : 99.80%
# Val   | Loss : 1.0936  Acc : 77.31%
# Time elapsed : 275.81 s
#
# Epoch 39/50
# -----------
# Train | Loss : 0.0099  Acc : 99.85%
# Val   | Loss : 1.0978  Acc : 77.02%
# Time elapsed : 277.41 s
#
# Epoch 40/50
# -----------
# Train | Loss : 0.0100  Acc : 99.80%
# Val   | Loss : 1.0921  Acc : 77.31%
# Time elapsed : 274.30 s
#
# Epoch 41/50
# -----------
# Train | Loss : 0.0088  Acc : 99.83%
# Val   | Loss : 1.0926  Acc : 77.02%
# Time elapsed : 268.62 s
#
# Epoch 42/50
# -----------
# Train | Loss : 0.0114  Acc : 99.73%
# Val   | Loss : 1.0975  Acc : 76.65%
# Time elapsed : 267.54 s
#
# Epoch 43/50
# -----------
# Train | Loss : 0.0094  Acc : 99.80%
# Val   | Loss : 1.0979  Acc : 76.93%
# Time elapsed : 268.50 s
#
# Epoch 44/50
# -----------
# Train | Loss : 0.0085  Acc : 99.85%
# Val   | Loss : 1.0958  Acc : 77.31%
# Time elapsed : 274.41 s
#
# Epoch 45/50
# -----------
# Train | Loss : 0.0079  Acc : 99.87%
# Val   | Loss : 1.0986  Acc : 77.40%
# Time elapsed : 270.61 s
#
# Epoch 46/50
# -----------
# Train | Loss : 0.0103  Acc : 99.82%
# Val   | Loss : 1.0996  Acc : 77.12%
# Time elapsed : 274.09 s
#
# Epoch 47/50
# -----------
# Train | Loss : 0.0091  Acc : 99.78%
# Val   | Loss : 1.1057  Acc : 77.02%
# Time elapsed : 277.98 s
#
# Epoch 48/50
# -----------
# Train | Loss : 0.0077  Acc : 99.92%
# Val   | Loss : 1.1062  Acc : 77.21%
# Time elapsed : 272.93 s
#
# Epoch 49/50
# -----------
# Train | Loss : 0.0113  Acc : 99.78%
# Val   | Loss : 1.1059  Acc : 77.12%
# Time elapsed : 268.40 s
#
# Epoch 50/50
# -----------
# Train | Loss : 0.0101  Acc : 99.67%
# Val   | Loss : 1.1057  Acc : 77.31%
# Time elapsed : 273.99 s

# %%
print(max(acc_tuning1[0]))
# Out:
# 77.40112994350282
