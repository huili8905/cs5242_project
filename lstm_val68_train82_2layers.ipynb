# %% [markdown]
# ## Video Action Classification

# %%
import os
import pickle

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_packed_sequence, pack_sequence, pack_padded_sequence
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device : {}".format(dev))
# Out:
# Using device : cuda:0

# %% [markdown]
# Load dataset

# %%
# pickle_filename = 'data.pickle'

# if os.path.isfile(pickle_filename):
#     with open(pickle_filename, 'rb') as file:
#         train_data_feat, train_data_labels, test_data_feat = pickle.load(file)
# else:
#     from read_datasetBreakfast import load_data, read_mapping_dict

#     COMP_PATH = ''

#     ''' 
#     training to load train set
#     test to load test set
#     '''
#     train_split =  os.path.join(COMP_PATH, 'splits/train.split1.bundle') #Train Split
#     test_split  =  os.path.join(COMP_PATH, 'splits/test.split1.bundle') #Test Split
#     GT_folder   =  os.path.join(COMP_PATH, 'groundTruth/') #Ground Truth Labels for each training video 
#     DATA_folder =  os.path.join(COMP_PATH, 'data/') #Frame I3D features for all videos
#     mapping_loc =  os.path.join(COMP_PATH, 'splits/mapping_bf.txt') 

#     actions_dict = read_mapping_dict(mapping_loc)
#     train_data_feat, train_data_labels = load_data( train_split, actions_dict, GT_folder, DATA_folder, datatype = "training") #Get features and labels
#     test_data_feat = load_data( test_split, actions_dict, GT_folder, DATA_folder, datatype = "test") #Get features only
    
#     with open(pickle_filename, 'wb') as file:
#         pickle.dump((train_data_feat, train_data_labels, test_data_feat), file)

# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))

# %% [markdown]
# ```python
# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))
# > 1460
# > 1460
# > 252
# ```

# %% [markdown]
# Flatten dataset

# %%
# with open("training_segment.txt", 'r') as file:
#     training_segment = [[int(a) for a in line.split()] for line in file]

# # tot_segment_len = 0
# # n_segment_len = 0
# # max_segment_len = 0
# # min_segment_len = float("inf")

# train_feat_flat = []
# train_labels_flat = []
# train_flat_idx = []
# for video_idx, video_segments in enumerate(tqdm(training_segment)):
#     for i in range(len(video_segments)-1):
#         segment_len = video_segments[i+1] - video_segments[i]
# #         tot_segment_len += segment_len
# #         n_segment_len += 1
# #         if segment_len > max_segment_len:
# #             max_segment_len = segment_len
# #         if segment_len < min_segment_len:
# #             min_segment_len = segment_len
#         train_flat_idx.append(len(train_feat_flat))
#         train_feat_flat.extend(train_data_feat[video_idx][video_segments[i]:video_segments[i+1]])
#         train_labels_flat.extend([(train_data_labels[video_idx][i])-1]*segment_len)
# train_flat_idx.append(len(train_feat_flat))

# # avg_segment_len = tot_segment_len / n_segment_len
# # print(avg_segment_len, max_segment_len, min_segment_len)

# %% [markdown]
# ```python
# print(avg_segment_len, max_segment_len, min_segment_len)
# > 404.3518021201413 5791 8
# ```

# %% [markdown]
# Pickle (or load) flatten dataset

# %%
num_split = 10
load_split = 10

files_exist = []
for i in range(num_split):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    files_exist.append(os.path.isfile(pickle_filename))

if not all(files_exist):
    max_len = len(train_feat_flat)
    split_len = max_len//num_split
    for i in tqdm(range(num_split)):
        pickle_filename = "flatten_data_{}.pickle".format(i)
        start_idx = split_len*i
        end_idx = split_len*(i+1) if i < num_split-1 else max_len
        print(i, start_idx, end_idx)
        with open(pickle_filename, 'wb') as file:
            train_feat_split_tensor = torch.stack(train_feat_flat[start_idx:end_idx]).to(dtype=torch.float32)
            train_labels_split_tensor = torch.LongTensor(train_labels_flat[start_idx:end_idx])
            pickle.dump((train_feat_split_tensor, train_labels_split_tensor), file)
    with open("flatten_data_idx.txt", 'w') as file:
        for i in train_flat_idx:
            file.write("{} ".format(i))

train_feat_split_list = []
train_labels_split_list = []
for i in tqdm(range(load_split)):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    with open(pickle_filename, 'rb') as file:
        train_feat_split, train_labels_split = pickle.load(file)
        train_feat_split_list.append(train_feat_split)
        train_labels_split_list.append(train_labels_split)
with open("flatten_data_idx.txt", 'r') as file:
    train_flat_idx = [int(a) for line in file for a in line.split()]

train_feat_tensor = torch.cat(train_feat_split_list, dim=0)
train_labels_tensor = torch.cat(train_labels_split_list, dim=0)
print(train_feat_tensor.shape)
print(train_labels_tensor.shape)
print(len(train_flat_idx))
print(train_flat_idx[:10])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# torch.Size([2860789, 400])
# torch.Size([2860789])
# 7076
# [0, 260, 465, 793, 1054, 1687, 5923, 7216, 7288, 7338]

# %% [markdown]
# Define model

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.dropout1 = nn.Dropout(p=0.2)
        self.num_layers = 2
        self.lstm = nn.LSTM(400, 64, batch_first=True, num_layers=self.num_layers, dropout=0.5)
        self.dropout2 = nn.Dropout(p=0.5)
        self.linear = nn.Linear(64*(2+self.num_layers), 47)
        self.padding_value = 0
    def forward(self, x):
        x_pad, lengths = pad_packed_sequence(x, batch_first=True, padding_value=self.padding_value)
        x_pad = self.dropout1(x_pad)
        x = pack_padded_sequence(x_pad, lengths, batch_first=True, enforce_sorted=False)
        
        h, (h_last, c) = self.lstm(x)
        
        h_pad, lengths = pad_packed_sequence(h, batch_first=True, padding_value=self.padding_value)
        h_avg_pool = torch.sum(h_pad, 1) / (torch.sum((h_pad != self.padding_value), 1) + 1e-5)
        h_max_pool = torch.max(h_pad, 1)[0]
        x = torch.cat((*(h_last.unbind()), h_avg_pool, h_max_pool), 1)
        
        x = self.dropout2(x)
        
        x = self.linear(x)
        return x

model = Model()
for param in model.parameters():
    print(type(param.data), param.size())
# Out:
# <class 'torch.Tensor'> torch.Size([256, 400])
# <class 'torch.Tensor'> torch.Size([256, 64])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([256, 64])
# <class 'torch.Tensor'> torch.Size([256, 64])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([47, 256])
# <class 'torch.Tensor'> torch.Size([47])

# %% [markdown]
# Define training routine

# %%
import time
import copy

import copy
def train_val(num_epoch, dataloader_dict, model, loss, optimizer, print_epoch=True, device=None):
    val_acc_history = []
    val_loss_history = []
    train_acc_history = []
    train_loss_history = []
    best_acc = 0.0
    best_model_weights = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epoch):
        since = time.time()
        if print_epoch:
            print("Epoch {}/{}".format(epoch+1, num_epoch))
            print("-----------")
        
        for phase in ["train", "val"]:
            if phase == "train":
                model.train()
            else :
                model.eval()
            total_loss = 0.0
            total_correct = 0.0
            for X, y, batch_len in dataloader_dict[phase]:
                if device is not None:
                    X = X.to(device)
                    y = y.to(device)
                with torch.set_grad_enabled(phase == "train"):
                    y_tilde = model(X)
                    L = loss(y_tilde, y)
                    if phase == "train":
                        optimizer.zero_grad()
                        L.backward()
                        optimizer.step()
                y_tilde_label = torch.argmax(y_tilde, dim=1)
                num_correct = torch.sum((y_tilde_label == y))
                
                total_loss += L.item() * batch_len
                total_correct += num_correct.item()
            
            epoch_loss = total_loss / len(dataloader_dict[phase].dataset)
            epoch_acc = (total_correct / len(dataloader_dict[phase].dataset)) * 100
            
            if phase == "val":
                val_loss_history.append(epoch_loss)
                val_acc_history.append(epoch_acc)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_weights = copy.deepcopy(model.state_dict())
            if phase == "train":
                train_loss_history.append(epoch_loss)
                train_acc_history.append(epoch_acc)

            if print_epoch:
                print("{} | Loss : {:.4f}  Acc : {:.2f}%".format(phase.capitalize().ljust(5), epoch_loss, epoch_acc))
        
        print("Time elapsed : {:.2f} s".format(time.time() - since))
        print()
    
    model.load_state_dict(best_model_weights)
    return model, (val_acc_history, val_loss_history, train_acc_history, train_loss_history)

# %% [markdown]
# Create dataset

# %%
from torch.utils.data import Dataset, DataLoader, Subset
from torch._utils import _accumulate

class MyDataset(Dataset):
    
    def __init__(self, features, labels, indices):
        self.features = features
        self.labels = labels
        self.indices = indices
        self.len = len(self.indices) - 1

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        return (self.features[self.indices[idx]:self.indices[idx+1]], self.labels[self.indices[idx]])

my_dataset = MyDataset(train_feat_tensor, train_labels_tensor, train_flat_idx)

# %% [markdown]
# Split dataset

# %%
tot_len = len(my_dataset)
print("Number of training data: {}".format(tot_len))

train_split_size = 0.8
lengths = [int(tot_len*train_split_size), tot_len - int(tot_len*train_split_size)]

train_dataset, val_dataset = torch.utils.data.random_split(my_dataset, lengths)
# Out:
# Number of training data: 7075

# %% [markdown]
# Create DataLoader

# %%
def collate(batch_data):
    features = []
    labels = []
    for feature, label in batch_data:
        features.append(feature)
        labels.append(label)
    return (pack_sequence(features, enforce_sorted=False), torch.tensor(labels), len(batch_data))

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)

# %% [markdown]
# Start training

# %%
my_model = Model()
my_model.to(dev)
loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(my_model.parameters())

trained_model, acc = train_val(100, {"train": train_loader, "val": val_loader}, my_model, loss, optimizer, device=dev)
# Out:
# Epoch 1/100
# -----------
# Train | Loss : 3.4588  Acc : 10.95%
# Val   | Loss : 3.0949  Acc : 18.30%
# Time elapsed : 72.81 s
#
# Epoch 2/100
# -----------
# Train | Loss : 2.8585  Acc : 23.30%
# Val   | Loss : 2.5571  Acc : 27.14%
# Time elapsed : 74.43 s
#
# Epoch 3/100
# -----------
# Train | Loss : 2.5584  Acc : 28.46%
# Val   | Loss : 2.5930  Acc : 27.49%
# Time elapsed : 73.54 s
#
# Epoch 4/100
# -----------
# Train | Loss : 2.4181  Acc : 31.34%
# Val   | Loss : 2.2320  Acc : 34.06%
# Time elapsed : 73.44 s
#
# Epoch 5/100
# -----------
# Train | Loss : 2.2164  Acc : 35.32%
# Val   | Loss : 2.2688  Acc : 31.94%
# Time elapsed : 72.70 s
#
# Epoch 6/100
# -----------
# Train | Loss : 2.0894  Acc : 37.99%
# Val   | Loss : 1.9410  Acc : 40.64%
# Time elapsed : 73.16 s
#
# Epoch 7/100
# -----------
# Train | Loss : 2.0183  Acc : 40.18%
# Val   | Loss : 2.0149  Acc : 39.22%
# Time elapsed : 73.50 s
#
# Epoch 8/100
# -----------
# Train | Loss : 1.9779  Acc : 40.25%
# Val   | Loss : 1.8456  Acc : 44.31%
# Time elapsed : 74.20 s
#
# Epoch 9/100
# -----------
# Train | Loss : 1.8861  Acc : 42.49%
# Val   | Loss : 1.7832  Acc : 44.45%
# Time elapsed : 72.80 s
#
# Epoch 10/100
# -----------
# Train | Loss : 1.8349  Acc : 43.96%
# Val   | Loss : 1.7993  Acc : 45.30%
# Time elapsed : 72.58 s
#
# Epoch 11/100
# -----------
# Train | Loss : 1.7401  Acc : 46.68%
# Val   | Loss : 1.7651  Acc : 45.09%
# Time elapsed : 73.03 s
#
# Epoch 12/100
# -----------
# Train | Loss : 1.6797  Acc : 47.63%
# Val   | Loss : 1.6847  Acc : 48.06%
# Time elapsed : 72.32 s
#
# Epoch 13/100
# -----------
# Train | Loss : 1.6640  Acc : 48.73%
# Val   | Loss : 1.6188  Acc : 49.12%
# Time elapsed : 73.27 s
#
# Epoch 14/100
# -----------
# Train | Loss : 1.6172  Acc : 49.66%
# Val   | Loss : 1.6398  Acc : 49.82%
# Time elapsed : 72.17 s
#
# Epoch 15/100
# -----------
# Train | Loss : 1.5491  Acc : 52.08%
# Val   | Loss : 1.5182  Acc : 52.30%
# Time elapsed : 72.74 s
#
# Epoch 16/100
# -----------
# Train | Loss : 1.4996  Acc : 52.17%
# Val   | Loss : 1.4497  Acc : 54.77%
# Time elapsed : 74.83 s
#
# Epoch 17/100
# -----------
# Train | Loss : 1.4667  Acc : 54.06%
# Val   | Loss : 1.4977  Acc : 55.55%
# Time elapsed : 74.32 s
#
# Epoch 18/100
# -----------
# Train | Loss : 1.5026  Acc : 53.09%
# Val   | Loss : 1.6893  Acc : 48.62%
# Time elapsed : 74.29 s
#
# Epoch 19/100
# -----------
# Train | Loss : 1.4622  Acc : 53.85%
# Val   | Loss : 1.5203  Acc : 51.66%
# Time elapsed : 72.75 s
#
# Epoch 20/100
# -----------
# Train | Loss : 1.4121  Acc : 56.04%
# Val   | Loss : 1.4027  Acc : 56.61%
# Time elapsed : 73.21 s
#
# Epoch 21/100
# -----------
# Train | Loss : 1.3925  Acc : 55.23%
# Val   | Loss : 1.3678  Acc : 56.75%
# Time elapsed : 69.99 s
#
# Epoch 22/100
# -----------
# Train | Loss : 1.3661  Acc : 55.87%
# Val   | Loss : 1.4163  Acc : 53.92%
# Time elapsed : 69.91 s
#
# Epoch 23/100
# -----------
# Train | Loss : 1.3111  Acc : 58.04%
# Val   | Loss : 1.3995  Acc : 57.46%
# Time elapsed : 68.61 s
#
# Epoch 24/100
# -----------
# Train | Loss : 1.2765  Acc : 59.15%
# Val   | Loss : 1.3669  Acc : 57.46%
# Time elapsed : 69.32 s
#
# Epoch 25/100
# -----------
# Train | Loss : 1.2348  Acc : 59.93%
# Val   | Loss : 1.3901  Acc : 56.89%
# Time elapsed : 69.31 s
#
# Epoch 26/100
# -----------
# Train | Loss : 1.2295  Acc : 60.78%
# Val   | Loss : 1.3682  Acc : 58.09%
# Time elapsed : 66.89 s
#
# Epoch 27/100
# -----------
# Train | Loss : 1.2154  Acc : 60.34%
# Val   | Loss : 1.3636  Acc : 57.03%
# Time elapsed : 67.29 s
#
# Epoch 28/100
# -----------
# Train | Loss : 1.3000  Acc : 59.01%
# Val   | Loss : 1.3935  Acc : 55.34%
# Time elapsed : 66.65 s
#
# Epoch 29/100
# -----------
# Train | Loss : 1.1978  Acc : 61.43%
# Val   | Loss : 1.3568  Acc : 59.22%
# Time elapsed : 67.88 s
#
# Epoch 30/100
# -----------
# Train | Loss : 1.1744  Acc : 62.30%
# Val   | Loss : 1.3000  Acc : 59.01%
# Time elapsed : 67.17 s
#
# Epoch 31/100
# -----------
# Train | Loss : 1.2206  Acc : 60.78%
# Val   | Loss : 1.2844  Acc : 59.08%
# Time elapsed : 68.73 s
#
# Epoch 32/100
# -----------
# Train | Loss : 1.1025  Acc : 63.99%
# Val   | Loss : 1.2590  Acc : 60.21%
# Time elapsed : 67.90 s
#
# Epoch 33/100
# -----------
# Train | Loss : 1.1174  Acc : 64.28%
# Val   | Loss : 1.2461  Acc : 60.49%
# Time elapsed : 66.77 s
#
# Epoch 34/100
# -----------
# Train | Loss : 1.0782  Acc : 65.28%
# Val   | Loss : 1.2567  Acc : 60.14%
# Time elapsed : 65.97 s
#
# Epoch 35/100
# -----------
# Train | Loss : 1.0637  Acc : 65.62%
# Val   | Loss : 1.2301  Acc : 61.55%
# Time elapsed : 66.73 s
#
# Epoch 36/100
# -----------
# Train | Loss : 1.0532  Acc : 65.88%
# Val   | Loss : 1.2694  Acc : 60.00%
# Time elapsed : 67.19 s
#
# Epoch 37/100
# -----------
# Train | Loss : 1.0212  Acc : 66.57%
# Val   | Loss : 1.2307  Acc : 60.49%
# Time elapsed : 67.94 s
#
# Epoch 38/100
# -----------
# Train | Loss : 1.0124  Acc : 67.16%
# Val   | Loss : 1.2566  Acc : 60.92%
# Time elapsed : 67.69 s
#
# Epoch 39/100
# -----------
# Train | Loss : 1.0539  Acc : 65.18%
# Val   | Loss : 1.2479  Acc : 61.20%
# Time elapsed : 67.18 s
#
# Epoch 40/100
# -----------
# Train | Loss : 0.9680  Acc : 68.06%
# Val   | Loss : 1.2675  Acc : 60.49%
# Time elapsed : 68.57 s
#
# Epoch 41/100
# -----------
# Train | Loss : 0.9845  Acc : 67.79%
# Val   | Loss : 1.3493  Acc : 60.49%
# Time elapsed : 67.70 s
#
# Epoch 42/100
# -----------
# Train | Loss : 0.9581  Acc : 68.82%
# Val   | Loss : 1.2648  Acc : 61.91%
# Time elapsed : 66.50 s
#
# Epoch 43/100
# -----------
# Train | Loss : 0.9694  Acc : 68.22%
# Val   | Loss : 1.2698  Acc : 60.14%
# Time elapsed : 67.62 s
#
# Epoch 44/100
# -----------
# Train | Loss : 0.9423  Acc : 69.17%
# Val   | Loss : 1.1945  Acc : 63.18%
# Time elapsed : 67.68 s
#
# Epoch 45/100
# -----------
# Train | Loss : 0.8850  Acc : 71.06%
# Val   | Loss : 1.2128  Acc : 63.53%
# Time elapsed : 66.09 s
#
# Epoch 46/100
# -----------
# Train | Loss : 0.9397  Acc : 68.09%
# Val   | Loss : 1.2558  Acc : 61.06%
# Time elapsed : 66.26 s
#
# Epoch 47/100
# -----------
# Train | Loss : 0.9206  Acc : 70.05%
# Val   | Loss : 1.2085  Acc : 63.39%
# Time elapsed : 66.32 s
#
# Epoch 48/100
# -----------
# Train | Loss : 0.8725  Acc : 71.06%
# Val   | Loss : 1.1799  Acc : 62.33%
# Time elapsed : 65.88 s
#
# Epoch 49/100
# -----------
# Train | Loss : 0.8613  Acc : 71.31%
# Val   | Loss : 1.2247  Acc : 62.33%
# Time elapsed : 67.62 s
#
# Epoch 50/100
# -----------
# Train | Loss : 0.8512  Acc : 71.06%
# Val   | Loss : 1.1780  Acc : 63.46%
# Time elapsed : 67.22 s
#
# Epoch 51/100
# -----------
# Train | Loss : 0.8766  Acc : 70.05%
# Val   | Loss : 1.1530  Acc : 64.10%
# Time elapsed : 67.37 s
#
# Epoch 52/100
# -----------
# Train | Loss : 0.8520  Acc : 71.64%
# Val   | Loss : 1.2196  Acc : 63.46%
# Time elapsed : 66.10 s
#
# Epoch 53/100
# -----------
# Train | Loss : 0.7943  Acc : 73.00%
# Val   | Loss : 1.1940  Acc : 63.04%
# Time elapsed : 66.36 s
#
# Epoch 54/100
# -----------
# Train | Loss : 0.8032  Acc : 72.99%
# Val   | Loss : 1.1668  Acc : 64.10%
# Time elapsed : 68.68 s
#
# Epoch 55/100
# -----------
# Train | Loss : 0.7939  Acc : 73.76%
# Val   | Loss : 1.1448  Acc : 62.83%
# Time elapsed : 66.12 s
#
# Epoch 56/100
# -----------
# Train | Loss : 0.8296  Acc : 71.70%
# Val   | Loss : 1.2156  Acc : 62.83%
# Time elapsed : 68.32 s
#
# Epoch 57/100
# -----------
# Train | Loss : 0.7791  Acc : 73.41%
# Val   | Loss : 1.2480  Acc : 62.19%
# Time elapsed : 67.13 s
#
# Epoch 58/100
# -----------
# Train | Loss : 0.7903  Acc : 73.78%
# Val   | Loss : 1.3043  Acc : 62.61%
# Time elapsed : 67.39 s
#
# Epoch 59/100
# -----------
# Train | Loss : 0.7761  Acc : 74.63%
# Val   | Loss : 1.2329  Acc : 63.25%
# Time elapsed : 65.84 s
#
# Epoch 60/100
# -----------
# Train | Loss : 0.7770  Acc : 73.80%
# Val   | Loss : 1.2362  Acc : 64.38%
# Time elapsed : 68.30 s
#
# Epoch 61/100
# -----------
# Train | Loss : 0.7167  Acc : 76.47%
# Val   | Loss : 1.1890  Acc : 62.69%
# Time elapsed : 67.73 s
#
# Epoch 62/100
# -----------
# Train | Loss : 0.7380  Acc : 75.09%
# Val   | Loss : 1.1491  Acc : 64.17%
# Time elapsed : 66.47 s
#
# Epoch 63/100
# -----------
# Train | Loss : 0.7204  Acc : 75.49%
# Val   | Loss : 1.2688  Acc : 61.41%
# Time elapsed : 68.59 s
#
# Epoch 64/100
# -----------
# Train | Loss : 0.7300  Acc : 75.21%
# Val   | Loss : 1.1600  Acc : 64.10%
# Time elapsed : 66.50 s
#
# Epoch 65/100
# -----------
# Train | Loss : 0.6788  Acc : 77.39%
# Val   | Loss : 1.2308  Acc : 63.89%
# Time elapsed : 66.63 s
#
# Epoch 66/100
# -----------
# Train | Loss : 0.7373  Acc : 74.98%
# Val   | Loss : 1.2615  Acc : 63.18%
# Time elapsed : 67.82 s
#
# Epoch 67/100
# -----------
# Train | Loss : 0.6892  Acc : 76.38%
# Val   | Loss : 1.1402  Acc : 65.30%
# Time elapsed : 66.01 s
#
# Epoch 68/100
# -----------
# Train | Loss : 0.6912  Acc : 76.17%
# Val   | Loss : 1.1935  Acc : 64.17%
# Time elapsed : 67.23 s
#
# Epoch 69/100
# -----------
# Train | Loss : 0.7101  Acc : 75.44%
# Val   | Loss : 1.1737  Acc : 65.09%
# Time elapsed : 66.50 s
#
# Epoch 70/100
# -----------
# Train | Loss : 0.6458  Acc : 78.45%
# Val   | Loss : 1.1748  Acc : 64.24%
# Time elapsed : 66.63 s
#
# Epoch 71/100
# -----------
# Train | Loss : 0.6414  Acc : 78.04%
# Val   | Loss : 1.1645  Acc : 65.58%
# Time elapsed : 67.62 s
#
# Epoch 72/100
# -----------
# Train | Loss : 0.6516  Acc : 78.34%
# Val   | Loss : 1.2279  Acc : 64.59%
# Time elapsed : 65.59 s
#
# Epoch 73/100
# -----------
# Train | Loss : 0.6321  Acc : 78.45%
# Val   | Loss : 1.2052  Acc : 65.37%
# Time elapsed : 66.84 s
#
# Epoch 74/100
# -----------
# Train | Loss : 0.6219  Acc : 79.19%
# Val   | Loss : 1.2028  Acc : 64.81%
# Time elapsed : 67.13 s
#
# Epoch 75/100
# -----------
# Train | Loss : 0.6656  Acc : 77.77%
# Val   | Loss : 1.2116  Acc : 64.81%
# Time elapsed : 66.70 s
#
# Epoch 76/100
# -----------
# Train | Loss : 0.5980  Acc : 79.35%
# Val   | Loss : 1.1655  Acc : 66.08%
# Time elapsed : 67.49 s
#
# Epoch 77/100
# -----------
# Train | Loss : 0.6451  Acc : 78.07%
# Val   | Loss : 1.1884  Acc : 65.30%
# Time elapsed : 65.71 s
#
# Epoch 78/100
# -----------
# Train | Loss : 0.6792  Acc : 77.39%
# Val   | Loss : 1.1810  Acc : 65.65%
# Time elapsed : 66.05 s
#
# Epoch 79/100
# -----------
# Train | Loss : 0.6504  Acc : 78.53%
# Val   | Loss : 1.1941  Acc : 63.89%
# Time elapsed : 66.52 s
#
# Epoch 80/100
# -----------
# Train | Loss : 0.5902  Acc : 80.04%
# Val   | Loss : 1.2064  Acc : 66.36%
# Time elapsed : 65.91 s
#
# Epoch 81/100
# -----------
# Train | Loss : 0.7206  Acc : 76.40%
# Val   | Loss : 1.1513  Acc : 66.29%
# Time elapsed : 68.01 s
#
# Epoch 82/100
# -----------
# Train | Loss : 0.5954  Acc : 79.43%
# Val   | Loss : 1.1702  Acc : 66.29%
# Time elapsed : 67.99 s
#
# Epoch 83/100
# -----------
# Train | Loss : 0.6787  Acc : 76.50%
# Val   | Loss : 1.1874  Acc : 65.02%
# Time elapsed : 67.09 s
#
# Epoch 84/100
# -----------
# Train | Loss : 0.5799  Acc : 79.77%
# Val   | Loss : 1.2231  Acc : 65.72%
# Time elapsed : 65.50 s
#
# Epoch 85/100
# -----------
# Train | Loss : 0.5633  Acc : 80.65%
# Val   | Loss : 1.1742  Acc : 66.29%
# Time elapsed : 66.93 s
#
# Epoch 86/100
# -----------
# Train | Loss : 0.5917  Acc : 79.93%
# Val   | Loss : 1.2026  Acc : 65.30%
# Time elapsed : 67.98 s
#
# Epoch 87/100
# -----------
# Train | Loss : 0.5752  Acc : 80.14%
# Val   | Loss : 1.1652  Acc : 66.43%
# Time elapsed : 71.15 s
#
# Epoch 88/100
# -----------
# Train | Loss : 0.5585  Acc : 80.51%
# Val   | Loss : 1.1534  Acc : 67.00%
# Time elapsed : 69.78 s
#
# Epoch 89/100
# -----------
# Train | Loss : 0.5556  Acc : 81.41%
# Val   | Loss : 1.2236  Acc : 65.65%
# Time elapsed : 69.08 s
#
# Epoch 90/100
# -----------
# Train | Loss : 0.7453  Acc : 76.40%
# Val   | Loss : 1.2336  Acc : 64.17%
# Time elapsed : 69.50 s
#
# Epoch 91/100
# -----------
# Train | Loss : 0.5752  Acc : 80.32%
# Val   | Loss : 1.1869  Acc : 65.30%
# Time elapsed : 68.17 s
#
# Epoch 92/100
# -----------
# Train | Loss : 0.5400  Acc : 81.87%
# Val   | Loss : 1.1912  Acc : 66.36%
# Time elapsed : 68.95 s
#
# Epoch 93/100
# -----------
# Train | Loss : 0.4863  Acc : 83.55%
# Val   | Loss : 1.1750  Acc : 67.35%
# Time elapsed : 69.48 s
#
# Epoch 94/100
# -----------
# Train | Loss : 0.5057  Acc : 82.44%
# Val   | Loss : 1.2671  Acc : 63.39%
# Time elapsed : 68.78 s
#
# Epoch 95/100
# -----------
# Train | Loss : 0.5245  Acc : 81.75%
# Val   | Loss : 1.2338  Acc : 66.15%
# Time elapsed : 69.50 s
#
# Epoch 96/100
# -----------
# Train | Loss : 0.5042  Acc : 82.65%
# Val   | Loss : 1.1625  Acc : 68.27%
# Time elapsed : 70.28 s
#
# Epoch 97/100
# -----------
# Train | Loss : 0.4915  Acc : 82.84%
# Val   | Loss : 1.2190  Acc : 66.64%
# Time elapsed : 71.23 s
#
# Epoch 98/100
# -----------
# Train | Loss : 0.4639  Acc : 83.90%
# Val   | Loss : 1.2403  Acc : 66.01%
# Time elapsed : 68.17 s
#
# Epoch 99/100
# -----------
# Train | Loss : 0.4846  Acc : 83.73%
# Val   | Loss : 1.2628  Acc : 65.72%
# Time elapsed : 70.47 s
#
# Epoch 100/100
# -----------
# Train | Loss : 0.5043  Acc : 82.63%
# Val   | Loss : 1.2872  Acc : 64.17%
# Time elapsed : 70.17 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.figure(figsize=(18, 5))
epoch_num = range(1, 101)
plt.subplot(1, 2, 1)
plt.title('Accuracy')
plt.ylim(0, 110)
plt.grid(True)
plt.plot(epoch_num, acc[2], color="blue")
plt.plot(epoch_num, acc[0], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])
plt.subplot(1, 2, 2)
plt.title('Loss')
plt.ylim(0, 3)
plt.grid(True)
plt.plot(epoch_num, acc[3], color="blue")
plt.plot(epoch_num, acc[1], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])

# %%
optimizer = optim.Adam(my_model.parameters(), lr=0.0005)
trained_model_tuning, acc_tuning = train_val(50, {"train": train_loader, "val": val_loader}, trained_model, loss, optimizer, device=dev)
