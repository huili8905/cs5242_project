# %% [markdown]
# ## Video Action Classification

# %%
import os
import pickle

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_packed_sequence, pack_sequence, pack_padded_sequence
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device : {}".format(dev))
# Out:
# Using device : cuda:0

# %% [markdown]
# Load dataset

# %%
# pickle_filename = 'data.pickle'

# if os.path.isfile(pickle_filename):
#     with open(pickle_filename, 'rb') as file:
#         train_data_feat, train_data_labels, test_data_feat = pickle.load(file)
# else:
#     from read_datasetBreakfast import load_data, read_mapping_dict

#     COMP_PATH = ''

#     ''' 
#     training to load train set
#     test to load test set
#     '''
#     train_split =  os.path.join(COMP_PATH, 'splits/train.split1.bundle') #Train Split
#     test_split  =  os.path.join(COMP_PATH, 'splits/test.split1.bundle') #Test Split
#     GT_folder   =  os.path.join(COMP_PATH, 'groundTruth/') #Ground Truth Labels for each training video 
#     DATA_folder =  os.path.join(COMP_PATH, 'data/') #Frame I3D features for all videos
#     mapping_loc =  os.path.join(COMP_PATH, 'splits/mapping_bf.txt') 

#     actions_dict = read_mapping_dict(mapping_loc)
#     train_data_feat, train_data_labels = load_data( train_split, actions_dict, GT_folder, DATA_folder, datatype = "training") #Get features and labels
#     test_data_feat = load_data( test_split, actions_dict, GT_folder, DATA_folder, datatype = "test") #Get features only
    
#     with open(pickle_filename, 'wb') as file:
#         pickle.dump((train_data_feat, train_data_labels, test_data_feat), file)

# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))

# %% [markdown]
# ```python
# print(len(train_data_feat))
# print(len(train_data_labels))
# print(len(test_data_feat))
# > 1460
# > 1460
# > 252
# ```

# %% [markdown]
# Flatten dataset

# %%
# with open("training_segment.txt", 'r') as file:
#     training_segment = [[int(a) for a in line.split()] for line in file]

# # tot_segment_len = 0
# # n_segment_len = 0
# # max_segment_len = 0
# # min_segment_len = float("inf")

# train_feat_flat = []
# train_labels_flat = []
# train_flat_idx = []
# for video_idx, video_segments in enumerate(tqdm(training_segment)):
#     for i in range(len(video_segments)-1):
#         segment_len = video_segments[i+1] - video_segments[i]
# #         tot_segment_len += segment_len
# #         n_segment_len += 1
# #         if segment_len > max_segment_len:
# #             max_segment_len = segment_len
# #         if segment_len < min_segment_len:
# #             min_segment_len = segment_len
#         train_flat_idx.append(len(train_feat_flat))
#         train_feat_flat.extend(train_data_feat[video_idx][video_segments[i]:video_segments[i+1]])
#         train_labels_flat.extend([(train_data_labels[video_idx][i])-1]*segment_len)
# train_flat_idx.append(len(train_feat_flat))

# # avg_segment_len = tot_segment_len / n_segment_len
# # print(avg_segment_len, max_segment_len, min_segment_len)

# %% [markdown]
# ```python
# print(avg_segment_len, max_segment_len, min_segment_len)
# > 404.3518021201413 5791 8
# ```

# %% [markdown]
# Pickle (or load) flatten dataset

# %%
num_split = 10
load_split = 10

files_exist = []
for i in range(num_split):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    files_exist.append(os.path.isfile(pickle_filename))

if not all(files_exist):
    max_len = len(train_feat_flat)
    split_len = max_len//num_split
    for i in tqdm(range(num_split)):
        pickle_filename = "flatten_data_{}.pickle".format(i)
        start_idx = split_len*i
        end_idx = split_len*(i+1) if i < num_split-1 else max_len
        print(i, start_idx, end_idx)
        with open(pickle_filename, 'wb') as file:
            train_feat_split_tensor = torch.stack(train_feat_flat[start_idx:end_idx]).to(dtype=torch.float32)
            train_labels_split_tensor = torch.LongTensor(train_labels_flat[start_idx:end_idx])
            pickle.dump((train_feat_split_tensor, train_labels_split_tensor), file)
    with open("flatten_data_idx.txt", 'w') as file:
        for i in train_flat_idx:
            file.write("{} ".format(i))

train_feat_split_list = []
train_labels_split_list = []
for i in tqdm(range(load_split)):
    pickle_filename = "flatten_data_{}.pickle".format(i)
    with open(pickle_filename, 'rb') as file:
        train_feat_split, train_labels_split = pickle.load(file)
        train_feat_split_list.append(train_feat_split)
        train_labels_split_list.append(train_labels_split)
with open("flatten_data_idx.txt", 'r') as file:
    train_flat_idx = [int(a) for line in file for a in line.split()]

train_feat_tensor = torch.cat(train_feat_split_list, dim=0)
train_labels_tensor = torch.cat(train_labels_split_list, dim=0)
print(train_feat_tensor.shape)
print(train_labels_tensor.shape)
print(len(train_flat_idx))
print(train_flat_idx[:10])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# torch.Size([2860789, 400])
# torch.Size([2860789])
# 7076
# [0, 260, 465, 793, 1054, 1687, 5923, 7216, 7288, 7338]

# %% [markdown]
# Define model

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
#         self.dropout1 = nn.Dropout(p=0.1)
        self.num_layers = 2
        self.lstm = nn.LSTM(400, 64, batch_first=True, num_layers=self.num_layers, dropout=0.5)
        self.dropout2 = nn.Dropout(p=0.3)
        self.linear = nn.Linear(64*(2+self.num_layers), 47)
        self.padding_value = 0
    def forward(self, x):
#         x_pad, lengths = pad_packed_sequence(x, batch_first=True, padding_value=self.padding_value)
#         x_pad = self.dropout1(x_pad)
#         x = pack_padded_sequence(x_pad, lengths, batch_first=True, enforce_sorted=False)
        
        h, (h_last, c) = self.lstm(x)
        
        h_pad, lengths = pad_packed_sequence(h, batch_first=True, padding_value=self.padding_value)
        h_avg_pool = torch.sum(h_pad, 1) / (torch.sum((h_pad != self.padding_value), 1) + 1e-5)
        h_max_pool = torch.max(h_pad, 1)[0]
        x = torch.cat((*(h_last.unbind()), h_avg_pool, h_max_pool), 1)
        
        x = self.dropout2(x)
        
        x = self.linear(x)
        return x

model = Model()
for param in model.parameters():
    print(type(param.data), param.size())
# Out:
# <class 'torch.Tensor'> torch.Size([256, 400])
# <class 'torch.Tensor'> torch.Size([256, 64])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([256, 64])
# <class 'torch.Tensor'> torch.Size([256, 64])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([256])
# <class 'torch.Tensor'> torch.Size([47, 256])
# <class 'torch.Tensor'> torch.Size([47])

# %% [markdown]
# Define training routine

# %%
import time
import copy

import copy
def train_val(num_epoch, dataloader_dict, model, loss, optimizer, print_epoch=True, device=None):
    val_acc_history = []
    val_loss_history = []
    train_acc_history = []
    train_loss_history = []
    best_acc = 0.0
    best_model_weights = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epoch):
        since = time.time()
        if print_epoch:
            print("Epoch {}/{}".format(epoch+1, num_epoch))
            print("-----------")
        
        for phase in ["train", "val"]:
            if phase == "train":
                model.train()
            else :
                model.eval()
            total_loss = 0.0
            total_correct = 0.0
            for X, y, batch_len in dataloader_dict[phase]:
                if device is not None:
                    X = X.to(device)
                    y = y.to(device)
                with torch.set_grad_enabled(phase == "train"):
                    y_tilde = model(X)
                    L = loss(y_tilde, y)
                    if phase == "train":
                        optimizer.zero_grad()
                        L.backward()
                        optimizer.step()
                y_tilde_label = torch.argmax(y_tilde, dim=1)
                num_correct = torch.sum((y_tilde_label == y))
                
                total_loss += L.item() * batch_len
                total_correct += num_correct.item()
            
            epoch_loss = total_loss / len(dataloader_dict[phase].dataset)
            epoch_acc = (total_correct / len(dataloader_dict[phase].dataset)) * 100
            
            if phase == "val":
                val_loss_history.append(epoch_loss)
                val_acc_history.append(epoch_acc)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_weights = copy.deepcopy(model.state_dict())
            if phase == "train":
                train_loss_history.append(epoch_loss)
                train_acc_history.append(epoch_acc)

            if print_epoch:
                print("{} | Loss : {:.4f}  Acc : {:.2f}%".format(phase.capitalize().ljust(5), epoch_loss, epoch_acc))
        
        print("Time elapsed : {:.2f} s".format(time.time() - since))
        print()
    
    model.load_state_dict(best_model_weights)
    return model, (val_acc_history, val_loss_history, train_acc_history, train_loss_history)

# %% [markdown]
# Create dataset

# %%
from torch.utils.data import Dataset, DataLoader, Subset
from torch._utils import _accumulate

class MyDataset(Dataset):
    
    def __init__(self, features, labels, indices):
        self.features = features
        self.labels = labels
        self.indices = indices
        self.len = len(self.indices) - 1

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        return (self.features[self.indices[idx]:self.indices[idx+1]], self.labels[self.indices[idx]])

my_dataset = MyDataset(train_feat_tensor, train_labels_tensor, train_flat_idx)

# %% [markdown]
# Split dataset

# %%
tot_len = len(my_dataset)
print("Number of training data: {}".format(tot_len))

train_split_size = 0.8
lengths = [int(tot_len*train_split_size), tot_len - int(tot_len*train_split_size)]

train_dataset, val_dataset = torch.utils.data.random_split(my_dataset, lengths)
# Out:
# Number of training data: 7075

# %% [markdown]
# Create DataLoader

# %%
def collate(batch_data):
    features = []
    labels = []
    for feature, label in batch_data:
        features.append(feature)
        labels.append(label)
    return (pack_sequence(features, enforce_sorted=False), torch.tensor(labels), len(batch_data))

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True, pin_memory=True, collate_fn=collate)

# %% [markdown]
# Start training

# %%
my_model = Model()
my_model.to(dev)
loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(my_model.parameters())

trained_model, acc = train_val(100, {"train": train_loader, "val": val_loader}, my_model, loss, optimizer, device=dev)
# Out:
# Epoch 1/100
# -----------
# Train | Loss : 3.2980  Acc : 14.91%
# Val   | Loss : 2.8306  Acc : 22.26%
# Time elapsed : 61.57 s
#
# Epoch 2/100
# -----------
# Train | Loss : 2.7118  Acc : 25.51%
# Val   | Loss : 2.5265  Acc : 28.20%
# Time elapsed : 61.12 s
#
# Epoch 3/100
# -----------
# Train | Loss : 2.5435  Acc : 28.52%
# Val   | Loss : 2.3318  Acc : 33.29%
# Time elapsed : 60.22 s
#
# Epoch 4/100
# -----------
# Train | Loss : 2.3336  Acc : 32.49%
# Val   | Loss : 2.2592  Acc : 32.23%
# Time elapsed : 61.11 s
#
# Epoch 5/100
# -----------
# Train | Loss : 2.2275  Acc : 34.20%
# Val   | Loss : 2.1846  Acc : 34.63%
# Time elapsed : 61.29 s
#
# Epoch 6/100
# -----------
# Train | Loss : 2.0749  Acc : 37.84%
# Val   | Loss : 2.0348  Acc : 39.08%
# Time elapsed : 60.01 s
#
# Epoch 7/100
# -----------
# Train | Loss : 1.9605  Acc : 40.80%
# Val   | Loss : 2.0099  Acc : 40.42%
# Time elapsed : 61.69 s
#
# Epoch 8/100
# -----------
# Train | Loss : 1.8972  Acc : 42.53%
# Val   | Loss : 1.8679  Acc : 42.61%
# Time elapsed : 58.75 s
#
# Epoch 9/100
# -----------
# Train | Loss : 1.8056  Acc : 44.45%
# Val   | Loss : 1.8405  Acc : 45.37%
# Time elapsed : 59.76 s
#
# Epoch 10/100
# -----------
# Train | Loss : 1.7611  Acc : 46.15%
# Val   | Loss : 1.8260  Acc : 45.02%
# Time elapsed : 59.61 s
#
# Epoch 11/100
# -----------
# Train | Loss : 1.6523  Acc : 48.48%
# Val   | Loss : 1.8659  Acc : 43.67%
# Time elapsed : 59.54 s
#
# Epoch 12/100
# -----------
# Train | Loss : 1.6932  Acc : 48.13%
# Val   | Loss : 1.6916  Acc : 47.21%
# Time elapsed : 60.47 s
#
# Epoch 13/100
# -----------
# Train | Loss : 1.5412  Acc : 51.38%
# Val   | Loss : 1.6086  Acc : 51.59%
# Time elapsed : 59.91 s
#
# Epoch 14/100
# -----------
# Train | Loss : 1.4842  Acc : 52.46%
# Val   | Loss : 1.5692  Acc : 52.16%
# Time elapsed : 60.21 s
#
# Epoch 15/100
# -----------
# Train | Loss : 1.4979  Acc : 52.60%
# Val   | Loss : 1.5820  Acc : 52.01%
# Time elapsed : 60.55 s
#
# Epoch 16/100
# -----------
# Train | Loss : 1.3921  Acc : 55.80%
# Val   | Loss : 1.5624  Acc : 51.94%
# Time elapsed : 60.21 s
#
# Epoch 17/100
# -----------
# Train | Loss : 1.3735  Acc : 56.24%
# Val   | Loss : 1.5742  Acc : 51.94%
# Time elapsed : 59.70 s
#
# Epoch 18/100
# -----------
# Train | Loss : 1.3907  Acc : 55.85%
# Val   | Loss : 1.5574  Acc : 52.01%
# Time elapsed : 59.82 s
#
# Epoch 19/100
# -----------
# Train | Loss : 1.2727  Acc : 59.47%
# Val   | Loss : 1.4591  Acc : 55.05%
# Time elapsed : 60.25 s
#
# Epoch 20/100
# -----------
# Train | Loss : 1.2309  Acc : 60.78%
# Val   | Loss : 1.4782  Acc : 53.29%
# Time elapsed : 60.63 s
#
# Epoch 21/100
# -----------
# Train | Loss : 1.2922  Acc : 59.40%
# Val   | Loss : 1.6127  Acc : 48.20%
# Time elapsed : 59.71 s
#
# Epoch 22/100
# -----------
# Train | Loss : 1.2762  Acc : 58.92%
# Val   | Loss : 1.4877  Acc : 52.79%
# Time elapsed : 60.86 s
#
# Epoch 23/100
# -----------
# Train | Loss : 1.2427  Acc : 60.04%
# Val   | Loss : 1.3834  Acc : 55.90%
# Time elapsed : 60.08 s
#
# Epoch 24/100
# -----------
# Train | Loss : 1.3212  Acc : 59.03%
# Val   | Loss : 1.5050  Acc : 53.71%
# Time elapsed : 59.91 s
#
# Epoch 25/100
# -----------
# Train | Loss : 1.2048  Acc : 62.40%
# Val   | Loss : 1.3999  Acc : 56.82%
# Time elapsed : 57.91 s
#
# Epoch 26/100
# -----------
# Train | Loss : 1.1444  Acc : 63.23%
# Val   | Loss : 1.3747  Acc : 55.41%
# Time elapsed : 59.05 s
#
# Epoch 27/100
# -----------
# Train | Loss : 1.1094  Acc : 63.99%
# Val   | Loss : 1.3478  Acc : 56.75%
# Time elapsed : 59.44 s
#
# Epoch 28/100
# -----------
# Train | Loss : 1.0540  Acc : 66.25%
# Val   | Loss : 1.3394  Acc : 57.95%
# Time elapsed : 60.21 s
#
# Epoch 29/100
# -----------
# Train | Loss : 1.0234  Acc : 66.75%
# Val   | Loss : 1.2951  Acc : 58.73%
# Time elapsed : 63.14 s
#
# Epoch 30/100
# -----------
# Train | Loss : 0.9876  Acc : 67.86%
# Val   | Loss : 1.3014  Acc : 59.58%
# Time elapsed : 60.01 s
#
# Epoch 31/100
# -----------
# Train | Loss : 0.9861  Acc : 68.18%
# Val   | Loss : 1.2971  Acc : 59.15%
# Time elapsed : 60.04 s
#
# Epoch 32/100
# -----------
# Train | Loss : 0.9854  Acc : 67.70%
# Val   | Loss : 1.3231  Acc : 57.10%
# Time elapsed : 60.88 s
#
# Epoch 33/100
# -----------
# Train | Loss : 0.9433  Acc : 69.51%
# Val   | Loss : 1.3274  Acc : 59.43%
# Time elapsed : 60.25 s
#
# Epoch 34/100
# -----------
# Train | Loss : 0.9239  Acc : 69.95%
# Val   | Loss : 1.3334  Acc : 58.45%
# Time elapsed : 61.08 s
#
# Epoch 35/100
# -----------
# Train | Loss : 0.8893  Acc : 70.72%
# Val   | Loss : 1.2846  Acc : 59.15%
# Time elapsed : 60.71 s
#
# Epoch 36/100
# -----------
# Train | Loss : 0.8567  Acc : 71.96%
# Val   | Loss : 1.3123  Acc : 59.08%
# Time elapsed : 59.41 s
#
# Epoch 37/100
# -----------
# Train | Loss : 0.8314  Acc : 72.86%
# Val   | Loss : 1.2987  Acc : 58.52%
# Time elapsed : 60.21 s
#
# Epoch 38/100
# -----------
# Train | Loss : 0.7958  Acc : 74.05%
# Val   | Loss : 1.2383  Acc : 62.76%
# Time elapsed : 60.05 s
#
# Epoch 39/100
# -----------
# Train | Loss : 0.7981  Acc : 73.37%
# Val   | Loss : 1.3033  Acc : 57.60%
# Time elapsed : 59.49 s
#
# Epoch 40/100
# -----------
# Train | Loss : 0.8068  Acc : 72.69%
# Val   | Loss : 1.2987  Acc : 60.57%
# Time elapsed : 59.75 s
#
# Epoch 41/100
# -----------
# Train | Loss : 0.8528  Acc : 71.75%
# Val   | Loss : 1.2539  Acc : 59.86%
# Time elapsed : 61.32 s
#
# Epoch 42/100
# -----------
# Train | Loss : 0.7581  Acc : 74.63%
# Val   | Loss : 1.2454  Acc : 61.77%
# Time elapsed : 61.53 s
#
# Epoch 43/100
# -----------
# Train | Loss : 0.7997  Acc : 73.60%
# Val   | Loss : 1.3440  Acc : 60.00%
# Time elapsed : 61.97 s
#
# Epoch 44/100
# -----------
# Train | Loss : 0.7786  Acc : 73.37%
# Val   | Loss : 1.2224  Acc : 61.98%
# Time elapsed : 59.94 s
#
# Epoch 45/100
# -----------
# Train | Loss : 0.7226  Acc : 76.01%
# Val   | Loss : 1.2880  Acc : 60.57%
# Time elapsed : 62.50 s
#
# Epoch 46/100
# -----------
# Train | Loss : 0.7205  Acc : 76.04%
# Val   | Loss : 1.2920  Acc : 61.70%
# Time elapsed : 64.84 s
#
# Epoch 47/100
# -----------
# Train | Loss : 0.6805  Acc : 77.17%
# Val   | Loss : 1.2896  Acc : 58.30%
# Time elapsed : 66.48 s
#
# Epoch 48/100
# -----------
# Train | Loss : 0.6796  Acc : 77.12%
# Val   | Loss : 1.3188  Acc : 59.51%
# Time elapsed : 64.72 s
#
# Epoch 49/100
# -----------
# Train | Loss : 0.6913  Acc : 77.26%
# Val   | Loss : 1.3271  Acc : 60.99%
# Time elapsed : 63.71 s
#
# Epoch 50/100
# -----------
# Train | Loss : 0.6909  Acc : 77.14%
# Val   | Loss : 1.3449  Acc : 61.06%
# Time elapsed : 65.51 s
#
# Epoch 51/100
# -----------
# Train | Loss : 0.6972  Acc : 76.82%
# Val   | Loss : 1.2998  Acc : 60.99%
# Time elapsed : 66.19 s
#
# Epoch 52/100
# -----------
# Train | Loss : 0.6718  Acc : 76.98%
# Val   | Loss : 1.2789  Acc : 61.41%
# Time elapsed : 66.23 s
#
# Epoch 53/100
# -----------
# Train | Loss : 0.6274  Acc : 78.67%
# Val   | Loss : 1.2895  Acc : 62.19%
# Time elapsed : 67.99 s
#
# Epoch 54/100
# -----------
# Train | Loss : 0.6067  Acc : 80.02%
# Val   | Loss : 1.2561  Acc : 62.33%
# Time elapsed : 65.69 s
#
# Epoch 55/100
# -----------
# Train | Loss : 0.6160  Acc : 79.28%
# Val   | Loss : 1.2660  Acc : 62.90%
# Time elapsed : 66.49 s
#
# Epoch 56/100
# -----------
# Train | Loss : 0.6043  Acc : 79.77%
# Val   | Loss : 1.2766  Acc : 61.20%
# Time elapsed : 66.20 s
#
# Epoch 57/100
# -----------
# Train | Loss : 0.6051  Acc : 79.33%
# Val   | Loss : 1.2717  Acc : 62.69%
# Time elapsed : 65.23 s
#
# Epoch 58/100
# -----------
# Train | Loss : 0.6247  Acc : 78.71%
# Val   | Loss : 1.2718  Acc : 62.33%
# Time elapsed : 63.10 s
#
# Epoch 59/100
# -----------
# Train | Loss : 0.5931  Acc : 79.79%
# Val   | Loss : 1.2395  Acc : 62.90%
# Time elapsed : 63.92 s
#
# Epoch 60/100
# -----------
# Train | Loss : 0.6426  Acc : 78.53%
# Val   | Loss : 1.2947  Acc : 61.41%
# Time elapsed : 62.28 s
#
# Epoch 61/100
# -----------
# Train | Loss : 0.5573  Acc : 81.17%
# Val   | Loss : 1.2251  Acc : 63.60%
# Time elapsed : 63.29 s
#
# Epoch 62/100
# -----------
# Train | Loss : 0.5392  Acc : 81.38%
# Val   | Loss : 1.2783  Acc : 62.12%
# Time elapsed : 62.82 s
#
# Epoch 63/100
# -----------
# Train | Loss : 0.5578  Acc : 81.18%
# Val   | Loss : 1.2464  Acc : 62.97%
# Time elapsed : 63.24 s
#
# Epoch 64/100
# -----------
# Train | Loss : 0.5110  Acc : 83.00%
# Val   | Loss : 1.2475  Acc : 63.25%
# Time elapsed : 64.49 s
#
# Epoch 65/100
# -----------
# Train | Loss : 0.4800  Acc : 83.75%
# Val   | Loss : 1.3536  Acc : 61.27%
# Time elapsed : 62.76 s
#
# Epoch 66/100
# -----------
# Train | Loss : 0.6023  Acc : 80.14%
# Val   | Loss : 1.3441  Acc : 60.49%
# Time elapsed : 62.64 s
#
# Epoch 67/100
# -----------
# Train | Loss : 0.5788  Acc : 80.34%
# Val   | Loss : 1.2654  Acc : 62.40%
# Time elapsed : 61.53 s
#
# Epoch 68/100
# -----------
# Train | Loss : 0.5394  Acc : 81.75%
# Val   | Loss : 1.2831  Acc : 62.76%
# Time elapsed : 62.55 s
#
# Epoch 69/100
# -----------
# Train | Loss : 0.4826  Acc : 83.50%
# Val   | Loss : 1.2913  Acc : 63.18%
# Time elapsed : 64.19 s
#
# Epoch 70/100
# -----------
# Train | Loss : 0.4704  Acc : 83.82%
# Val   | Loss : 1.3036  Acc : 62.19%
# Time elapsed : 63.75 s
#
# Epoch 71/100
# -----------
# Train | Loss : 0.4748  Acc : 83.90%
# Val   | Loss : 1.3723  Acc : 61.84%
# Time elapsed : 64.56 s
#
# Epoch 72/100
# -----------
# Train | Loss : 0.4341  Acc : 85.53%
# Val   | Loss : 1.2890  Acc : 62.61%
# Time elapsed : 63.19 s
#
# Epoch 73/100
# -----------
# Train | Loss : 0.4704  Acc : 84.31%
# Val   | Loss : 1.4014  Acc : 61.91%
# Time elapsed : 63.14 s
#
# Epoch 74/100
# -----------
# Train | Loss : 0.4594  Acc : 84.24%
# Val   | Loss : 1.3521  Acc : 60.78%
# Time elapsed : 62.27 s
#
# Epoch 75/100
# -----------
# Train | Loss : 0.4197  Acc : 85.90%
# Val   | Loss : 1.3482  Acc : 62.69%
# Time elapsed : 61.42 s
#
# Epoch 76/100
# -----------
# Train | Loss : 0.4959  Acc : 82.83%
# Val   | Loss : 1.2724  Acc : 62.90%
# Time elapsed : 63.31 s
#
# Epoch 77/100
# -----------
# Train | Loss : 0.4154  Acc : 85.28%
# Val   | Loss : 1.3403  Acc : 64.03%
# Time elapsed : 63.86 s
#
# Epoch 78/100
# -----------
# Train | Loss : 0.4296  Acc : 85.69%
# Val   | Loss : 1.3352  Acc : 62.97%
# Time elapsed : 62.97 s
#
# Epoch 79/100
# -----------
# Train | Loss : 0.4292  Acc : 85.64%
# Val   | Loss : 1.3276  Acc : 62.05%
# Time elapsed : 61.28 s
#
# Epoch 80/100
# -----------
# Train | Loss : 0.5079  Acc : 82.81%
# Val   | Loss : 1.3209  Acc : 61.13%
# Time elapsed : 63.69 s
#
# Epoch 81/100
# -----------
# Train | Loss : 0.4414  Acc : 84.86%
# Val   | Loss : 1.2996  Acc : 63.53%
# Time elapsed : 61.93 s
#
# Epoch 82/100
# -----------
# Train | Loss : 0.3663  Acc : 87.97%
# Val   | Loss : 1.3129  Acc : 63.89%
# Time elapsed : 62.81 s
#
# Epoch 83/100
# -----------
# Train | Loss : 0.3751  Acc : 87.28%
# Val   | Loss : 1.3300  Acc : 63.39%
# Time elapsed : 62.54 s
#
# Epoch 84/100
# -----------
# Train | Loss : 0.3651  Acc : 87.79%
# Val   | Loss : 1.3657  Acc : 63.89%
# Time elapsed : 62.47 s
#
# Epoch 85/100
# -----------
# Train | Loss : 0.3896  Acc : 87.21%
# Val   | Loss : 1.3459  Acc : 62.76%
# Time elapsed : 62.75 s
#
# Epoch 86/100
# -----------
# Train | Loss : 0.3798  Acc : 86.89%
# Val   | Loss : 1.3471  Acc : 65.09%
# Time elapsed : 62.97 s
#
# Epoch 87/100
# -----------
# Train | Loss : 0.3317  Acc : 89.20%
# Val   | Loss : 1.4078  Acc : 63.39%
# Time elapsed : 62.23 s
#
# Epoch 88/100
# -----------
# Train | Loss : 0.3486  Acc : 88.07%
# Val   | Loss : 1.3798  Acc : 62.97%
# Time elapsed : 63.42 s
#
# Epoch 89/100
# -----------
# Train | Loss : 0.3474  Acc : 88.27%
# Val   | Loss : 1.2883  Acc : 64.88%
# Time elapsed : 61.16 s
#
# Epoch 90/100
# -----------
# Train | Loss : 0.3773  Acc : 87.39%
# Val   | Loss : 1.3283  Acc : 63.04%
# Time elapsed : 61.04 s
#
# Epoch 91/100
# -----------
# Train | Loss : 0.3798  Acc : 86.77%
# Val   | Loss : 1.3602  Acc : 63.46%
# Time elapsed : 62.22 s
#
# Epoch 92/100
# -----------
# Train | Loss : 0.3535  Acc : 87.92%
# Val   | Loss : 1.3539  Acc : 63.67%
# Time elapsed : 62.92 s
#
# Epoch 93/100
# -----------
# Train | Loss : 0.3281  Acc : 88.75%
# Val   | Loss : 1.4266  Acc : 61.98%
# Time elapsed : 63.54 s
#
# Epoch 94/100
# -----------
# Train | Loss : 0.4041  Acc : 86.31%
# Val   | Loss : 1.5509  Acc : 61.13%
# Time elapsed : 61.53 s
#
# Epoch 95/100
# -----------
# Train | Loss : 0.4381  Acc : 85.02%
# Val   | Loss : 1.3804  Acc : 63.18%
# Time elapsed : 64.02 s
#
# Epoch 96/100
# -----------
# Train | Loss : 0.3176  Acc : 89.33%
# Val   | Loss : 1.3461  Acc : 63.32%
# Time elapsed : 62.87 s
#
# Epoch 97/100
# -----------
# Train | Loss : 0.3148  Acc : 89.45%
# Val   | Loss : 1.4472  Acc : 63.25%
# Time elapsed : 65.59 s
#
# Epoch 98/100
# -----------
# Train | Loss : 0.4126  Acc : 85.76%
# Val   | Loss : 1.4497  Acc : 61.84%
# Time elapsed : 65.07 s
#
# Epoch 99/100
# -----------
# Train | Loss : 0.3447  Acc : 88.73%
# Val   | Loss : 1.3617  Acc : 65.30%
# Time elapsed : 64.57 s
#
# Epoch 100/100
# -----------
# Train | Loss : 0.3207  Acc : 89.10%
# Val   | Loss : 1.3990  Acc : 64.24%
# Time elapsed : 64.90 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.figure(figsize=(18, 5))
epoch_num = range(1, 101)
plt.subplot(1, 2, 1)
plt.title('Accuracy')
plt.ylim(0, 110)
plt.grid(True)
plt.plot(epoch_num, acc[2], color="blue")
plt.plot(epoch_num, acc[0], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])
plt.subplot(1, 2, 2)
plt.title('Loss')
plt.ylim(0, 3)
plt.grid(True)
plt.plot(epoch_num, acc[3], color="blue")
plt.plot(epoch_num, acc[1], color="red")
blue_patch = mpatches.Patch(color='blue', label='Training')
red_patch = mpatches.Patch(color='red', label='Validation')
plt.legend(handles=[blue_patch, red_patch])

# %%
optimizer = optim.Adam(my_model.parameters(), lr=0.0005)
trained_model, acc = train_val(50, {"train": train_loader, "val": val_loader}, trained_model, loss, optimizer, device=dev)
# Out:
# Epoch 1/50
# -----------
# Train | Loss : 0.2566  Acc : 91.73%
# Val   | Loss : 1.4047  Acc : 64.81%
# Time elapsed : 65.06 s
#
# Epoch 2/50
# -----------
# Train | Loss : 0.2185  Acc : 93.36%
# Val   | Loss : 1.3911  Acc : 65.09%
# Time elapsed : 64.98 s
#
# Epoch 3/50
# -----------
# Train | Loss : 0.2129  Acc : 93.30%
# Val   | Loss : 1.3780  Acc : 65.02%
# Time elapsed : 64.85 s
#
# Epoch 4/50
# -----------
# Train | Loss : 0.2230  Acc : 92.28%
# Val   | Loss : 1.3931  Acc : 64.59%
# Time elapsed : 64.36 s
#
# Epoch 5/50
# -----------
# Train | Loss : 0.2096  Acc : 93.25%
# Val   | Loss : 1.4082  Acc : 65.72%
# Time elapsed : 66.19 s
#
# Epoch 6/50
# -----------
# Train | Loss : 0.2059  Acc : 93.73%
# Val   | Loss : 1.4261  Acc : 65.16%
# Time elapsed : 66.78 s
#
# Epoch 7/50
# -----------
# Train | Loss : 0.1862  Acc : 93.94%
# Val   | Loss : 1.4103  Acc : 66.08%
# Time elapsed : 67.52 s
#
# Epoch 8/50
# -----------
# Train | Loss : 0.1870  Acc : 94.36%
# Val   | Loss : 1.4247  Acc : 65.16%
# Time elapsed : 64.49 s
#
# Epoch 9/50
# -----------
# Train | Loss : 0.2020  Acc : 93.22%
# Val   | Loss : 1.4236  Acc : 65.87%
# Time elapsed : 65.17 s
#
# Epoch 10/50
# -----------
# Train | Loss : 0.1989  Acc : 93.59%
# Val   | Loss : 1.4492  Acc : 64.95%
# Time elapsed : 65.07 s
#
# Epoch 11/50
# -----------
# Train | Loss : 0.1873  Acc : 93.71%
# Val   | Loss : 1.4156  Acc : 66.08%
# Time elapsed : 63.46 s
#
# Epoch 12/50
# -----------
# Train | Loss : 0.1796  Acc : 94.31%
# Val   | Loss : 1.4451  Acc : 64.88%
# Time elapsed : 65.82 s
#
# Epoch 13/50
# -----------
# Train | Loss : 0.1813  Acc : 94.15%
# Val   | Loss : 1.4657  Acc : 65.44%
# Time elapsed : 65.52 s
#
# Epoch 14/50
# -----------
# Train | Loss : 0.1699  Acc : 94.63%
# Val   | Loss : 1.5056  Acc : 63.82%
# Time elapsed : 65.35 s
#
# Epoch 15/50
# -----------
# Train | Loss : 0.1629  Acc : 94.81%
# Val   | Loss : 1.4957  Acc : 64.73%
# Time elapsed : 64.58 s
#
# Epoch 16/50
# -----------
# Train | Loss : 0.1654  Acc : 94.36%
# Val   | Loss : 1.4720  Acc : 65.09%
# Time elapsed : 67.79 s
#
# Epoch 17/50
# -----------
# Train | Loss : 0.1665  Acc : 95.02%
# Val   | Loss : 1.4415  Acc : 66.01%
# Time elapsed : 65.23 s
#
# Epoch 18/50
# -----------
# Train | Loss : 0.1583  Acc : 94.95%
# Val   | Loss : 1.4885  Acc : 64.31%
# Time elapsed : 65.73 s
#
# Epoch 19/50
# -----------
# Train | Loss : 0.1687  Acc : 94.75%
# Val   | Loss : 1.5662  Acc : 63.18%
# Time elapsed : 64.15 s
#
# Epoch 20/50
# -----------
# Train | Loss : 0.1885  Acc : 93.78%
# Val   | Loss : 1.5596  Acc : 63.04%
# Time elapsed : 64.83 s
#
# Epoch 21/50
# -----------
# Train | Loss : 0.1869  Acc : 94.01%
# Val   | Loss : 1.4747  Acc : 64.38%
# Time elapsed : 65.09 s
#
# Epoch 22/50
# -----------
# Train | Loss : 0.1604  Acc : 95.16%
# Val   | Loss : 1.4805  Acc : 64.95%
# Time elapsed : 63.82 s
#
# Epoch 23/50
# -----------
# Train | Loss : 0.1458  Acc : 95.80%
# Val   | Loss : 1.5123  Acc : 64.88%
# Time elapsed : 66.88 s
#
# Epoch 24/50
# -----------
# Train | Loss : 0.1564  Acc : 94.96%
# Val   | Loss : 1.5062  Acc : 63.75%
# Time elapsed : 66.58 s
#
# Epoch 25/50
# -----------
# Train | Loss : 0.1516  Acc : 95.11%
# Val   | Loss : 1.5476  Acc : 64.52%
# Time elapsed : 64.57 s
#
# Epoch 26/50
# -----------
# Train | Loss : 0.1307  Acc : 96.25%
# Val   | Loss : 1.5107  Acc : 65.87%
# Time elapsed : 65.00 s
#
# Epoch 27/50
# -----------
# Train | Loss : 0.1503  Acc : 95.19%
# Val   | Loss : 1.5505  Acc : 65.02%
# Time elapsed : 65.30 s
#
# Epoch 28/50
# -----------
# Train | Loss : 0.1547  Acc : 95.04%
# Val   | Loss : 1.5615  Acc : 63.39%
# Time elapsed : 63.86 s
#
# Epoch 29/50
# -----------
# Train | Loss : 0.1427  Acc : 95.57%
# Val   | Loss : 1.5778  Acc : 64.10%
# Time elapsed : 66.30 s
#
# Epoch 30/50
# -----------
# Train | Loss : 0.1598  Acc : 94.93%
# Val   | Loss : 1.5274  Acc : 65.23%
# Time elapsed : 63.97 s
#
# Epoch 31/50
# -----------
# Train | Loss : 0.1613  Acc : 95.04%
# Val   | Loss : 1.5652  Acc : 64.59%
# Time elapsed : 63.29 s
#
# Epoch 32/50
# -----------
# Train | Loss : 0.1403  Acc : 95.46%
# Val   | Loss : 1.5572  Acc : 64.52%
# Time elapsed : 65.29 s
#
# Epoch 33/50
# -----------
# Train | Loss : 0.1487  Acc : 95.09%
# Val   | Loss : 1.6093  Acc : 63.46%
# Time elapsed : 64.57 s
#
# Epoch 34/50
# -----------
# Train | Loss : 0.1471  Acc : 95.18%
# Val   | Loss : 1.5801  Acc : 64.38%
# Time elapsed : 65.55 s
#
# Epoch 35/50
# -----------
# Train | Loss : 0.1453  Acc : 95.55%
# Val   | Loss : 1.5807  Acc : 64.38%
# Time elapsed : 65.06 s
#
# Epoch 36/50
# -----------
# Train | Loss : 0.1659  Acc : 94.59%
# Val   | Loss : 1.5599  Acc : 63.89%
# Time elapsed : 65.95 s
#
# Epoch 37/50
# -----------
# Train | Loss : 0.1489  Acc : 95.12%
# Val   | Loss : 1.6588  Acc : 62.12%
# Time elapsed : 65.61 s
#
# Epoch 38/50
# -----------
# Train | Loss : 0.1909  Acc : 93.67%
# Val   | Loss : 1.5032  Acc : 65.80%
# Time elapsed : 65.99 s
#
# Epoch 39/50
# -----------
# Train | Loss : 0.1457  Acc : 95.14%
# Val   | Loss : 1.5895  Acc : 64.38%
# Time elapsed : 64.37 s
#
# Epoch 40/50
# -----------
# Train | Loss : 0.1410  Acc : 95.34%
# Val   | Loss : 1.5486  Acc : 64.95%
# Time elapsed : 65.29 s
#
# Epoch 41/50
# -----------
# Train | Loss : 0.1224  Acc : 96.31%
# Val   | Loss : 1.5510  Acc : 64.88%
# Time elapsed : 65.64 s
#
# Epoch 42/50
# -----------
# Train | Loss : 0.1107  Acc : 96.77%
# Val   | Loss : 1.5383  Acc : 65.58%
# Time elapsed : 65.92 s
#
# Epoch 43/50
# -----------
# Train | Loss : 0.1231  Acc : 95.90%
# Val   | Loss : 1.5378  Acc : 64.10%
# Time elapsed : 66.40 s
#
# Epoch 44/50
# -----------
# Train | Loss : 0.1312  Acc : 95.90%
# Val   | Loss : 1.6299  Acc : 63.96%
# Time elapsed : 65.76 s
#
# Epoch 45/50
# -----------
# Train | Loss : 0.1260  Acc : 96.20%
# Val   | Loss : 1.6014  Acc : 65.65%
# Time elapsed : 64.97 s
#
# Epoch 46/50
# -----------
# Train | Loss : 0.1039  Acc : 96.87%
# Val   | Loss : 1.5595  Acc : 65.02%
# Time elapsed : 64.63 s
#
# Epoch 47/50
# -----------
# Train | Loss : 0.1268  Acc : 96.08%
# Val   | Loss : 1.6072  Acc : 64.31%
# Time elapsed : 65.63 s
#
# Epoch 48/50
# -----------
# Train | Loss : 0.1141  Acc : 96.41%
# Val   | Loss : 1.6211  Acc : 63.60%
# Time elapsed : 66.96 s
#
# Epoch 49/50
# -----------
# Train | Loss : 0.1251  Acc : 96.01%
# Val   | Loss : 1.6525  Acc : 63.46%
# Time elapsed : 66.46 s
#
# Epoch 50/50
# -----------
# Train | Loss : 0.1080  Acc : 96.66%
# Val   | Loss : 1.6396  Acc : 64.31%
# Time elapsed : 65.67 s
